# %% [markdown]
# # 1. 모집단과 표본

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. 확률

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3. 경우의 수
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1 ) 경우의 수 계산
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4. 팩토리얼
# ![image.png](attachment:image.png)

# %% [markdown]
# 얼마 전 인터넷 상에서 화제가 되었던, 초등학생 수학 문제로 보는 “문과-이과 구분법” 을 아시나요?
#
# 40-32/2 = ? 의 정답은 무엇일까요?
#
# 초등학생은 이에 4!라고 대답했습니다. 이 초등학생의 답을 보고
#
# 이과생은 “잘 알고 있네.” 라고 했고,
#
# 문과생은 “역시 잘 모르는구나.” 라고 대답하고 있습니다.
#
# 혹시 여러분은 왜 이런지 아시겠나요? 이 유머는 문,이과 상관없이 팩토리얼(!) 에 대해서만 알면 되는데요. 한 번 4! 을 계산해보겠습니다.
#
# 그럼 이제 4명의 학생을 뽑는 경우의 수를 계산해보겠습니다. 첫 번째로는 4명을 모두 뽑을 수 있고, 두 번째에서는 첫 번째에서 뽑힌 학생을 제외한 3명, 세 번째에서는 첫,두 번째에서 뽑힌 학생을 제외한 2명, 마지막에서는 앞에서 뽑힌 3명을 제외한 1명이 남으므로 4!과 같습니다.
#
# 이렇게 n개의 요소들을 순서대로 배치하는 경우의 수를 팩토리얼로 구할 수 있습니다.

# %%
# ! 함수 정의 
def fac(n): 
    if n == 0 :
        return 1
    elif n == 1 :
        return 1
    else :
        return n * fac(n-1) 
    
# 4! 계산
print(fac(4))
# Out:
# 24

# %% [markdown]
# # 5. 공리
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 6. 순열

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# [] 안에서로다른n개의원소를주고, 이원소들중k개를순서를고려하여뽑는경우의수계산

# %%
# 20명의 반 학생들 중 4명을 뽑아 400m 계주 달리기 선수를 뽑는다고 합니다.

# 순서를 고려하여 학생들을 배치할 때 나올 수 있는 경우의 수는 얼마일까요?

116280

# %%
from itertools import permutations 
from itertools import combinations

# 순열 : 6명 수강생 중 2명에게 순위별 상품을 주는 경우의 수 
rank_per = list(permutations(["가","나","다","라","마","바"],2))
rank_per_num = len(rank_per)

print(rank_per)
print(rank_per_num)
# Out:
# [('가', '나'), ('가', '다'), ('가', '라'), ('가', '마'), ('가', '바'), ('나', '가'), ('나', '다'), ('나', '라'), ('나', '마'), ('나', '바'), ('다', '가'), ('다', '나'), ('다', '라'), ('다', '마'), ('다', '바'), ('라', '가'), ('라', '나'), ('라', '다'), ('라', '마'), ('라', '바'), ('마', '가'), ('마', '나'), ('마', '다'), ('마', '라'), ('마', '바'), ('바', '가'), ('바', '나'), ('바', '다'), ('바', '라'), ('바', '마')]
# 30

# %% [markdown]
# # 7. 조합

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# [] 안에서로다른n개의원소를주고, 이원소들중k개를순서를고려하지않고뽑는경우의수계산

# %%
# 내기에서 진 10명의 친구들 중 3명을 청소 당번으로 뽑으려고 합니다.

# 청소 당번은 순서가 의미를 갖지 않으므로, 순서를 고려하지 않고 뽑고자 합니다.

# 청소 당번을 뽑을 수 있는 경우의 수는 얼마일까요?

10 * 9 * 8 / 3 / 2
# Out:
# 120.0

# %%
from itertools import permutations 
from itertools import combinations

# 조합 : 6명 수강생 중 2명에게 순위 상관없이 상품을 주는 경우의 수 
rank_com = list(combinations(["가","나","다","라","마","바"],2))
rank_com_num = len(rank_com)

print(rank_com)
print(rank_com_num)
# Out:
# [('가', '나'), ('가', '다'), ('가', '라'), ('가', '마'), ('가', '바'), ('나', '다'), ('나', '라'), ('나', '마'), ('나', '바'), ('다', '라'), ('다', '마'), ('다', '바'), ('라', '마'), ('라', '바'), ('마', '바')]
# 15

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 8. 중복순열

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# [] 안에서로다른n개의원소를주고, 이원소들중k개를중복을허용하면서순서를고려하여뽑는경우의수계산

# %%
# 날씨의 신은 코더랜드의 하루의 날씨를 마음대로 정할 수 있습니다.

# 날씨의 신은 “맑음”, “흐림”, “비” 세 가지 날씨 중 하나를 골라 하루의 날씨를 정할 수 있습니다.

# 날씨의 신이 2월 25일, 2월 26일, 2월 28일 이렇게 3일의 날씨를 결정하고자 합니다.

# 날씨의 신이 날씨를 결정하는 경우의 수는 총 몇 가지일까요?

from itertools import product
list(product(['맑음', '흐림', '비'], repeat = 3))
print(len(list(product(['맑음', '흐림', '비'], repeat = 3))))
# Out:
# 27

# %%
from itertools import product
from itertools import combinations_with_replacement

# 중복순열

re_per = list(product(['A', 'B','C','D','E'], repeat = 3))
re_per_num = len(re_per)

print(re_per)
print(re_per_num)
# Out:
# [('A', 'A', 'A'), ('A', 'A', 'B'), ('A', 'A', 'C'), ('A', 'A', 'D'), ('A', 'A', 'E'), ('A', 'B', 'A'), ('A', 'B', 'B'), ('A', 'B', 'C'), ('A', 'B', 'D'), ('A', 'B', 'E'), ('A', 'C', 'A'), ('A', 'C', 'B'), ('A', 'C', 'C'), ('A', 'C', 'D'), ('A', 'C', 'E'), ('A', 'D', 'A'), ('A', 'D', 'B'), ('A', 'D', 'C'), ('A', 'D', 'D'), ('A', 'D', 'E'), ('A', 'E', 'A'), ('A', 'E', 'B'), ('A', 'E', 'C'), ('A', 'E', 'D'), ('A', 'E', 'E'), ('B', 'A', 'A'), ('B', 'A', 'B'), ('B', 'A', 'C'), ('B', 'A', 'D'), ('B', 'A', 'E'), ('B', 'B', 'A'), ('B', 'B', 'B'), ('B', 'B', 'C'), ('B', 'B', 'D'), ('B', 'B', 'E'), ('B', 'C', 'A'), ('B', 'C', 'B'), ('B', 'C', 'C'), ('B', 'C', 'D'), ('B', 'C', 'E'), ('B', 'D', 'A'), ('B', 'D', 'B'), ('B', 'D', 'C'), ('B', 'D', 'D'), ('B', 'D', 'E'), ('B', 'E', 'A'), ('B', 'E', 'B'), ('B', 'E', 'C'), ('B', 'E', 'D'), ('B', 'E', 'E'), ('C', 'A', 'A'), ('C', 'A', 'B'), ('C', 'A', 'C'), ('C', 'A', 'D'), ('C', 'A', 'E'), ('C', 'B', 'A'), ('C', 'B', 'B'), ('C', 'B', 'C'), ('C', 'B', 
# ...

# %% [markdown]
# # 9. 중복조합

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# [] 안에서로다른n개의원소를주고, 이원소들중k개를순서를중복을허락하여순서를고려하지않고뽑는경우의수계산

# %%
# 과일 가게에는 오렌지, 포도, 사과가 있습니다.

# 엘리스 토끼는 이 과일들을 적절히 골라 5개의 과일을 사려고 합니다.

# 즉, 오렌지 5개를 살 수도 있고, 오렌지 2개, 포도 2개, 사과 1개를 살 수도 있습니다.

# 이와 같이 엘리스 토끼가 3종류의 과일을 적절히 골라 5개의 과일을 사는 경우의 수는 몇 가지일까요?

# (단, 과일은 충분히 많이 있다고 가정합니다.)

from itertools import combinations
list( combinations_with_replacement(['오렌지','포도','사과'], 5))
len(list( combinations_with_replacement(['오렌지','포도','사과'], 5)))
# Out:
# 21

# %%
from itertools import product
from itertools import combinations_with_replacement

# 중복조합

re_com = list(combinations_with_replacement(['A','B','C','D','E'], 3))
re_com_num = len(re_com)

print(re_com)
print(re_com_num)

# %% [markdown]
# # 10. 조건부 확률

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 11. 독립

# %%
두 사건 A와 B가 서로 독립이면, 한 사건의 결과가 다른 사건의 결과에 영향을 미치지 않음을 의미한다.

따라서 P(A|B) = P(A)이고, P(B) = P(B|A)가 성립한다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import random
answer_Q1andQ2 = 0
answer_Q2 = 0
answer_Q1orQ2 = 0
random.seed(4)

# 함수 정의 
def random_answer():
    return random.choice(["A", "B"])
    


# 30명의 응답 결과
for i in range(30):
    Q1 = random_answer()
    Q2 = random_answer()
    
    if Q2 == "A":
        answer_Q2 += 1
    if Q2 == "A" and Q1 == "A":
        answer_Q1andQ2 += 1
    if Q2 == "A" or Q1 == "A":
        answer_Q1orQ2 += 1


# 조건부 확률과 독립
# 조건부 확률을 사용하여 1번 문항에 A를 응답한 경우(사건A)에서 두 문항 모두에 A를 응답한 경우(사건B)의 확률을 구해보면
print( "P(B|A):", answer_Q1andQ2/answer_Q2)

# 최소 한 문항에 A를 응답한 경우(사건O) 일 때, 두 문항 모두에 A를 응답한 경우(사건B) 의 확률을 계산해보면
print( "P(B|O):", answer_Q1andQ2/answer_Q1orQ2)

# %% [markdown]
# P(B|A)를 잘 계산하셨습니다! 1번 문항에 A를 응답했다라는 조건(사건A)이 주어졌을 때 두 문항 모두 A를 응답할 (사건B) 조건부 확률은 무엇인가요?
#
#  = P(B|A)
#
#
# P(B|O)를 잘 계산하셨습니다! 최소 하나의 문항에 A를 응답했다라는 조건(사건O)이 주어졌을 때 두 문항 모두 A를 응답할 (사건B) 조건부 확률은 무엇인가요?
#
#  = P{B|O)

# %% [markdown]
# # 12. 확률 변수

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 확률분포는 확률변수가 가질 수 있는 값들 중에서, 그 값을 가질 확률이 어떻게 되는지를 나타낸 것이다.
#
# 따라서 동전을 던지는 사건을 X라고 했을 때,
#
# P(X=앞면)은 1/2, P(X=뒷면) = 1/2이다.
#
# 그렇다면 정육면체 주사위를 던지는 사건을 Y라고 할 때 3이 나오는 확률변수 P(Y=3)은 얼마인가?
#
#  = 1 / 6

# %%
from sympy.stats import given, density, Die

## Q1. 6개의 면이 있는 주사위 생성
Die6 = Die('Die6', 6)
Die6_dict = density(Die6).dict
print(Die6)
print(Die6_dict)


## Q2. 3 초과의 면만 나오는 조건을 가진 주사위 생성
condi = given(Die6, Die6 > 3)
condi_dict = density(condi).dict
print(condi)
print(condi_dict)

# %% [markdown]
# # 13. 확률분포

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1 ) 이산 확률 분포
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2 ) 연속 확률 분포
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 14. 확률질량함수

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 15. 확률밀도함수

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 16. 누적분포함수

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
