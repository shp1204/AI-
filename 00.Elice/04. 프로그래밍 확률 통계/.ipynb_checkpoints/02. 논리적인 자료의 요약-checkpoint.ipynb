# %% [markdown]
# # 1. 중심 위치의 측도

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1 ) 평균

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
from scipy import stats

coffee = np.array([202,177,121,148,89,121,137,158])

#평균계산
cf_mean = np.mean(coffee)
print("Mean :", round(cf_mean,2))

# %% [markdown]
# ## 2 ) 중앙값

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
from scipy import stats

coffee = np.array([202,177,121,148,89,121,137,158])

#중앙값 계산
cf_median = np.median(coffee)
print("Median :", round(cf_median,2))

# %% [markdown]
# ## 3 ) 최빈값

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
from scipy import stats

coffee = np.array([202,177,121,148,89,121,137,158])

#최빈값 계산
cf_mode = stats.mode(coffee)
print("Mode :", cf_mode[0][0])

# %% [markdown]
# ## 4 ) 비교

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. 퍼진 정도의 측도

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1 ) 분산
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from statistics import variance, stdev
import numpy as np

coffee = np.array([202,177,121,148,89,121,137,158])

#분산 계산
cf_var = variance(coffee)
print("Simple Variance :", round(cf_var,2))

# %% [markdown]
# ## 2 ) 표준편차
# ![image.png](attachment:image.png)

# %%
from statistics import variance, stdev
import numpy as np

coffee = np.array([202,177,121,148,89,121,137,158])

#표준편차 계산
cf_std = stdev(coffee)
print("Sample std.Dev : ", round(cf_std,2))

# %% [markdown]
# ## 3 ) 범위
# ![image.png](attachment:image.png)

# %%
from statistics import variance, stdev
import numpy as np

coffee = np.array([202,177,121,148,89,121,137,158])

#범위 계산
cf_range = np.max(coffee, axis = 0) - np.min(coffee, axis = 0)
print("Range :", cf_range)

# %% [markdown]
# ## 4 ) 백분위수
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from statistics import variance, stdev
import numpy as np

coffee = np.array([202,177,121,148,89,121,137,158])

#백분위수
cf_quant_20 = np.percentile(coffee, 20)
cf_quant_80 = np.percentile(coffee, 80)
print("20 Quantiles : ", cf_quant_20 )
print("80 Quantiles : ", cf_quant_80 )

# %% [markdown]
# ## 5 ) 사분위수

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 사분위수 범위는, 제1사분위수와 제3사분위수 사이에 대해 범위를 구한 것이므로 극단값의 영향을 받지 않고 퍼진 정도를 확인할 수 있지만, 관측값들의 값들이 온전히 반영되지 않는다는 단점이 있습니다.

# %%
from statistics import variance, stdev
import numpy as np

coffee = np.array([202,177,121,148,89,121,137,158])

#IQR 
q75, q25 = np.percentile(coffee, [75, 25])
cf_IQR = q75-q25
print("Inter quartile range:",cf_IQR)

# %% [markdown]
# ## 6 ) 비교
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 7 ) 변동계수
# ![image.png](attachment:image.png)

# %%
from statistics import variance, stdev
import numpy as np

coffee = np.array([202,177,121,148,89,121,137,158])

#CV
cf_cv = stdev(coffee)/np.mean(coffee)
cf_cv = round(cf_cv,2)
print("CV:", cf_cv)

# %% [markdown]
# # 3. 도수분포표와 상자그림

# %% [markdown]
# ## 1 ) 도수분포표

# %% [markdown]
# 수치형 자료가 도수분포표로만 주어진 경우, 관측값들의 원래 값들은 알 수 없으므로 계급에 속해있는 모든 관측값들이 계급의 중간값을 갖는다고 가정하여 평균을 구해야 한다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd

# 주량 데이터
drink_cup = pd.DataFrame({'cup' :[22,7,19,3,10,8,19,7,15,9,35,5],'who' : [ 'A', 'E', 'D', 'B', 'C','A','A','A','D','B', 'C','B']})

print(drink_cup)

# 도수분포표

factor_cup = pd.cut(drink_cup.cup, 4)
group_cup = drink_cup['cup'].groupby(factor_cup)
count_cup = group_cup.agg(['count'])

print(count_cup)

# %% [markdown]
# ## 2 ) 상자그림

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt


#카페인 함유량
coffee = np.array([202,177,121,148,89,121,137,158])

#상자그림
fig, ax = plt.subplots()
## 여기에 코드를 작성해주세요
plt.boxplot(coffee)

##
plt.show()

# %% [markdown]
# # 4. 두 변수 자료의 요약

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1 ) 분할표

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np 
import pandas as pd
import matplotlib as plt

# 데이터 불러오기
mart = pd.read_csv("mart.csv")
print(mart)

# Q1.지역별로 선호하는 마트
region_crosstab = pd.crosstab(mart['region'], mart['mart'])
print(region_crosstab)

# Q2. 가족구성원의 수별로 선호하는 마트
famnum_crosstab = pd.crosstab(mart['family_num'], mart['mart'])
print(famnum_crosstab)

# %% [markdown]
# ## 2 ) 산점도

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt
import pandas as pd
elice_utils = EliceUtils()    
# body.csv 읽어오기 
body = pd.read_csv("body.csv")

# Q1. 산점도 
##1-1 키와 몸무게간 산점도 
fig, ax = plt.subplots()
## 여기에 코드를 작성해 주세요
plt.scatter(body['height'], body['weight'])

##
plt.show()
fig.savefig("height_weight_plot.png")


##1-2 키와 체지방량 산점도 
fig, ax = plt.subplots()
## 여기에 코드를 작성해 주세요
plt.scatter(body['height'], body['body_fat'])

##
plt.show()
fig.savefig("height_fat_plot.png")


##1-3 키와 다리길이 산점도 
fig, ax = plt.subplots()
## 여기에 코드를 작성해 주세요
plt.scatter(body['height'], body['leglen'])

##
plt.show()
fig.savefig("height_leglen_plot.png")



##1-4 키와 모발 산점도 
fig, ax = plt.subplots()
## 여기에 코드를 작성해 주세요
plt.scatter(body['height'], body['hair'])

##
plt.show()
fig.savefig("height_hair_plot.png")

# %% [markdown]
# ## 3 ) 공분산
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from statistics import variance, stdev
import numpy as np 
import pandas as pd

# body.csv 읽어오기 
body = pd.read_csv("body.csv")

# 공분산
cov_body = body.cov()

print(cov_body)

# %% [markdown]
# ## 4 ) 상관계수
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from statistics import variance, stdev
import numpy as np 
import pandas as pd

# body.csv 읽어오기 
body = pd.read_csv("body.csv")

# 상관계수 
corr_body = body.corr()

print(corr_body)
