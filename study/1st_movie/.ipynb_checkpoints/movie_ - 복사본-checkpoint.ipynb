# %%
import pandas as pd
df = pd.read_csv('./data/movies_train.csv')
testdf = pd.read_csv('./data/movies_test.csv')
# 지수 표현 제거
pd.options.display.float_format = '{:.5f}'.format

# %%
df.corr()
# Out:
#                   time  dir_prev_bfnum  dir_prev_num  num_staff  num_actor  \
# time           1.00000         0.26468       0.30673    0.62321    0.11415
# dir_prev_bfnum 0.26468         1.00000       0.13182    0.32352    0.08382
# dir_prev_num   0.30673         0.13182       1.00000    0.45071    0.01401
# num_staff      0.62321         0.32352       0.45071    1.00000    0.07787
# num_actor      0.11415         0.08382       0.01401    0.07787    1.00000
# box_off_num    0.44145         0.28318       0.25967    0.54426    0.11118
#
#                 box_off_num
# time                0.44145
# dir_prev_bfnum      0.28318
# dir_prev_num        0.25967
# num_staff           0.54426
# num_actor           0.11118
# box_off_num         1.00000

# %% [markdown]
# # 전처리

# %%
# column 생성
def make_col(dataframe, column_name, mapper) :
    new = []
    for i in dataframe[column_name] :
        if i in mapper.keys() :
            new.append(mapper.get(i))
        else :
            new.append(1)
    dataframe['new_' + str(column_name)] = pd.DataFrame(new)
    del dataframe[column_name]
    return dataframe

# %% [markdown]
# ## title
# title 은 제거

# %%
del df['title']
del testdf['title']

# %% [markdown]
# ## distributor

# %%
a = df.groupby(['distributor']).mean()['box_off_num'].sort_values(ascending=False)

distributor_mapper = {}
for i in range(len(a)) :
    if a[i] >= 1000000 :
        distributor_mapper.update({a.index[i] : 5 })
    elif a[i] >= 100000 :
        distributor_mapper.update({a.index[i] : 4 })
    elif a[i] >= 10000 :
        distributor_mapper.update({a.index[i] : 3 })
    elif a[i] >= 1000 :
        distributor_mapper.update({a.index[i] : 2 })
    else :
        distributor_mapper.update({a.index[i] : 1 })

df = make_col(df, 'distributor', distributor_mapper )
testdf = make_col(testdf, 'distributor', distributor_mapper )

# %% [markdown]
# ### 배급사별 box_off_num 의 평균에 따른 head, tail

# %%
df.groupby(['distributor']).mean()['box_off_num'].sort_values(ascending=False).head(20)
# Out:
# distributor
# CJ E&M Pictures    4.122337e+06
# (주)쇼박스             3.386656e+06
# (주)아이필름코퍼레이션       3.117859e+06
# 쇼박스(주)미디어플렉스       2.634823e+06
# 영구아트무비             2.541603e+06
# CJ E&M 영화부문        2.505309e+06
# (주)NEW             2.184405e+06
# CJ 엔터테인먼트          2.162742e+06
# 이십세기폭스코리아(주)       1.637046e+06
# SK텔레콤(주)           1.383867e+06
# CGV아트하우스           1.318189e+06
# 롯데엔터테인먼트           1.238149e+06
# 전망좋은영화사            1.214237e+06
# 주머니필름              1.201944e+06
# NEW                1.019017e+06
# 싸이더스               9.634390e+05
# 시네마서비스             8.968432e+05
# 보람엔터테인먼트           8.496350e+05
# 스튜디오 블루            7.716990e+05
# 씨네그루(주)키다리이엔티      7.551840e+05
# Name: box_off_num, dtype: float64

# %%
df.groupby(['distributor']).mean()['box_off_num'].sort_values(ascending=False).tail(20)
# Out:
# distributor
# 웃기씨네           464.5
# 판다미디어          432.0
# (주)더픽쳐스        429.0
# 이상우필름          339.0
# (주)온비즈넷        310.0
# (주)유비네트워크      303.0
# (주)휘엔터테인먼트     228.0
# 크리에이티브컴즈(주)    188.0
# ysfilm         172.0
# 에스와이코마드        163.0
# 건시네마           162.0
# (주)씨엠닉스        136.0
# 위더스필름           90.0
# 인터콘미디어          79.0
# 한국YWCA연합회       71.0
# 나우콘텐츠           54.0
# 위드시네마           46.0
# 사람과 사람들         42.0
# 고구마공작소           8.0
# 인피니티엔터테인먼트       2.0
# Name: box_off_num, dtype: float64

# %% [markdown]
# ## genre

# %% [markdown]
# ### genre 에 따른 box_off_num 평균 확인

# %%
df.groupby(['genre']).mean()['box_off_num'].sort_values(ascending=False).index
# Out:
# Index(['느와르', '액션', 'SF', '코미디', '드라마', '공포', '미스터리', '멜로/로맨스', '애니메이션',
#        '서스펜스', '다큐멘터리', '뮤지컬'],
#       dtype='object', name='genre')

# %%
df.groupby(['genre']).mean()['box_off_num'].sort_values(ascending=False)
# Out:
# genre
# 느와르       2.263695e+06
# 액션        2.203974e+06
# SF        1.788346e+06
# 코미디       1.193914e+06
# 드라마       6.256898e+05
# 공포        5.908325e+05
# 미스터리      5.275482e+05
# 멜로/로맨스    4.259680e+05
# 애니메이션     1.819267e+05
# 서스펜스      8.261100e+04
# 다큐멘터리     6.717226e+04
# 뮤지컬       6.627000e+03
# Name: box_off_num, dtype: float64

# %%
df['genre'].value_counts()
# Out:
# 드라마       221
# 다큐멘터리      93
# 멜로/로맨스     78
# 코미디        53
# 공포         42
# 액션         28
# 느와르        27
# 애니메이션      21
# 미스터리       17
# SF         13
# 뮤지컬         5
# 서스펜스        2
# Name: genre, dtype: int64

# %% [markdown]
# ### genre_version1

# %%
df = pd.get_dummies(df, columns=['genre'], prefix='genre')
testdf = pd.get_dummies(testdf, columns=['genre'], prefix='genre')

# %% [markdown]
# ### genre_version2
#
# version1, 3 보다 좋음
#
# 영화 종류 묶기 + box_off_num의 평균에 따라 비선호 영화 묶기
#
# => 1466134.4524178207
#
# * 드라마 멜로/로맨스6
#
# * 느와르 액션5
#
# * sf4
#
# * 코미디3
#
# * 공포 미스터리 서스펜스2
#
# * 애니메이션 다큐멘터리 뮤지컬1

# %%
genre_mapper = {'느와르' : 5 , '액션' : 5, 'SF' : 4, '코미디' : 3, '드라마' : 6, '공포' : 2, '미스터리' : 2, '멜로/로맨스' : 6, '애니메이션' : 1,
       '서스펜스' : 2, '다큐멘터리' : 1, '뮤지컬' : 1} 

df = make_col(df, 'genre', genre_mapper )
testdf = make_col(testdf, 'genre', genre_mapper )

# %% [markdown]
# ### genre_version3
#
# box_off_num 평균에 따라 임의로 분류
#
# => 1467553.925063711

# %%
느와르       4
액션        4
SF        3
코미디       3
드라마       2
공포        2
미스터리      2
멜로/로맨스    2
애니메이션     1
서스펜스     1
다큐멘터리     1
뮤지컬       1

# %%
genre_mapper = {'느와르' : 4 , '액션' : 4, 'SF' : 3, '코미디' : 3, '드라마' : 2, '공포' : 2, '미스터리' : 2, '멜로/로맨스' : 2, '애니메이션' : 1,
       '서스펜스' : 1, '다큐멘터리' : 1, '뮤지컬' : 1} 

df = make_col(df, 'genre', genre_mapper )
testdf = make_col(testdf, 'genre', genre_mapper )

# %% [markdown]
# ## release_time
#
# * days 그대로 사용해보자
#
# => sklearn,  1484884.4136596955
#
# => 전처리 하는 것이 더 좋음

# %%
def release_time(df) :
    years, months, days = [], [], []
    for line in df['release_time'] :
        a = line.split('-')
        years.append(int(a[0]))
        months.append(int(a[1]))
        days.append(int(a[2]))
        
    new_days = []
    for i in range(len(days)) :
        if int(days[i]) >= 20 :
            new_days.append(3)
        elif int(days[i]) >= 10 :
            new_days.append(2)
        else :
            new_days.append(1)    
            
    df['release_year'] = pd.DataFrame(years)
    df['release_month'] = pd.DataFrame(months)
    df['release_day'] = pd.DataFrame(new_days)

    del df['release_time']
    return df

df = release_time(df)
testdf = release_time(testdf)

# %% [markdown]
# ## time
#
# 전처리 이전과 비교하였을 때, box_off_num 과의 상관관계는 낮아졌다 ( 0.44 -> 0.29 )
#
# 하지만, 전처리 이후 성능이 개선됨
#
# => 1472434.761373017 ( 130, 70, ~ )
#
# => 1472973.0197688688 ( 130, 100, 70, ~ )

# %%
def time(df) :
    new_time = []
    for i in df['time'] :
        if i >= 130 :
            new_time.append(3)
        elif i > 70 : 
            new_time.append(2)
        else :
            new_time.append(1)

    df['new_time'] = pd.DataFrame(new_time)
    del df['time']
    return df

df = time(df)
testdf = time(testdf)

# %% [markdown]
# ## screening_rat

# %% [markdown]
# ### mapping_version1
#
# version1 이  version2보다 더 좋음

# %%
screening_rat_mapper = {'15세 관람가' : 3, '12세 관람가' : 2, '전체 관람가' : 2, '청소년 관람불가' : 1} 

df = make_col(df, 'screening_rat', screening_rat_mapper )
testdf = make_col(testdf, 'screening_rat', screening_rat_mapper )

# %% [markdown]
# ### mapping_version2

# %%
def screen_rat(df) :
    tmp = sorted(df['screening_rat'].unique(), reverse=False)

    mapping = {}
    num = 1
    for i in tmp :
        mapping.update({i : num})
        num += 1

    return make_col(df, 'screening_rat', mapping)

# %%
df = screen_rat(df)
testdf = screen_rat(testdf)

# %% [markdown]
# ### mapping_version3
#
# version1과 큰 차이는 나지 않지만 더 좋음
#
# => 1483501.7131900766

# %%
df = pd.get_dummies(df, columns=['screening_rat'], prefix='screening_rat')
testdf = pd.get_dummies(testdf, columns=['screening_rat'], prefix='screening_rat')

# %% [markdown]
# ### 관람 연령 제한에 따른 box_off_num 평균, 영화 수

# %%
df.groupby(['screening_rat']).mean()['box_off_num'].sort_values(ascending=False)
# Out:
# screening_rat
# 15세 관람가     1.247519e+06
# 12세 관람가     8.449809e+05
# 청소년 관람불가    3.641813e+05
# 전체 관람가      1.351005e+05
# Name: box_off_num, dtype: float64

# %%
df.groupby(['screening_rat']).count()['box_off_num'].sort_values(ascending=False)
# Out:
# screening_rat
# 청소년 관람불가    204
# 15세 관람가     202
# 12세 관람가     102
# 전체 관람가       92
# Name: box_off_num, dtype: int64

# %% [markdown]
# ## director

# %%
del df['director']
del testdf['director']

# %% [markdown]
# ## dir_prev_bfnum

# %% [markdown]
# ### version1
# * 결측치 0으로 채워 넣음

# %%
df = df.fillna(0)
testdf = testdf.fillna(0)

# %% [markdown]
# ### version2
# * 결측치가 많은 column이므로 제거
#
# => 1483572.7123881471

# %%
del df['dir_prev_bfnum']
del testdf['dir_prev_bfnum']

# %% [markdown]
# ### version3
# * log_scale

# %%
df = df.fillna(0)
testdf = testdf.fillna(0)

# %% [markdown]
# ## dir_prev_num
#
# * column제거하였더니 점수 떨어짐
#
# => 1471931.2287102737

# %%
del df['dir_prev_num']
del testdf['dir_prev_num']

# %% [markdown]
# ## num_staff
#
# staff 는 범주화하지 않는 것이 더 좋다!
#
# =>	1536288.9882051074

# %% [markdown]
# ### staff_version1

# %%
def staff(dataframe) : 
    new_staff = []
    for i in dataframe['num_staff'] :
        if i == 0 :
            new_staff.append(0)
        elif i <= 100 :
            new_staff.append(1)
        elif i <= 300 :
            new_staff.append(2)        
        elif i <= 500 :
            new_staff.append(3)
        else :
            new_staff.append(4)
    dataframe['new_staff'] = pd.DataFrame(new_staff)
    del dataframe['num_staff']
    
    return dataframe

# %%
df = staff(df)
testdf = staff(testdf)

# %%
df.groupby(['new_staff']).mean()['box_off_num'].sort_values(ascending=False)
# Out:
# new_staff
# 4    4.132596e+06
# 3    1.980997e+06
# 2    6.495566e+05
# 1    1.164862e+05
# 0    7.805562e+03
# Name: box_off_num, dtype: float64

# %% [markdown]
# ## num_actor
#
# column 제거했더니 ?
#
# => sklearn, 1470532.643567296

# %%
del df['num_actor']
del testdf['num_actor']

# %%
df
# Out:
#      num_staff  box_off_num  new_distributor  new_genre  release_year  \
# 0           91        23398                5          5          2012
# 1          387      7072501                5          5          2015
# 2          343      6959083                5          5          2013
# 3           20       217866                5          3          2012
# 4          251       483387                5          3          2010
# ..         ...          ...              ...        ...           ...
# 595        510      1475091                5          6          2014
# 596        286      1716438                5          6          2013
# 597        123         2475                3          2          2010
# 598        431      2192525                5          5          2015
# 599        363      7166532                5          5          2013
#
#      release_month  release_day  new_time  screening_rat_12세 관람가  \
# 0               11            3         2                      0
# 1               11            2         3                      0
# 2                6            1         2                      0
# 3                7            2         2                      0
# 4               11            1         2                      0
# ..             ...          ...       ...                    ...
# 595              8            2         2                      0
# 596              3            2         2                      0
# 597              9            3         2                      0
# 598              5            2         2                      0
# 599              1            3         2                      0
#
#      screening_rat_15세 관람가  screening_rat_전체 관람가  screening_rat_청소년 관람불가
# 0                        0                     0                       1
# 1                        0                     0                       1
# 2                        1                     0                       0
# 3                        0                     1                       0
# 4                        1                     0                       0
# ..                     ...                   ...                     ...
# 595                      0                     0                       1
# 596                      1                     0                       0
# 597                      0                     0                       1
# 598                      1                     0                       0
# 599                      1                     0                       0
#
# [600 rows x 12 columns]

# %% [markdown]
# # 상관관계

# %%
df.corr().sort_values(by='box_off_num', ascending = False)
# Out:
#                         num_staff  box_off_num  new_distributor  genre_SF  \
# box_off_num               0.54426      1.00000          0.45016   0.08801
# num_staff                 1.00000      0.54426          0.69184   0.04153
# new_distributor           0.69184      0.45016          1.00000   0.00243
# new_time                  0.32914      0.29498          0.25603   0.02884
# screening_rat_15세 관람가     0.24653      0.21037          0.25791   0.03932
# genre_느와르                 0.20978      0.18487          0.16987  -0.03230
# genre_액션                  0.24919      0.18119          0.17672  -0.03293
# genre_SF                  0.04153      0.08801          0.00243   1.00000
# genre_코미디                 0.10900      0.08278          0.13506  -0.04632
# screening_rat_12세 관람가     0.06047      0.03390          0.03496   0.02408
# release_month            -0.00284      0.01910         -0.02799  -0.00726
# release_year             -0.03289     -0.00250         -0.05986   0.02170
# release_day               0.00825     -0.01102         -0.02770  -0.02874
# genre_미스터리               -0.03484     -0.01689          0.00112  -0.02541
# genre_공포                  0.04187     -0.01763          0.07549  -0.04083
# genre_서스펜스               -0.01402     -0.01981          0.00896  -0.00861
# genre_드라마                 0.06166     -0.03449         -0.02986  -0.11364
# genre_뮤지컬                -0.08248     -0.03521         -0.08493  -0.01364
# genre_애니메이션              -0.12254     -0.05487          0.07856  -0.02834
# genre_멜로/로맨스             -0.03582     -0.05973         -0.07943  -0.05753
# screening_rat_전체 관람가     -0.27374     -0.13353         -0.16415  -0.03156
# screening_rat_청소년 관람불가   -0.08569     -0.13518         -0.16016  -0.03432
# genre_다큐멘터리              -0.34485     -0.15031         -0.26730  -0.06374
#
#                         genre_공포  genre_느와르  genre_다큐멘터리  genre_드라마  \
# box_off_num             -0.01763    0.18487     -0.15031   -0.03449
# num_staff                0.04187    0.20978     -0.34485    0.06166
# new_distributor          0.07549    0.16987     -0.26730   -0.02986
# new_time                -0.01868    0.17683     -0.10756    0.03035
# screening_rat_15세 관람가    0.06718   -0.00153     -0.13945    0.01167
# genre_느와르               -0.05955    1.00000     -0.09297   -0.16576
# genre_액션                -0.06070   -0.04803     -0.09476   -0.16895
# genre_SF                -0.04083   -0.03230     -0.06374   -0.11364
# genre_코미디               -0.08540   -0.06757     -0.13332   -0.23770
# screening_rat_12세 관람가   -0.10677   -0.09824      0.08815    0.11434
# release_month            0.02024   -0.03393     -0.00283   -0.00466
# release_year             0.01730    0.01302     -0.01226   -0.06083
# release_day              0.03654    0.00816     -0.04828   -0.03553
# genre_미스터리              -0.04685   -0.03707     -0.07314   -0.13040
# genre_공포                 1.00000   -0.05955     -0.11750   -0.20950
# genre_서스펜스              -0.01587   -0.01255     -0.02477   -0.04416
# genre_드라마               -0.20950   -0.16576     -0.32705    1.00000
# genre_뮤지컬               -0.02515   -0.01990     -0.03926   -0.07000
# genre_애니메이션             -0.05225   -0.04134     -0.08157   -0.14543
# genre_멜로/로맨스            -0.10605   -0.08391     -0.16556   -0.29518
# screening_rat_전체 관람가    -0.11675   -0.09238      0.48237   -0.16194
# screening_rat_청소년 관람불가   0.10645    0.14969     -0.29768    0.02086
# genre_다큐멘터리             -0.11750   -0.09297      1.00000   -0.32705
#
#                         genre_멜로/로맨스  genre_뮤지컬  ...  genre_액션  genre_코미디  \
# box_off_num                 -0.05973   -0.03521  ...   0.18119    0.08278
# num_staff                   -0.03582   -0.08248  ...   0.24919    0.10900
# new_distributor             -0.07943   -0.08493  ...   0.17672    0.13506
# new_time                    -0.06007    0.05618  ...   0.11945   -0.02120
# screening_rat_15세 관람가       -0.05516   -0.06531  ...   0.10991    0.12623
# genre_느와르                   -0.08391   -0.01990  ...  -0.04803   -0.06757
# genre_액션                    -0.08552   -0.02028  ...   1.00000   -0.06887
# genre_SF                    -0.05753   -0.01364  ...  -0.03293   -0.04632
# genre_코미디                   -0.12033   -0.02853  ...  -0.06887    1.00000
# screening_rat_12세 관람가       -0.04301    0.00732  ...  -0.07909    0.01548
# release_month               -0.01010    0.05914  ...   0.03185   -0.03224
# release_year                 0.06786    0.00274  ...  -0.01352   -0.05330
# release_day                 -0.00056    0.00514  ...   0.07541    0.04964
# genre_미스터리                  -0.06601   -0.01565  ...  -0.03778   -0.05315
# genre_공포                    -0.10605   -0.02515  ...  -0.06070   -0.08540
# genre_서스펜스                  -0.02236   -0.00530  ...  -0.01280   -0.01800
# genre_드라마                   -0.29518   -0.07000  ...  -0.16895   -0.23770
# genre_뮤지컬                   -0.03544    1.00000  ...  -0.02028   -0.02853
# genre_애니메이션                 -0.07362   -0.01746  ...  -0.04214   -0.05928
# genre_멜로/로맨스                 1.00000   -0.03544  ...  -0.08552   -0.12033
# screening_rat_전체 관람가        -0.15075    0.16453  ...  -0.09415   -0.08357
# screening_rat_청소년 관람불가       0.20380   -0.06580  ...   0.02469   -0.07464
# genre_다큐멘터리                 -0.16556   -0.03926  ...  -0.09476   -0.13332
#
#                         release_year  release_month  release_day  new_time  \
# box_off_num                 -0.00250        0.01910     -0.01102   0.29498
# num_staff                   -0.03289       -0.00284      0.00825   0.32914
# new_distributor             -0.05986       -0.02799     -0.02770   0.25603
# new_time                    -0.05254        0.00813      0.02927   1.00000
# screening_rat_15세 관람가       -0.07186       -0.05132     -0.01894   0.04755
# genre_느와르                    0.01302       -0.03393      0.00816   0.17683
# genre_액션                    -0.01352        0.03185      0.07541   0.11945
# genre_SF                     0.02170       -0.00726     -0.02874   0.02884
# genre_코미디                   -0.05330       -0.03224      0.04964  -0.02120
# screening_rat_12세 관람가       -0.02142        0.04292     -0.02659  -0.03082
# release_month                0.04663        1.00000     -0.05270   0.00813
# release_year                 1.00000        0.04663      0.02214  -0.05254
# release_day                  0.02214       -0.05270      1.00000   0.02927
# genre_미스터리                   0.05400        0.02310     -0.04549  -0.01163
# genre_공포                     0.01730        0.02024      0.03654  -0.01868
# genre_서스펜스                   0.02519       -0.00872      0.02486  -0.00394
# genre_드라마                   -0.06083       -0.00466     -0.03553   0.03035
# genre_뮤지컬                    0.00274        0.05914      0.00514   0.05618
# genre_애니메이션                  0.04354        0.01806      0.01972  -0.07472
# genre_멜로/로맨스                 0.06786       -0.01010     -0.00056  -0.06007
# screening_rat_전체 관람가        -0.06660       -0.00010      0.03884  -0.07623
# screening_rat_청소년 관람불가       0.13932        0.01724      0.01043   0.03498
# genre_다큐멘터리                 -0.01226       -0.00283     -0.04828  -0.10756
#
#                         screening_rat_12세 관람가  screening_rat_15세 관람가  \
# box_off_num                           0.03390                0.21037
# num_staff                             0.06047                0.24653
# new_distributor                       0.03496                0.25791
# new_time                             -0.03082                0.04755
# screening_rat_15세 관람가                -0.32242                1.00000
# genre_느와르                            -0.09824               -0.00153
# genre_액션                             -0.07909                0.10991
# genre_SF                              0.02408                0.03932
# genre_코미디                             0.01548                0.12623
# screening_rat_12세 관람가                 1.00000               -0.32242
# release_month                         0.04292               -0.05132
# release_year                         -0.02142               -0.07186
# release_day                          -0.02659               -0.01894
# genre_미스터리                           -0.07728                0.06965
# genre_공포                             -0.10677                0.06718
# genre_서스펜스                           -0.02617               -0.04120
# genre_드라마                             0.11434                0.01167
# genre_뮤지컬                             0.00732               -0.06531
# genre_애니메이션                          -0.01376               -0.11649
# genre_멜로/로맨스                         -0.04301               -0.05516
# screening_rat_전체 관람가                 -0.19260               -0.30318
# screening_rat_청소년 관람불가               -0.32483               -0.51133
# genre_다큐멘터리                           0.08815               -0.13945
#
#                         screening_rat_전체 관람가  screening_rat_청소년 관람불가
# box_off_num                         -0.13353                -0.13518
# num_staff                           -0.27374                -0.08569
# new_distributor                     -0.16415                -0.16016
# new_time                            -0.07623                 0.03498
# screening_rat_15세 관람가               -0.30318                -0.51133
# genre_느와르                           -0.09238                 0.14969
# genre_액션                            -0.09415                 0.02469
# genre_SF                            -0.03156                -0.03432
# genre_코미디                           -0.08357                -0.07464
# screening_rat_12세 관람가               -0.19260                -0.32483
# release_month                       -0.00010                 0.01724
# release_year                        -0.06660                 0.13932
# release_day                          0.03884                 0.01043
# genre_미스터리                          -0.07267                 0.04707
# genre_공포                            -0.11675                 0.10645
# genre_서스펜스                          -0.02461                 0.08057
# genre_드라마                           -0.16194                 0.02086
# genre_뮤지컬                            0.16453                -0.06580
# genre_애니메이션                          0.27133                -0.07926
# genre_멜로/로맨스                        -0.15075                 0.20380
# screening_rat_전체 관람가                 1.00000                -0.30544
# screening_rat_청소년 관람불가              -0.30544                 1.00000
# genre_다큐멘터리                          0.48237                -0.29768
#
# [23 rows x 23 columns]

# %% [markdown]
# # 모델링

# %%
import numpy as np
from sklearn.metrics import make_scorer

def rmse(predict, actual):
    predict = np.array(predict)
    actual = np.array(actual)

    distance = predict - actual
    square_distance = distance ** 2
    mean_square_distance = square_distance.mean()
    score = np.sqrt(mean_square_distance)
    
    return score

rmse_score = make_scorer(rmse)
rmse_score
# Out:
# make_scorer(rmse)

# %% [markdown]
# ## sklearn_Linear Regression

# %%
train_Y = df['box_off_num']
train_X = df.drop(['box_off_num'], axis=1)

test_X = testdf

# %%
from sklearn import linear_model

lm = linear_model.LinearRegression()
lm.fit(train_X, train_Y)

prediction = lm.predict(test_X)

# %% [markdown]
# ## sklearn_RandomForestRegressor
#
# => 1528294.5021972428	 ( epoch X )

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

model = RandomForestRegressor(n_estimators=300,
                              n_jobs=-1,
                              random_state=46)
#score = cross_val_score(model, X_train, y_train, cv=20, scoring=rmse_score).mean()

# %%
train_Y = df['box_off_num']
train_X = df.drop(['box_off_num'], axis=1)

test_X = testdf

model.fit(train_X, train_Y)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=300, n_jobs=-1, oob_score=False,
#                       random_state=46, verbose=0, warm_start=False)

# %%
prediction = model.predict(test_X)
# Out:
# array([1.37224077e+06, 1.37712202e+06, 2.91496949e+06, 2.35731362e+06,
#        2.18836183e+06, 3.83021800e+04, 3.05253000e+03, 1.25348333e+03,
#        4.89507000e+03, 2.70432873e+05, 4.52084997e+05, 1.09368079e+06,
#        2.43055558e+06, 3.80952000e+03, 1.54969315e+06, 2.49022232e+06,
#        4.11237000e+03, 2.80051673e+06, 9.91018117e+05, 4.01313674e+06,
#        3.31340000e+02, 2.75170133e+04, 1.04387323e+05, 2.15437233e+04,
#        2.86300000e+02, 3.14427729e+06, 2.01759000e+03, 2.63354868e+06,
#        9.63927000e+03, 7.76519000e+03, 4.01482357e+06, 2.53251757e+05,
#        3.11146333e+03, 5.57792827e+05, 6.60871667e+03, 2.34236933e+04,
#        1.94996333e+03, 4.38108000e+03, 4.30301000e+03, 3.68430000e+02,
#        5.67607333e+03, 2.82403647e+05, 9.73643447e+05, 3.93951430e+05,
#        1.05306354e+06, 1.88549011e+06, 8.36590000e+02, 1.48209400e+04,
#        7.02168903e+05, 7.65833333e+02, 6.29552667e+03, 1.05540849e+06,
#        5.76044333e+03, 1.29539582e+06, 1.30844980e+06, 2.60748967e+04,
#        4.44599333e+03, 3.18019688e+06, 1.92390372e+06, 2.93474856e+06,
#        1.92882118e+06, 2.17977983e+06, 2.15948367e+04, 1.29967333e+03,
#        3.28331233e+04, 6.82160000e+02, 9.15074830e+05, 1.83428483e+05,
#        2.76173406e+06, 8.25968200e+05, 1.41813257e+05, 6.81546667e+02,
#        1.58190981e+06, 2.49652567e+04, 6.64543333e+02, 4.57946667e+03,
#        2.17091213e+05, 2.70879024e+06, 1.64686904e+06, 1.27141257e+05,
#        9.91135333e+03, 3.25553333e+02, 6.77323333e+02, 9.99896117e+05,
#        2.44863633e+04, 2.12578334e+06, 6.58209333e+03, 1.27417313e+06,
#        2.24633023e+05, 7.16773333e+03, 4.01650000e+02, 8.60017000e+03,
#        9.04382800e+04, 3.30943333e+02, 2.76343333e+02, 5.20069667e+03,
#        1.87969113e+05, 1.00914000e+03, 1.45449000e+03])

# %% [markdown]
# ## LGBM
#
# => 1480188.794477261

# %%
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
k_fold = KFold(n_splits=10, shuffle=True, random_state = 777)

model = lgb.LGBMRegressor(random_state = 777, n_estimators=10000)
X_train, X_test, Y_train = df.drop(['box_off_num'], axis=1), testdf, df['box_off_num']


params = {
    'learning_rate' : [0.001, 0.0001, 0.00001],
    'min_child_samples' : [20, 30]}

gs = GridSearchCV(estimator=model,
                 param_grid = params,
                 scoring=rmse_score,
                 cv=k_fold)

# %%
gs.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=777, shuffle=True),
#              error_score=nan,
#              estimator=LGBMRegressor(boosting_type='gbdt', class_weight=None,
#                                      colsample_bytree=1.0,
#                                      importance_type='split', learning_rate=0.1,
#                                      max_depth=-1, min_child_samples=20,
#                                      min_child_weight=0.001, min_split_gain=0.0,
#                                      n_estimators=10000, n_jobs=-1,
#                                      num_leaves=31, objective=None,
#                                      random_state=777, reg_alpha=0.0,
#                                      reg_lambda=0.0, silent=True, subsample=1.0,
#                                      subsample_for_bin=200000,
#                                      subsample_freq=0),
#              iid='deprecated', n_jobs=None,
#              param_grid={'learning_rate': [0.001, 0.0001, 1e-05],
#                          'min_child_samples': [20, 30]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=make_scorer(rmse), verbose=0)

# %%
gs.best_params_
# Out:
# {'learning_rate': 1e-05, 'min_child_samples': 30}

# %%
model = lgb.LGBMRegressor(random_state = 777, n_estimators=10000, learning_rate= 1e-05, min_child_samples= 30)
models = []
for train_idx, val_idx in k_fold.split(X_train) :
    x_t = X_train.iloc[train_idx]
    y_t = Y_train.iloc[train_idx]
    x_val = X_train.iloc[val_idx]
    y_val = Y_train.iloc[val_idx]
    
    models.append(model.fit(x_t, y_t, eval_set = (x_val, y_val), early_stopping_rounds=1000, verbose=100))
# Out:
# Training until validation scores don't improve for 1000 rounds
# [100]	valid_0's l2: 4.39233e+12
# [200]	valid_0's l2: 4.39124e+12
# [300]	valid_0's l2: 4.39015e+12
# [400]	valid_0's l2: 4.38906e+12
# [500]	valid_0's l2: 4.38798e+12
# [600]	valid_0's l2: 4.3869e+12
# [700]	valid_0's l2: 4.38582e+12
# [800]	valid_0's l2: 4.38474e+12
# [900]	valid_0's l2: 4.38367e+12
# [1000]	valid_0's l2: 4.3826e+12
# [1100]	valid_0's l2: 4.38153e+12
# [1200]	valid_0's l2: 4.38047e+12
# [1300]	valid_0's l2: 4.37941e+12
# [1400]	valid_0's l2: 4.37835e+12
# [1500]	valid_0's l2: 4.37729e+12
# [1600]	valid_0's l2: 4.37623e+12
# [1700]	valid_0's l2: 4.37518e+12
# [1800]	valid_0's l2: 4.37413e+12
# [1900]	valid_0's l2: 4.37308e+12
# [2000]	valid_0's l2: 4.37204e+12
# [2100]	valid_0's l2: 4.37099e+12
# [2200]	valid_0's l2: 4.36995e+12
# [2300]	valid_0's l2: 4.36892e+12
# [2400]	valid_0's l2: 4.36788e+12
# [2500]	valid_0's l2: 4.36685e+12
# [2600]	valid_0's l2: 4.36578e+12
# [2700]	valid_0's l2: 4.36472e+12
# [2800]	valid_0's l2: 4.36366e+12
# [2900]	valid_0's l2: 4.36261e+12
# [3000]	valid_0's l2: 4.36155e+12
+12
# Did not meet early stopping. Best iteration is:
# [10000]	valid_0's l2: 4.30591e+12
# Training until validation scores don't improve for 1000 rounds
# [100]	valid_0's l2: 1.19178e+12
# [200]	valid_0's l2: 1.19058e+12
# [300]	valid_0's l2: 1.18938e+12
# [400]	valid_0's l2: 1.18819e+12
# [500]	valid_0's l2: 1.187e+12
# [600]	valid_0's l2: 1.18581e+12
# [700]	valid_0's l2: 1.18462e+12
# [800]	valid_0's l2: 1.18344e+12
# [900]	valid_0's l2: 1.18226e+12
# [1000]	valid_0's l2: 1.18109e+12
# [1100]	valid_0's l2: 1.17992e+12
# [1200]	valid_0's l2: 1.17875e+12
# [1300]	valid_0's l2: 1.17759e+12
# [1400]	valid_0's l2: 1.17642e+12
# [1500]	valid_0's l2: 1.17527e+12
# [1600]	valid_0's l2: 1.17411e+12
# [1700]	valid_0's l2: 1.17296e+12
# [1800]	valid_0's l2: 1.17181e+12
# [1900]	valid_0's l2: 1.17067e+12
# [2000]	valid_0's l2: 1.16953e+12
# [2100]	valid_0's l2: 1.16839e+12
# [2200]	valid_0's l2: 1.16726e+12
# [2300]	valid_0's l2: 1.16613e+12
# [2400]	valid_0's l2: 1.165e+12
# [2500]	valid_0's l2: 1.16388e+12
# [2600]	valid_0's l2: 1.16276e+12
# [2700]	valid_0's l2: 1.16164e+12
# [2800]	valid_0's l2: 1.16053e+12
# [2900]	valid_0's l2: 1.15942e+12
# [3000]	valid_0's l2: 1.15831e+12
# [3100]	valid_0's l2: 1.1572e+12
# [3200]	valid_0's l2: 1.1561e+12
# [3300]	valid_0's l2: 1.15501e+12
# [3400]	valid_0's l2: 1.15391e+12
# [3500]	valid_0's l2: 1.15282e+12
# [3600]	valid_0's l2: 1.15173e+12
# [3700]	valid_0's l2: 1.15065e+12
# [3800]	valid_0's l2: 1.14957e+12
# [3900]	valid_0's l2: 1.14849e+12
# [4000]	valid_0's l2: 1.14741e+12
# [4100]	valid_0's l2: 1.14634e+12
# [4200]	valid_0's l2: 1.14527e+12
# [4300]	valid_0's l2: 1.14421e+12
# [4400]	valid_0's l2: 1.14315e+12
# [4500]	valid_0's l2: 1.14209e+12
# [4600]	valid_0's l2: 1.14103e+12
# [4700]	valid_0's l2: 1.13998e+12
# [4800]	valid_0's l2: 1.13893e+12
# [4900]	valid_0's l2: 1.13788e+12
# [5000]	valid_0's l2: 1.13684e+12
# [5100]	valid_0's l2: 1.1358e+12
# [5200]	valid_0's l2: 1.13476e+12
# [5300]	valid_0's l2: 1.13373e+12
# [5400]	valid_0's l2: 1.1327e+12
# [5500]	valid_0's l2: 1.13167e+12
# [5600]	valid_0's l2: 1.13064e+12
# [5700]	valid_0's l2: 1.12962e+12
# [5800]	valid_0's l2: 1.1286e+12
# [5900]	valid_0's l2: 1.12759e+12
# [6000]	valid_0's l2: 1.12658e+12
# [6100]	valid_0's l2: 1.12557e+12
# [6200]	valid_0's l2: 1.12456e+12
# [6300]	valid_0's l2: 1.12356e+12
# [6400]	valid_0's l2: 1.12256e+12
# [6500]	valid_0's l2: 1.12156e+12
# [6600]	valid_0's l2: 1.12057e+12
# [6700]	valid_0's l2: 1.11958e+12
# [6800]	valid_0's l2: 1.11859e+12
# [6900]	valid_0's l2: 1.1176e+12
# [7000]	valid_0's l2: 1.11662e+12
# [7100]	valid_0's l2: 1.11564e+12
# [7200]	valid_0's l2: 1.11466e+12
# [7300]	valid_0's l2: 1.11369e+12
# [7400]	valid_0's l2: 1.11272e+12
# [7500]	valid_0's l2: 1.11176e+12
# [7600]	valid_0's l2: 1.11083e+12
# [7700]	valid_0's l2: 1.1099e+12
# [7800]	valid_0's l2: 1.10897e+12
# [7900]	valid_0's l2: 1.10805e+12
# [8000]	valid_0's l2: 1.10713e+12
# [8100]	valid_0's l2: 1.10622e+12
# [8200]	valid_0's l2: 1.1053e+12
# [8300]	valid_0's l2: 1.10439e+12
# [8400]	valid_0's l2: 1.10348e+12
# [8500]	valid_0's l2: 1.10258e+12
# [8600]	valid_0's l2: 1.10167e+12
# [8700]	valid_0's l2: 1.10077e+12
# [8800]	valid_0's l2: 1.09988e+12
# [8900]	valid_0's l2: 1.09898e+12
# [9000]	valid_0's l2: 1.09809e+12
# [9100]	valid_0's l2: 1.0972e+12
# [9200]	valid_0's l2: 1.09631e+12
# [9300]	valid_0's l2: 1.09543e+12
# [9400]	valid_0's l2: 1.09454e+12
# [9500]	valid_0's l2: 1.09367e+12
# [9600]	valid_0's l2: 1.09279e+12
# [9700]	valid_0's l2: 1.09192e+12
# [9800]	valid_0's l2: 1.09104e+12
# [9900]	valid_0's l2: 1.09018e+12
# [10000]	valid_0's l2: 1.08931e+12
# Did not meet early stopping. Best iteration is:
# [10000]	valid_0's l2: 1.08931e+12
# Training until validation scores don't improve for 1000 rounds
# [100]	valid_0's l2: 5.55181e+12
# [200]	valid_0's l2: 5.55025e+12
# [300]	valid_0's l2: 5.5487e+12
# [400]	valid_0's l2: 5.54696e+12
# [500]	valid_0's l2: 5.54502e+12
# [600]	valid_0's l2: 5.54307e+12
# [700]	valid_0's l2: 5.54113e+12
# [800]	valid_0's l2: 5.5392e+12
# [900]	valid_0's l2: 5.53727e+12
# [1000]	valid_0's l2: 5.53534e+12
# [1100]	valid_0's l2: 5.53341e+12
# [1200]	valid_0's l2: 5.53149e+12
# [1300]	valid_0's l2: 5.52957e+12
# [1400]	valid_0's l2: 5.52766e+12
# [1500]	valid_0's l2: 5.52575e+12
# [1600]	valid_0's l2: 5.52384e+12
# [1700]	valid_0's l2: 5.52193e+12
# [1800]	valid_0's l2: 5.52003e+12
# [1900]	valid_0's l2: 5.51813e+12
# [2000]	valid_0's l2: 5.51624e+12
# [2100]	valid_0's l2: 5.51436e+12
# [2200]	valid_0's l2: 5.51247e+12
# [2300]	valid_0's l2: 5.51059e+12
# [2400]	valid_0's l2: 5.50871e+12
# [2500]	valid_0's l2: 5.50684e+12
# [2600]	valid_0's l2: 5.50497e+12
# [2700]	valid_0's l2: 5.5031e+12
# [2800]	valid_0's l2: 5.50124e+12
# [2900]	valid_0's l2: 5.49938e+12
# [3000]	valid_0's l2: 5.49752e+12
# [3100]	valid_0's l2: 5.49566e+12
# [3200]	valid_0's l2: 5.49381e+12
# [3300]	valid_0's l2: 5.49196e+12
# [3400]	valid_0's l2: 5.49012e+12
# [4300]	valid_0's l2: 2.09193e+12
# [4400]	valid_0's l2: 2.09058e+12
# [4500]	valid_0's l2: 2.08922e+12
# [4600]	valid_0's l2: 2.08787e+12
# [4700]	valid_0's l2: 2.08653e+12
# [4800]	valid_0's l2: 2.08519e+12
# [4900]	valid_0's l2: 2.08385e+12
# [5000]	valid_0's l2: 2.08252e+12
# [5100]	valid_0's l2: 2.08118e+12
# [5200]	valid_0's l2: 2.07986e+12
# [5300]	valid_0's l2: 2.07854e+12
# [5400]	valid_0's l2: 2.07722e+12
# [5500]	valid_0's l2: 2.0759e+12
# [5600]	valid_0's l2: 2.07459e+12
# [5700]	valid_0's l2: 2.07328e+12
# [5800]	valid_0's l2: 2.07198e+12
# [5900]	valid_0's l2: 2.07068e+12
# [6000]	valid_0's l2: 2.06938e+12
# [6100]	valid_0's l2: 2.06809e+12
# [6200]	valid_0's l2: 2.0668e+12
# [6300]	valid_0's l2: 2.06552e+12
# [6400]	valid_0's l2: 2.06424e+12
# [6500]	valid_0's l2: 2.06296e+12
# [6600]	valid_0's l2: 2.06169e+12
# [6700]	valid_0's l2: 2.06042e+12
# [6800]	valid_0's l2: 2.05915e+12
# [6900]	valid_0's l2: 2.05789e+12
# [7000]	valid_0's l2: 2.05663e+12
# [7100]	valid_0's l2: 2.05537e+12
# [7200]	valid_0's l2: 2.05412e+12
# [7300]	valid_0's l2: 2.05287e+12
# [7400]	valid_0's l2: 2.05163e+12
# [7500]	valid_0's l2: 2.05039e+12
# [7600]	valid_0's l2: 2.04915e+12
# [7700]	valid_0's l2: 2.04792e+12
# [7800]	valid_0's l2: 2.04669e+12
# [7900]	valid_0's l2: 2.04546e+12
# [8000]	valid_0's l2: 2.04424e+12
# [8100]	valid_0's l2: 2.04302e+12
# [8200]	valid_0's l2: 2.0418e+12
# [8300]	valid_0's l2: 2.04059e+12
# [8400]	valid_0's l2: 2.03938e+12
# [8500]	valid_0's l2: 2.03818e+12
# [8600]	valid_0's l2: 2.03697e+12
# [8700]	valid_0's l2: 2.03578e+12
# [8800]	valid_0's l2: 2.03458e+12
# [8900]	valid_0's l2: 2.03339e+12
# [9000]	valid_0's l2: 2.03218e+12
# [9100]	valid_0's l2: 2.03096e+12
# [9200]	valid_0's l2: 2.02976e+12
# [9300]	valid_0's l2: 2.02855e+12
# [9400]	valid_0's l2: 2.02735e+12
# [9500]	valid_0's l2: 2.02615e+12
# [9600]	valid_0's l2: 2.02496e+12
# [9700]	valid_0's l2: 2.02377e+12
# [9800]	valid_0's l2: 2.02258e+12
# [9900]	valid_0's l2: 2.0214e+12
# [10000]	valid_0's l2: 2.02022e+12
# Did not meet early stopping. Best iteration is:
# [10000]	valid_0's l2: 2.02022e+12
# Training until validation scores don't improve for 1000 rounds
# [100]	valid_0's l2: 1.96475e+12
# [200]	valid_0's l2: 1.96292e+12
# [300]	valid_0's l2: 1.96109e+12
# [400]	valid_0's l2: 1.95927e+12
# [500]	valid_0's l2: 1.95745e+12
# [600]	valid_0's l2: 1.95564e+12
# [700]	valid_0's l2: 1.95382e+12
# [800]	valid_0's l2: 1.95202e+12
# [900]	valid_0's l2: 1.95021e+12
# [1000]	valid_0's l2: 1.94842e+12
# [1100]	valid_0's l2: 1.94662e+12
# [1200]	valid_0's l2: 1.94483e+12
# [1300]	valid_0's l2: 1.94304e+12
# [1400]	valid_0's l2: 1.94126e+12
# [1500]	valid_0's l2: 1.93948e+12
# [1600]	valid_0's l2: 1.93771e+12
# [1700]	valid_0's l2: 1.93594e+12
# [1800]	valid_0's l2: 1.93417e+12
# [1900]	valid_0's l2: 1.9324e+12
# [2000]	valid_0's l2: 1.93065e+12
# [2100]	valid_0's l2: 1.92889e+12
# [2200]	valid_0's l2: 1.92714e+12
# [2300]	valid_0's l2: 1.92539e+12
# [2400]	valid_0's l2: 1.92365e+12
# [2500]	valid_0's l2: 1.92191e+12
# [2600]	valid_0's l2: 1.92017e+12
# [2700]	valid_0's l2: 1.91844e+12
# [2800]	valid_0's l2: 1.91671e+12
# [2900]	valid_0's l2: 1.91498e+12
# [3000]	valid_0's l2: 1.91326e+12
# [3100]	valid_0's l2: 1.91155e+12
# [3200]	valid_0's l2: 1.90983e+12
# [3300]	valid_0's l2: 1.90812e+12
# [3400]	valid_0's l2: 1.90642e+12
# [3500]	valid_0's l2: 1.90472e+12
# [3600]	valid_0's l2: 1.90302e+12
# [3700]	valid_0's l2: 1.90132e+12
# [3800]	valid_0's l2: 1.89963e+12
# [3900]	valid_0's l2: 1.89795e+12
# [4000]	valid_0's l2: 1.89626e+12
# [4100]	valid_0's l2: 1.89458e+12
# [4200]	valid_0's l2: 1.89291e+12
# [4300]	valid_0's l2: 1.89124e+12
# [4400]	valid_0's l2: 1.8896e+12
# [4500]	valid_0's l2: 1.88797e+12
# [4600]	valid_0's l2: 1.88635e+12
# [4700]	valid_0's l2: 1.88473e+12
# [4800]	valid_0's l2: 1.88312e+12
# [4900]	valid_0's l2: 1.88151e+12
# [5000]	valid_0's l2: 1.8799e+12
# [5100]	valid_0's l2: 1.87829e+12
# [5200]	valid_0's l2: 1.87669e+12
# [5300]	valid_0's l2: 1.87509e+12
# [5400]	valid_0's l2: 1.8735e+12
# [5500]	valid_0's l2: 1.8719e+12
# [5600]	valid_0's l2: 1.87032e+12
# [5700]	valid_0's l2: 1.86873e+12
# [5800]	valid_0's l2: 1.86715e+12
# [5900]	valid_0's l2: 1.86557e+12
# [6000]	valid_0's l2: 1.864e+12
# [6100]	valid_0's l2: 1.86243e+12
# [6200]	valid_0's l2: 1.86086e+12
# [6300]	valid_0's l2: 1.8593e+12
# [6400]	valid_0's l2: 1.85773e+12
# [6500]	valid_0's l2: 1.85618e+12
# [6600]	valid_0's l2: 1.85462e+12
# [6700]	valid_0's l2: 1.85307e+12
# [6800]	valid_0's l2: 1.85152e+12
# [6900]	valid_0's l2: 1.84998e+12
# [7000]	valid_0's l2: 1.84844e+12
# [7100]	valid_0's l2: 1.8469e+12
# [7200]	valid_0's l2: 1.84537e+12
# [7300]	valid_0's l2: 1.84384e+12
# [7400]	valid_0's l2: 1.84231e+12
# [7500]	valid_0's l2: 1.84078e+12
# [7600]	valid_0's l2: 1.83926e+12
# [7700]	valid_0's l2: 1.83775e+12
#        625999.87401811, 903540.89438826, 625676.61787807, 630908.00879904,
#        625556.93486383, 672319.21502713, 757723.25541921, 627269.50418685,
#        625556.93486383, 625808.53751061, 625686.41850523, 627269.50418685,
#        635621.02988268, 626110.17356157, 625556.93486383, 757723.25541921,
#        625686.34886862, 625808.53751061, 905222.17818192, 905222.17818192,
#        625808.53751061, 757723.25541921, 757723.25541921, 625556.93486383,
#        625808.60714722, 851788.03603721, 905222.17818192, 635820.24005134,
#        625808.60714722, 691239.28514796, 626110.17356157, 626110.17356157,
#        904377.21559647, 904369.09662944, 625999.87401811, 625999.87401811,
#        625556.93486383, 625999.87401811, 627251.25526062, 692166.94831261,
#        625808.60714722, 627269.50418685, 956105.19463622, 956105.19463622,
#        691239.28514796, 956958.27618871, 672319.21502713, 672319.21502713,
#        627269.50418685, 625808.60714722, 956105.19463622, 625556.93486383,
#        625674.8463197 , 625998.10245973, 627251.25526062, 627251.25526062,
#        635577.638794  , 625556.93486383, 627289.84345835, 635820.24005134,
#        625556.93486383, 627269.50418685, 956958.27618871, 956958.27618871,
#        635621.02988268, 625808.60714722, 625674.8463197 , 635820.24005134,
#        956958.27618871, 626110.17356157, 625998.10245973, 635577.638794  ,
#        625806.83558885, 692166.94831261, 630926.25772527, 625674.8463197 ,
#        625806.83558885, 625674.8463197 , 625808.60714722, 956958.27618871,
#        626110.17356157, 692166.94831261, 625808.60714722, 904369.09662944,
#        625556.93486383, 630926.25772527, 625560.00726256, 625999.87401811,
#        627289.84345835, 672319.21502713, 903524.13404399, 852641.11758969,
#        625999.87401811, 905222.17818192, 627251.25526062, 851788.03603721,
#        903524.13404399, 691239.28514796, 627269.50418685, 625556.93486383,
#        903524.13404399, 627269.50418685, 625560.00726256, 625998.10245973,
#        627251.25526062, 903524.13404399, 757723.25541921, 627289.84345835,
#        630926.25772527, 625556.93486383, 625556.93486383, 693020.0298651 ,
#        630926.25772527, 956958.27618871, 625998.10245973, 692166.94831261,
#        630946.59699677, 626110.17356157, 625556.93486383, 626110.17356157,
#        635577.41282796, 625556.93486383, 625556.93486383, 626110.17356157,
#        691239.28514796, 625556.93486383, 625806.83558885])

# %% [markdown]
# ## sklearn_RandomForestRegressor
# + RMSE + Hyper Parameter Tuning
#
# * cv = 20 : 1460717.170338258
# * cv = 35 : 1454429.7489887767	(genre_mapping)
# * 전처리 변경 후  : 1485610.1551896033
# * cv = 19 : 1490913.1161172627
# * cv = 19 : 1455667.9935786778 (genre_get_dummies)
# * cv = 35 : 1469407.8483563093	(genre_get_dummies)
# * cv = 40 :  ????  (genre_mapping)

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators=300,
                              n_jobs=-1,
                              random_state=37)

X_train, X_test, Y_train = df.drop(['box_off_num'], axis=1), testdf, df['box_off_num']

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

n_estimators = 300

# 랜덤 서치 횟수
num_epoch = 100

# hyperparameter 탐색 결과가 저장될 리스트
coarse_hyperparameters_list = []

for epoch in range(num_epoch):
    # max depth의 값을 2~100으로 설정
    max_depth = np.random.randint(low=2, high=100)

    # 적용할 feature의 비율을 0.1~1.0로 설정
    max_features = np.random.uniform(low=0.1, high=1.0)

    model = RandomForestRegressor(n_estimators=n_estimators,
                                  max_depth=max_depth,
                                  max_features=max_features,
                                  n_jobs=-1,
                                  random_state=37)

    # cross_val_score를 실행하여 rmse의 평균 계산
    # cv는 데이터 조각 개수
    score = cross_val_score(model, X_train, Y_train, cv=19, scoring=rmse_score).mean() 
    
    # hyperparameter 탐색 결과를 저장할 딕셔너리
    hyperparameters = {
        'epoch': epoch,
        'score': score,
        'n_estimators': n_estimators,
        'max_depth': max_depth,
        'max_features': max_features,
        
    }

    # hyperparameter 탐색 결과 저장
    coarse_hyperparameters_list.append(hyperparameters)

    # hyperparameter 탐색 결과를 출력
    print(f"{epoch:2} n_estimators = {n_estimators}, max_depth = {max_depth:2}, max_features = {max_features:.6f}, Score = {score:.5f}")

# coarse_hyperparameters_list를 DataFrame으로 변환
coarse_hyperparameters_list = pd.DataFrame.from_dict(coarse_hyperparameters_list)

# coarse_hyperparameters_list를 score가 낮은 순으로 정렬
coarse_hyperparameters_list = coarse_hyperparameters_list.sort_values(by="score")

print(coarse_hyperparameters_list.shape)

# coarse_hyperparameters_list의 상위 10개 출력
coarse_hyperparameters_list.head(10)
# Out:
#  0 n_estimators = 300, max_depth = 20, max_features = 0.142193, Score = 1345468.26286
#  1 n_estimators = 300, max_depth =  8, max_features = 0.514011, Score = 1384029.54322
#  2 n_estimators = 300, max_depth = 47, max_features = 0.932290, Score = 1427875.30536
#  3 n_estimators = 300, max_depth = 81, max_features = 0.432295, Score = 1390614.60349
#  4 n_estimators = 300, max_depth = 69, max_features = 0.531131, Score = 1389334.55699
#  5 n_estimators = 300, max_depth = 88, max_features = 0.674587, Score = 1410988.37487
#  6 n_estimators = 300, max_depth = 13, max_features = 0.542204, Score = 1385069.56721
#  7 n_estimators = 300, max_depth = 77, max_features = 0.746038, Score = 1411864.02073
#  8 n_estimators = 300, max_depth = 50, max_features = 0.505160, Score = 1389334.55699
#  9 n_estimators = 300, max_depth = 21, max_features = 0.741678, Score = 1412884.50019
# 10 n_estimators = 300, max_depth = 68, max_features = 0.746141, Score = 1411864.02073
# 11 n_estimators = 300, max_depth = 78, max_features = 0.799496, Score = 1426182.36537
# 12 n_estimators = 300, max_depth = 43, max_features = 0.525033, Score = 1389334.55699
# 13 n_estimators = 300, max_depth = 23, max_features = 0.715804, Score = 1406893.02857
# 14 n_estimators = 300, max_depth = 73, max_features = 0.346489, Score = 1367510.36325
# 15 n_estimators = 300, max_depth = 82, max_features = 0.359725, Score = 1367510.36325
# 16 n_estimators = 300, max_depth = 24, max_features = 0.323348, Score = 1365831.95988
# 17 n_estimators = 300, max_depth = 73, max_features = 0.985931, Score = 1431803.59253
# 18 n_estimators = 300, max_depth = 69, max_features = 0.480167, Score = 1370016.76218
# 19 n_estimators = 300, max_depth = 36, max_features = 0.226727, Score = 1355611.45489
# 20 n_estimators = 300, max_depth = 37, max_features = 0.735303, Score = 1411864.02073
# 21 n_estimators = 300, max_depth = 63, max_features = 0.569941, Score = 1391447.64885
# 22 n_estimators = 300, max_depth = 77, max_features = 0.749336, Score = 1411864.02073
# 23 n_estimators = 300, max_depth = 62, max_features = 0.362730, Score = 1367510.36325
# 24 n_estimators = 300, max_depth = 72, max_features = 0.574366, Score = 1391447.64885
# 25 n_estimators = 300, max_depth = 16, max_features = 0.863316, Score = 1427872.04372
# 26 n_estimators = 300, max_depth = 28, max_features = 0.203734, Score = 1355911.84798
# 27 n_estimators = 300, max_depth = 79, max_features = 0.148817, Score = 1346328.86639
# 28 n_estimators = 300, max_depth = 80, max_features = 0.948331, Score = 1427875.30536
# 29 n_estimators = 300, max_depth = 19, max_features = 0.837190, Score = 1421290.07019
# 30 n_estimators = 300, max_depth = 99, max_features = 0.436659, Score = 1390614.60349
# 31 n_estimators = 300, max_depth = 41, max_features = 0.578118, Score = 1391447.64885
# 32 n_estimators = 300, max_depth = 38, max_features = 0.905585, Score = 1422269.00531
# 33 n_estimators = 300, max_depth = 42, max_features = 0.571906, Score = 1391447.64885
# 34 n_estimators = 300, max_depth = 85, max_features = 0.302175, Score = 1356342.73923
# 35 n_estimators = 300, max_depth = 57, max_features = 0.883779, Score = 1422269.00531
# 36 n_estimators = 300, max_depth = 97, max_features = 0.752607, Score = 1411864.02073
# 37 n_estimators = 300, max_depth = 99, max_features = 0.702977, Score = 1403339.77633
# 38 n_estimators = 300, max_depth = 49, max_features = 0.450549, Score = 1390614.60349
# 39 n_estimators = 300, max_depth =  6, max_features = 0.602739, Score = 1379320.06826
# 40 n_estimators = 300, max_depth = 92, max_features = 0.207201, Score = 1355611.45489
# 41 n_estimators = 300, max_depth = 82, max_features = 0.177322, Score = 1346328.86639
# 42 n_estimators = 300, max_depth = 37, max_features = 0.257618, Score = 1346319.74140
# 43 n_estimators = 300, max_depth = 92, max_features = 0.488667, Score = 1370016.76218
# 44 n_estimators = 300, max_depth = 37, max_features = 0.798714, Score = 1426182.36537
# 45 n_estimators = 300, max_depth = 13, max_features = 0.365396, Score = 1361685.29693
# 46 n_estimators = 300, max_depth = 93, max_features = 0.864756, Score = 1422269.00531
# 47 n_estimators = 300, max_depth = 77, max_features = 0.823851, Score = 1427401.08585
# 48 n_estimators = 300, max_depth = 68, max_features = 0.450687, Score = 1390614.60349
# 49 n_estimators = 300, max_depth = 98, max_features = 0.605087, Score = 1404755.29071
# 50 n_estimators = 300, max_depth = 19, max_features = 0.578581, Score = 1407675.85178
# 51 n_estimators = 300, max_depth = 11, max_features = 0.896574, Score = 1419657.43787
# 52 n_estimators = 300, max_depth = 79, max_features = 0.733768, Score = 1411864.02073
# 53 n_estimators = 300, max_depth = 18, max_features = 0.239745, Score = 1346815.24059
# 54 n_estimators = 300, max_depth =  5, max_features = 0.383645, Score = 1328846.34013
# 55 n_estimators = 300, max_depth = 59, max_features = 0.847269, Score = 1427401.08585
# 56 n_estimators = 300, max_depth =  2, max_features = 0.546270, Score = 1326381.46558
# 57 n_estimators = 300, max_depth = 97, max_features = 0.231642, Score = 1346319.74140
# 58 n_estimators = 300, max_depth = 99, max_features = 0.270114, Score = 1346319.74140
# 59 n_estimators = 300, max_depth = 76, max_features = 0.877932, Score = 1422269.00531
# 60 n_estimators = 300, max_depth = 16, max_features = 0.163428, Score = 1347362.28215
# 61 n_estimators = 300, max_depth = 80, max_features = 0.733466, Score = 1411864.02073
# 62 n_estimators = 300, max_depth =  6, max_features = 0.480454, Score = 1348582.94125
# 63 n_estimators = 300, max_depth =  4, max_features = 0.711754, Score = 1346477.59764
# 64 n_estimators = 300, max_depth = 30, max_features = 0.948169, Score = 1427903.26133
# 65 n_estimators = 300, max_depth = 75, max_features = 0.836815, Score = 1427401.08585
# 66 n_estimators = 300, max_depth = 67, max_features = 0.407905, Score = 1365991.53433
# 67 n_estimators = 300, max_depth = 76, max_features = 0.289981, Score = 1356342.73923
# 68 n_estimators = 300, max_depth = 19, max_features = 0.960148, Score = 1438357.98164
# 69 n_estimators = 300, max_depth = 90, max_features = 0.297176, Score = 1356342.73923
# 70 n_estimators = 300, max_depth = 93, max_features = 0.443538, Score = 1390614.60349
# 71 n_estimators = 300, max_depth = 78, max_features = 0.199797, Score = 1355611.45489
# 72 n_estimators = 300, max_depth =  8, max_features = 0.371325, Score = 1355346.38847
# 73 n_estimators = 300, max_depth = 98, max_features = 0.831253, Score = 1427401.08585
# 74 n_estimators = 300, max_depth =  3, max_features = 0.536830, Score = 1323758.86591
# 75 n_estimators = 300, max_depth = 34, max_features = 0.437116, Score = 1390614.60349
# 76 n_estimators = 300, max_depth = 73, max_features = 0.659026, Score = 1410988.37487
# 77 n_estimators = 300, max_depth = 99, max_features = 0.800752, Score = 1426182.36537
# 78 n_estimators = 300, max_depth = 38, max_features = 0.485745, Score = 1370016.76218
# 79 n_estimators = 300, max_depth = 35, max_features = 0.866701, Score = 1422269.00531
# 80 n_estimators = 300, max_depth = 63, max_features = 0.952135, Score = 1427875.30536
# 81 n_estimators = 300, max_depth =  3, max_features = 0.209064, Score = 1338453.47394
# 82 n_estimators = 300, max_depth = 64, max_features = 0.947746, Score = 1427875.30536
# 83 n_estimators = 300, max_depth = 36, max_features = 0.805452, Score = 1426182.36537
# 84 n_estimators = 300, max_depth = 76, max_features = 0.492788, Score = 1370016.76218
# 85 n_estimators = 300, max_depth = 98, max_features = 0.813475, Score = 1426182.36537
# 86 n_estimators = 300, max_depth = 79, max_features = 0.349797, Score = 1367510.36325
# 87 n_estimators = 300, max_depth = 79, max_features = 0.106183, Score = 1343836.72691
# 88 n_estimators = 300, max_depth = 26, max_features = 0.313245, Score = 1356548.07122
# 89 n_estimators = 300, max_depth = 71, max_features = 0.832816, Score = 1427401.08585
# 90 n_estimators = 300, max_depth = 38, max_features = 0.870548, Score = 1422269.00531
# 91 n_estimators = 300, max_depth = 17, max_features = 0.164100, Score = 1346590.98108
# 92 n_estimators = 300, max_depth = 84, max_features = 0.246933, Score = 1346319.74140
# 93 n_estimators = 300, max_depth = 41, max_features = 0.626239, Score = 1404755.29071
# 94 n_estimators = 300, max_depth = 95, max_features = 0.603372, Score = 1404755.29071
# 95 n_estimators = 300, max_depth = 89, max_features = 0.249919, Score = 1346319.74140
# 96 n_estimators = 300, max_depth = 83, max_features = 0.841970, Score = 1427401.08585
# 97 n_estimators = 300, max_depth = 82, max_features = 0.333402, Score = 1367510.36325
# 98 n_estimators = 300, max_depth =  3, max_features = 0.436041, Score = 1315473.22835
# 99 n_estimators = 300, max_depth = 63, max_features = 0.730660, Score = 1411864.02073
# (100, 5)
#     epoch         score  n_estimators  max_depth  max_features
# 98     98 1315473.22835           300          3       0.43604
# 74     74 1323758.86591           300          3       0.53683
# 56     56 1326381.46558           300          2       0.54627
# 54     54 1328846.34013           300          5       0.38365
# 81     81 1338453.47394           300          3       0.20906
# 87     87 1343836.72691           300         79       0.10618
# 0       0 1345468.26286           300         20       0.14219
# 42     42 1346319.74140           300         37       0.25762
# 57     57 1346319.74140           300         97       0.23164
# 92     92 1346319.74140           300         84       0.24693

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

n_estimators = 300
num_epoch = 100
finer_hyperparameters_list = []

for epoch in range(num_epoch):
    # coarse 단계에서 찾은 뎁스와 피쳐비율 구간을 적용
    max_depth = np.random.randint(low=5, high=35)
    max_features = np.random.uniform(low=0.1, high=0.3)
    
    model = RandomForestRegressor(n_estimators=n_estimators,
                                  max_depth=max_depth,
                                  max_features=max_features,
                                  n_jobs=-1,
                                  random_state=37)

    score = cross_val_score(model, X_train, Y_train, cv=19, scoring=rmse_score).mean()
    hyperparameters = {
        'epoch': epoch,
        'score': score,
        'n_estimators': n_estimators,
        'max_depth': max_depth,
        'max_features': max_features,
    }

    finer_hyperparameters_list.append(hyperparameters)
    print(f"{epoch:2} n_estimators = {n_estimators}, max_depth = {max_depth:2}, max_features = {max_features:.6f}, Score = {score:.5f}")

finer_hyperparameters_list = pd.DataFrame.from_dict(finer_hyperparameters_list)
finer_hyperparameters_list = finer_hyperparameters_list.sort_values(by="score")
print(finer_hyperparameters_list.shape)

finer_hyperparameters_list.head(10)
# Out:
#  0 n_estimators = 300, max_depth = 18, max_features = 0.123752, Score = 1343826.82958
#  1 n_estimators = 300, max_depth = 20, max_features = 0.234689, Score = 1353111.09913
#  2 n_estimators = 300, max_depth = 19, max_features = 0.111767, Score = 1351791.72276
#  3 n_estimators = 300, max_depth = 23, max_features = 0.177865, Score = 1344626.71751
#  4 n_estimators = 300, max_depth = 19, max_features = 0.127120, Score = 1351791.72276
#  5 n_estimators = 300, max_depth = 33, max_features = 0.224683, Score = 1355611.45489
#  6 n_estimators = 300, max_depth = 19, max_features = 0.193755, Score = 1356717.57267
#  7 n_estimators = 300, max_depth = 30, max_features = 0.120831, Score = 1343787.67248
#  8 n_estimators = 300, max_depth = 18, max_features = 0.166764, Score = 1341578.10647
#  9 n_estimators = 300, max_depth = 32, max_features = 0.270163, Score = 1346319.74140
# 10 n_estimators = 300, max_depth = 27, max_features = 0.271741, Score = 1345612.33417
# 11 n_estimators = 300, max_depth = 17, max_features = 0.219062, Score = 1342158.95610
# 12 n_estimators = 300, max_depth = 31, max_features = 0.276879, Score = 1356342.73923
# 13 n_estimators = 300, max_depth = 16, max_features = 0.284647, Score = 1356282.12863
# 14 n_estimators = 300, max_depth =  8, max_features = 0.221605, Score = 1335582.46846
# 15 n_estimators = 300, max_depth = 11, max_features = 0.282886, Score = 1350007.74541
# 16 n_estimators = 300, max_depth = 16, max_features = 0.112380, Score = 1352542.81481
# 17 n_estimators = 300, max_depth = 20, max_features = 0.283682, Score = 1364741.79950
# 18 n_estimators = 300, max_depth =  8, max_features = 0.118320, Score = 1328368.41923
# 19 n_estimators = 300, max_depth = 13, max_features = 0.200803, Score = 1333703.06870
# 20 n_estimators = 300, max_depth =  5, max_features = 0.127502, Score = 1338941.00873
# 21 n_estimators = 300, max_depth = 33, max_features = 0.281964, Score = 1356342.73923
# 22 n_estimators = 300, max_depth =  7, max_features = 0.151207, Score = 1320056.71719
# 23 n_estimators = 300, max_depth = 33, max_features = 0.270401, Score = 1346319.74140
# 24 n_estimators = 300, max_depth = 33, max_features = 0.138433, Score = 1346328.86639
# 25 n_estimators = 300, max_depth = 30, max_features = 0.121990, Score = 1343787.67248
# 26 n_estimators = 300, max_depth =  6, max_features = 0.192241, Score = 1320276.54908
# 27 n_estimators = 300, max_depth = 22, max_features = 0.124481, Score = 1349478.97017
# 28 n_estimators = 300, max_depth = 21, max_features = 0.173875, Score = 1341404.62864
# 29 n_estimators = 300, max_depth = 14, max_features = 0.105075, Score = 1337212.00931
# 30 n_estimators = 300, max_depth =  6, max_features = 0.240085, Score = 1328433.34271
# 31 n_estimators = 300, max_depth = 11, max_features = 0.287160, Score = 1350007.74541
# 32 n_estimators = 300, max_depth =  7, max_features = 0.254772, Score = 1325692.96845
# 33 n_estimators = 300, max_depth =  6, max_features = 0.204300, Score = 1320276.54908
# 34 n_estimators = 300, max_depth = 33, max_features = 0.282040, Score = 1356342.73923
# 35 n_estimators = 300, max_depth = 28, max_features = 0.239619, Score = 1345932.58345
# 36 n_estimators = 300, max_depth = 25, max_features = 0.178718, Score = 1347624.33920
# 37 n_estimators = 300, max_depth = 29, max_features = 0.255308, Score = 1345753.88928
# 38 n_estimators = 300, max_depth = 34, max_features = 0.135256, Score = 1343836.72691
# 39 n_estimators = 300, max_depth = 23, max_features = 0.259581, Score = 1345615.34710
# 40 n_estimators = 300, max_depth = 17, max_features = 0.137692, Score = 1346590.98108
# 41 n_estimators = 300, max_depth = 30, max_features = 0.104379, Score = 1343787.67248
# 42 n_estimators = 300, max_depth = 12, max_features = 0.180664, Score = 1340905.50714
# 43 n_estimators = 300, max_depth = 26, max_features = 0.187001, Score = 1356607.19219
# 44 n_estimators = 300, max_depth = 28, max_features = 0.180179, Score = 1346448.07476
# 45 n_estimators = 300, max_depth = 26, max_features = 0.245196, Score = 1345592.23996
# 46 n_estimators = 300, max_depth = 30, max_features = 0.108410, Score = 1343787.67248
# 47 n_estimators = 300, max_depth = 33, max_features = 0.251248, Score = 1346319.74140
# 48 n_estimators = 300, max_depth = 32, max_features = 0.166157, Score = 1346328.86639
# 49 n_estimators = 300, max_depth = 20, max_features = 0.181241, Score = 1345468.26286
# 50 n_estimators = 300, max_depth = 10, max_features = 0.161672, Score = 1336248.19525
# 51 n_estimators = 300, max_depth = 31, max_features = 0.272580, Score = 1346319.74140
# 52 n_estimators = 300, max_depth = 23, max_features = 0.185205, Score = 1359970.77280
# 53 n_estimators = 300, max_depth = 13, max_features = 0.211856, Score = 1333703.06870
# 54 n_estimators = 300, max_depth = 20, max_features = 0.247037, Score = 1353111.09913
# 55 n_estimators = 300, max_depth = 15, max_features = 0.276069, Score = 1345873.49304
# 56 n_estimators = 300, max_depth = 20, max_features = 0.216056, Score = 1347207.05202
# 57 n_estimators = 300, max_depth = 29, max_features = 0.278360, Score = 1356504.17238
# 58 n_estimators = 300, max_depth = 31, max_features = 0.234837, Score = 1346319.74140
# 59 n_estimators = 300, max_depth = 20, max_features = 0.276516, Score = 1364741.79950
# 60 n_estimators = 300, max_depth =  7, max_features = 0.153361, Score = 1320056.71719
# 61 n_estimators = 300, max_depth = 24, max_features = 0.277261, Score = 1360275.74841
# 62 n_estimators = 300, max_depth = 33, max_features = 0.239697, Score = 1346319.74140
# 63 n_estimators = 300, max_depth = 23, max_features = 0.233448, Score = 1345615.34710
# 64 n_estimators = 300, max_depth = 14, max_features = 0.183476, Score = 1340215.34727
# 65 n_estimators = 300, max_depth = 32, max_features = 0.195362, Score = 1355611.45489
# 66 n_estimators = 300, max_depth = 13, max_features = 0.276866, Score = 1353338.63917
# 67 n_estimators = 300, max_depth = 20, max_features = 0.160987, Score = 1345468.26286
# 68 n_estimators = 300, max_depth = 26, max_features = 0.275152, Score = 1356548.07122
# 69 n_estimators = 300, max_depth = 21, max_features = 0.207379, Score = 1351923.49409
# 70 n_estimators = 300, max_depth = 18, max_features = 0.146894, Score = 1341578.10647
# 71 n_estimators = 300, max_depth = 14, max_features = 0.230438, Score = 1351210.05746
# 72 n_estimators = 300, max_depth = 22, max_features = 0.122720, Score = 1349478.97017
# 73 n_estimators = 300, max_depth = 14, max_features = 0.167102, Score = 1343626.24296
# 74 n_estimators = 300, max_depth = 12, max_features = 0.258615, Score = 1345059.39724
# 75 n_estimators = 300, max_depth = 23, max_features = 0.216691, Score = 1359970.77280
# 76 n_estimators = 300, max_depth = 20, max_features = 0.285077, Score = 1364741.79950
# 77 n_estimators = 300, max_depth =  5, max_features = 0.133118, Score = 1338941.00873
# 78 n_estimators = 300, max_depth =  5, max_features = 0.292120, Score = 1323359.97610
# 79 n_estimators = 300, max_depth = 27, max_features = 0.249056, Score = 1345612.33417
# 80 n_estimators = 300, max_depth = 21, max_features = 0.211826, Score = 1351923.49409
# 81 n_estimators = 300, max_depth = 26, max_features = 0.195416, Score = 1356607.19219
# 82 n_estimators = 300, max_depth = 24, max_features = 0.125254, Score = 1345705.11519
# 83 n_estimators = 300, max_depth = 25, max_features = 0.186636, Score = 1358352.21993
# 84 n_estimators = 300, max_depth = 21, max_features = 0.280668, Score = 1363039.85798
# 85 n_estimators = 300, max_depth = 19, max_features = 0.244043, Score = 1348368.22751
# 86 n_estimators = 300, max_depth = 25, max_features = 0.174088, Score = 1347624.33920
# 87 n_estimators = 300, max_depth = 16, max_features = 0.167555, Score = 1347362.28215
# 88 n_estimators = 300, max_depth = 13, max_features = 0.194050, Score = 1333703.06870
# 89 n_estimators = 300, max_depth =  9, max_features = 0.213149, Score = 1326158.12802
# 90 n_estimators = 300, max_depth = 26, max_features = 0.254328, Score = 1345592.23996
# 91 n_estimators = 300, max_depth = 13, max_features = 0.176441, Score = 1349382.44771
# 92 n_estimators = 300, max_depth = 23, max_features = 0.163856, Score = 1344626.71751
# 93 n_estimators = 300, max_depth = 10, max_features = 0.239624, Score = 1345783.47357
# 94 n_estimators = 300, max_depth = 12, max_features = 0.242698, Score = 1345059.39724
# 95 n_estimators = 300, max_depth =  6, max_features = 0.151656, Score = 1320007.78955
# 96 n_estimators = 300, max_depth = 21, max_features = 0.182149, Score = 1351923.49409
# 97 n_estimators = 300, max_depth = 30, max_features = 0.254298, Score = 1346267.90758
# 98 n_estimators = 300, max_depth = 13, max_features = 0.141108, Score = 1349382.44771
# 99 n_estimators = 300, max_depth = 19, max_features = 0.219556, Score = 1356717.57267
# (100, 5)
#     epoch         score  n_estimators  max_depth  max_features
# 95     95 1320007.78955           300          6       0.15166
# 60     60 1320056.71719           300          7       0.15336
# 22     22 1320056.71719           300          7       0.15121
# 33     33 1320276.54908           300          6       0.20430
# 26     26 1320276.54908           300          6       0.19224
# 78     78 1323359.97610           300          5       0.29212
# 32     32 1325692.96845           300          7       0.25477
# 89     89 1326158.12802           300          9       0.21315
# 18     18 1328368.41923           300          8       0.11832
# 30     30 1328433.34271           300          6       0.24009

# %%
# 가장 정확도가 높은 하이퍼패러미터를 저장
best_hyperparameters = finer_hyperparameters_list.iloc[0]

best_max_depth = best_hyperparameters["max_depth"]
best_max_features = best_hyperparameters["max_features"]

print(f"max_depth(best) = {best_max_depth}, max_features(best) = {best_max_features:.6f}
#        2160660.87332292,  141027.07776579, 2523309.30315137,
#         941499.12366568,  960834.25581533,   51257.59518456,
#          75893.66010668, 1256620.66043896,   83215.71696615,
#          99589.01176992,  110518.33427127,   92800.26783366,
#         108754.57460087,   99796.80789283,   78056.08856587,
#         171598.46629587,  261022.90921365,   80759.15610254,
#          66264.0700463 , 4252972.0374916 , 6618796.09854766,
#         271504.15839414,   72327.80224781,   79389.2924744 ,
#         498570.94484523, 3142544.87105139,  156146.49058907,
#         252085.78122072,  157265.03695544,   81623.10006027,
#         674748.4635903 ,   91505.05186756,   76423.75000213,
#          76702.22502486,   82130.18163364,   72327.80224781,
#        2643910.21352729,   57413.62900631, 1148226.48620224,
#         100637.29588188, 1443656.55599818,  223236.01272431,
#         116475.74496944,  191419.35348961,  236399.31448309,
#         330106.77983526, 1092300.75343714, 2272558.1825713 ,
#        1815598.78659636,  170915.95561289, 2315243.30109318,
#         508518.10347231, 1197847.62385324, 2074538.87392419,
#         390671.40659937,   66847.94318305,   68978.33216874,
#        1764909.67904591,   60659.97944195,   93448.25943501,
#         102975.73305174,  505944.12700993, 1724404.73798085,
#        1111089.23429457,  311499.92446448,  497360.99307407,
#         355858.07413762,   94115.33066253, 1003355.49938697,
#         148446.23861182, 2707778.85224648,  113727.01385127,
#         660516.15796116,  200613.12049279,   86801.22808647,
#         167681.55617207,  238704.95333654,  150445.4214608 ,
#         166380.97037143,  217014.07361176,   93896.67787551,
#         310963.93785964,   86780.0387932 ,   70894.3966693 ])

# %% [markdown]
# ### 최적의 cv 찾기
# * 35로 사용 : 1454429.7489887767
# * 추가적으로 더 해볼 수 있으면 ? 해봐도 될듯
# * overfitting 일어나는 것 같아.........ㅠ

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators=100,
                              n_jobs=-1,
                              random_state=37)

X_train, X_test, Y_train = df.drop(['box_off_num'], axis=1), testdf, df['box_off_num']

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

n_estimators = 100

# 랜덤 서치 횟수
num_epoch = 50

# %%
cv_cv = []
for cv_turn in range(35,51, 1) : # 5, 7, 9, 11, 13, 15, 17, 19


# hyperparameter 탐색 결과가 저장될 리스트
    coarse_hyperparameters_list = []

    for epoch in range(num_epoch):
        # max depth의 값을 2~100으로 설정
        max_depth = np.random.randint(low=2, high=10)

        # 적용할 feature의 비율을 0.1~1.0로 설정
        max_features = np.random.uniform(low=0.1, high=1.0)

        model = RandomForestRegressor(n_estimators=n_estimators,
                                      max_depth=max_depth,
                                      max_features=max_features,
                                      n_jobs=-1,
                                      random_state=37)

        # cross_val_score를 실행하여 rmse의 평균 계산
        # cv는 데이터 조각 개수
        score = cross_val_score(model, X_train, Y_train, cv=cv_turn, scoring=rmse_score).mean() 

        # hyperparameter 탐색 결과를 저장할 딕셔너리
        hyperparameters = {
            'epoch': epoch,
            'score': score,
            'n_estimators': n_estimators,
            'max_depth': max_depth,
            'max_features': max_features,
            'cv' : cv_turn
        }

        # hyperparameter 탐색 결과 저장
        coarse_hyperparameters_list.append(hyperparameters)

        # hyperparameter 탐색 결과를 출력
        print(f"{epoch:2} n_estimators = {n_estimators}, max_depth = {max_depth:2}, max_features = {max_features:.6f}, Score = {score:.5f}, CV = {cv_turn}")

    # coarse_hyperparameters_list를 DataFrame으로 변환
    coarse_hyperparameters_list = pd.DataFrame.from_dict(coarse_hyperparameters_list)

    # coarse_hyperparameters_list를 score가 낮은 순으로 정렬
    coarse_hyperparameters_list = coarse_hyperparameters_list.sort_values(by="score")

    # coarse_hyperparameters_list의 상위 1개 저장
    cv_cv.append(coarse_hyperparameters_list.head(1))
# Out:
#  0 n_estimators = 100, max_depth =  4, max_features = 0.858669, Score = 1282875.46143, CV = 35
#  1 n_estimators = 100, max_depth =  2, max_features = 0.472122, Score = 1250527.83485, CV = 35
#  2 n_estimators = 100, max_depth =  4, max_features = 0.420797, Score = 1253739.93230, CV = 35
#  3 n_estimators = 100, max_depth =  4, max_features = 0.113389, Score = 1275597.00407, CV = 35
#  4 n_estimators = 100, max_depth =  6, max_features = 0.131492, Score = 1251926.84632, CV = 35
#  5 n_estimators = 100, max_depth =  6, max_features = 0.872735, Score = 1297226.98422, CV = 35
#  6 n_estimators = 100, max_depth =  7, max_features = 0.729731, Score = 1317374.45949, CV = 35
#  7 n_estimators = 100, max_depth =  6, max_features = 0.551336, Score = 1290898.28891, CV = 35
#  8 n_estimators = 100, max_depth =  4, max_features = 0.385187, Score = 1253739.93230, CV = 35
#  9 n_estimators = 100, max_depth =  8, max_features = 0.922225, Score = 1319473.51932, CV = 35
# 10 n_estimators = 100, max_depth =  4, max_features = 0.990197, Score = 1288883.00787, CV = 35
# 11 n_estimators = 100, max_depth =  7, max_features = 0.470049, Score = 1301053.97218, CV = 35
# 12 n_estimators = 100, max_depth =  4, max_features = 0.261420, Score = 1240169.81514, CV = 35
# 13 n_estimators = 100, max_depth =  8, max_features = 0.211544, Score = 1254541.73233, CV = 35
# 14 n_estimators = 100, max_depth =  4, max_features = 0.273184, Score = 1240169.81514, CV = 35
# 15 n_estimators = 100, max_depth =  9, max_features = 0.674870, Score = 1326176.72739, CV = 35
# 16 n_estimators = 100, max_depth =  4, max_features = 0.809104, Score = 1270954.60375, CV = 35
# 17 n_estimators = 100, max_depth =  3, max_features = 0.443371, Score = 1252310.25150, CV = 35
# 18 n_estimators = 100, max_depth =  6, max_features = 0.840616, Score = 1304803.21007, CV = 35
# 19 n_estimators = 100, max_depth =  2, max_features = 0.126350, Score = 1360793.26289, CV = 35
# 20 n_estimators = 100, max_depth =  7, max_features = 0.828381, Score = 1312085.36459, CV = 35
# 21 n_estimators = 100, max_depth =  2, max_features = 0.374277, Score = 1253384.38511, CV = 35
# 22 n_estimators = 100, max_depth =  7, max_features = 0.406746, Score = 1300323.65345, CV = 35
# 23 n_estimators = 100, max_depth =  7, max_features = 0.613155, Score = 1304681.56242, CV = 35
# 24 n_estimators = 100, max_depth =  4, max_features = 0.880204, Score = 1282875.46143, CV = 35
# 25 n_estimators = 100, max_depth =  4, max_features = 0.117752, Score = 1275597.00407, CV = 35
# 26 n_estimators = 100, max_depth =  5, max_features = 0.555967, Score = 1279267.35492, CV = 35
# 27 n_estimators = 100, max_depth =  4, max_features = 0.353751, Score = 1246786.83883, CV = 35
# 28 n_estimators = 100, max_depth =  8, max_features = 0.758857, Score = 1331068.89801, CV = 35
# 29 n_estimators = 100, max_depth =  5, max_features = 0.678583, Score = 1281280.12994, CV = 35
# 30 n_estimators = 100, max_depth =  4, max_features = 0.850411, Score = 1270954.60375, CV = 35
# 31 n_estimators = 100, max_depth =  5, max_features = 0.778405, Score = 1282526.15202, CV = 35
# 32 n_estimators = 100, max_depth =  2, max_features = 0.329952, Score = 1263521.57451, CV = 35
# 33 n_estimators = 100, max_depth =  3, max_features = 0.821605, Score = 1263540.37235, CV = 35
# 34 n_estimators = 100, max_depth =  7, max_features = 0.175967, Score = 1264267.05671, CV = 35
# 35 n_estimators = 100, max_depth =  8, max_features = 0.629055, Score = 1310274.06479, CV = 35
# 36 n_estimators = 100, max_depth =  4, max_features = 0.700532, Score = 1269017.46375, CV = 35
# 37 n_estimators = 100, max_depth =  3, max_features = 0.872461, Score = 1266918.67334, CV = 35
# 38 n_estimators = 100, max_depth =  5, max_features = 0.409334, Score = 1278871.85890, CV = 35
# 39 n_estimators = 100, max_depth =  8, max_features = 0.953816, Score = 1344857.13063, CV = 35
# 40 n_estimators = 100, max_depth =  7, max_features = 0.768797, Score = 1317374.45949, CV = 35
# 41 n_estimators = 100, max_depth =  2, max_features = 0.649334, Score = 1268182.41139, CV = 35
# 42 n_estimators = 100, max_depth =  3, max_features = 0.576322, Score = 1260644.73713, CV = 35
# 43 n_estimators = 100, max_depth =  5, max_features = 0.891113, Score = 1288964.21429, CV = 35
# 44 n_estimators = 100, max_depth =  2, max_features = 0.619208, Score = 1254932.61687, CV = 35
# 45 n_estimators = 100, max_depth =  5, max_features = 0.568903, Score = 1279267.35492, CV = 35
# 46 n_estimators = 100, max_depth =  3, max_features = 0.224774, Score = 1248484.27078, CV = 35
# 47 n_estimators = 100, max_depth =  3, max_features = 0.943687, Score = 1277192.40978, CV = 35
# 48 n_estimators = 100, max_depth =  9, max_features = 0.650716, Score = 1326176.72739, CV = 35
# 49 n_estimators = 100, max_depth =  7, max_features = 0.878659, Score = 1334632.24774, CV = 35
#  0 n_estimators = 100, max_depth =  2, max_features = 0.721384, Score = 1234877.84026, CV = 36
#  1 n_estimators = 100, max_depth =  4, max_features = 0.700221, Score = 1238635.37481, CV = 36
#  2 n_estimators = 100, max_depth =  9, max_features = 0.176546, Score = 1210819.66532, CV = 36
#  3 n_estimators = 100, max_depth =  4, max_features = 0.701592, Score = 1238635.37481, CV = 36
#  4 n_estimators = 100, max_depth =  7, max_features = 0.478601, Score = 1261669.59267, CV = 36
#  5 n_estimators = 100, max_depth =  2, max_features = 0.502863, Score = 1227784.81411, CV = 36
#  6 n_estimators = 100, max_depth =  6, max_features = 0.110711, Score = 1238246.88791, CV = 36
#  7 n_estimators = 100, max_depth =  6, max_features = 0.663390, Score = 1262901.27230, CV = 36
#  8 n_estimators = 100, max_depth =  5, max_features = 0.864953, Score = 1264615.10049, CV = 36
#  9 n_estimators = 100, max_depth =  4, max_features = 0.715588, Score = 1230265.55383, CV = 36
# 10 n_estimators = 100, max_depth =  8, max_features = 0.564798, Score = 1261986.32988, CV = 36
# 11 n_estimators = 100, max_depth =  3, max_features = 0.679376, Score = 1232254.89162, CV = 36
# 12 n_estimators = 100, max_depth =  3, max_features = 0.986577, Score = 1243456.62252, CV = 36
# 13 n_estimators = 100, max_depth =  6, max_features = 0.730421, Score = 1259970.72713, CV = 36
# 14 n_estimators = 100, max_depth =  5, max_features = 0.780458, Score = 1255669.68463, CV = 36
# 15 n_estimators = 100, max_depth =  4, max_features = 0.233590, Score = 1220068.27040, CV = 36
# 16 n_estimators = 100, max_depth =  3, max_features = 0.755819, Score = 1231221.17426, CV = 36
# 17 n_estimators = 100, max_depth =  9, max_features = 0.779348, Score = 1300929.92228, CV = 36
# 18 n_estimators = 100, max_depth =  8, max_features = 0.128900, Score = 1231462.54774, CV = 36
# 19 n_estimators = 100, max_depth =  2, max_features = 0.134914, Score = 1364541.36916, CV = 36
# 20 n_estimators = 100, max_depth =  6, max_features = 0.528440, Score = 1278293.27964, CV = 36
# 21 n_estimators = 100, max_depth =  6, max_features = 0.687266, Score = 1262901.27230, CV = 36
# 22 n_estimators = 100, max_depth =  9, max_features = 0.578463, Score = 1288434.30774, CV = 36
# 23 n_estimators = 100, max_depth =  9, max_features = 0.901154, Score = 1292264.93299, CV = 36
# 24 n_estimators = 100, max_depth =  4, max_features = 0.542150, Score = 1238708.63623, CV = 36
# 25 n_estimators = 100, max_depth =  3, max_features = 0.295888, Score = 1219295.44326, CV = 36
# 26 n_estimators = 100, max_depth =  8, max_features = 0.947844, Score = 1314834.43890, CV = 36
# 27 n_estimators = 100, max_depth =  6, max_features = 0.551751, Score = 1278293.27964, CV = 36
# 28 n_estimators = 100, max_depth =  4, max_features = 0.804992, Score = 1240595.35404, CV = 36
# 29 n_estimators = 100, max_depth =  8, max_features = 0.324753, Score = 1257849.14511, CV = 36
# 30 n_estimators = 100, max_depth =  8, max_features = 0.500761, Score = 1261986.32988, CV = 36
# 31 n_estimators = 100, max_depth =  3, max_features = 0.674952, Score = 1232254.89162, CV = 36
# 32 n_estimators = 100, max_depth =  7, max_features = 0.344649, Score = 1255260.43540, CV = 36
# 33 n_estimators = 100, max_depth =  5, max_features = 0.257928, Score = 1230286.12065, CV = 36
# 34 n_estimators = 100, max_depth =  7, max_features = 0.848392, Score = 1295226.23006, CV = 36
# 35 n_estimators = 100, max_depth =  2, max_features = 0.426839, Score = 1234367.93338, CV = 36
# 36 n_estimators = 100, max_depth =  7, max_features = 0.273973, Score = 1249586.95763, CV = 36
# 37 n_estimators = 100, max_depth =  2, max_features = 0.668918, Score = 1236368.06212, CV = 36
# 38 n_estimators = 100, max_depth =  3, max_features = 0.397220, Score = 1223935.02581, CV = 36
# 39 n_estimators = 100, max_depth =  5, max_features = 0.868501, Score = 1264615.10049, CV = 36
# 40 n_estimators = 100, max_depth =  7, max_features = 0.849098, Score = 1295226.23006, CV = 36
# 41 n_estimators = 100, max_depth =  9, max_features = 0.549450, Score = 1275113.92742, CV = 36
# 42 n_estimators = 100, max_depth =  3, max_features = 0.796765, Score = 1234777.13915, CV = 36
# 43 n_estimators = 100, max_depth =  4, max_features = 0.719610, Score = 1230265.55383, CV = 36
# 44 n_estimators = 100, max_depth =  3, max_features = 0.998169, Score = 1243456.62252, CV = 36
# 45 n_estimators = 100, max_depth =  2, max_features = 0.761761, Score = 1234877.84026, CV = 36
# 46 n_estimators = 100, max_depth =  8, max_features = 0.255908, Score = 1230087.64153, CV = 36
# 47 n_estimators = 100, max_depth =  6, max_features = 0.624865, Score = 1271699.64552, CV = 36
# 48 n_estimators = 100, max_depth =  8, max_features = 0.935444, Score = 1314834.43890, CV = 36
# 49 n_estimators = 100, max_depth =  5, max_features = 0.590097, Score = 1245225.48314, CV = 36
#  0 n_estimators = 100, max_depth =  7, max_features = 0.719400, Score = 1300100.28641, CV = 37
#  1 n_estimators = 100, max_depth =  7, max_features = 0.129411, Score = 1203055.19452, CV = 37
#  2 n_estimators = 100, max_depth =  3, max_features = 0.652703, Score = 1229923.63695, CV = 37
#  3 n_estimators = 100, max_depth =  6, max_features = 0.429850, Score = 1269147.56964, CV = 37
#  4 n_estimators = 100, max_depth =  5, max_features = 0.123940, Score = 1241930.89851, CV = 37
#  5 n_estimators = 100, max_depth =  2, max_features = 0.637158, Score = 1233049.36943, CV = 37
#  6 n_estimators = 100, max_depth =  4, max_features = 0.468204, Score = 1229524.62687, CV = 37
#  7 n_estimators = 100, max_depth =  7, max_features = 0.135411, Score = 1203055.19452, CV = 37
#  8 n_estimators = 100, max_depth =  5, max_features = 0.319059, Score = 1228004.32889, CV = 37
#  9 n_estimators = 100, max_depth =  2, max_features = 0.266189, Score = 1244119.10570, CV = 37
# 10 n_estimators = 100, max_depth =  6, max_features = 0.586353, Score = 1267370.74052, CV = 37
# 11 n_estimators = 100, max_depth =  4, max_features = 0.818417, Score = 1259469.89435, CV = 37
# 12 n_estimators = 100, max_depth =  2, max_features = 0.843677, Score = 1237902.75195, CV = 37
# 13 n_estimators = 100, max_depth =  5, max_features = 0.420525, Score = 1241945.59898, CV = 37
# 14 n_estimators = 100, max_depth =  6, max_features = 0.318417, Score = 1251337.98496, CV = 37
# 15 n_estimators = 100, max_depth =  3, max_features = 0.411826, Score = 1228679.22760, CV = 37
# 16 n_estimators = 100, max_depth =  3, max_features = 0.715307, Score = 1228329.87833, CV = 37
# 17 n_estimators = 100, max_depth =  4, max_features = 0.838809, Score = 1259469.89435, CV = 37
# 18 n_estimators = 100, max_depth =  4, max_features = 0.384259, Score = 1211915.90586, CV = 37
# 19 n_estimators = 100, max_depth =  9, max_features = 0.494676, Score = 1272136.97837, CV = 37
# 20 n_estimators = 100, max_depth =  4, max_features = 0.823933, Score = 1259469.89435, CV = 37
# 21 n_estimators = 100, max_depth =  7, max_features = 0.982391, Score = 1301955.88823, CV = 37
# 22 n_estimators = 100, max_depth =  2, max_features = 0.904315, Score = 1245379.73215, CV = 37
# 23 n_estimators = 100, max_depth =  5, max_features = 0.765090, Score = 1267482.24415, CV = 37
# 24 n_estimators = 100, max_depth =  5, max_features = 0.219910, Score = 1210673.39073, CV = 37
# 25 n_estimators = 100, max_depth =  4, max_features = 0.755655, Score = 1244173.44011, CV = 37
# 26 n_estimators = 100, max_depth =  7, max_features = 0.981622, Score = 1301955.88823, CV = 37
# 27 n_estimators = 100, max_depth =  8, max_features = 0.189188, Score = 1247142.83709, CV = 37
# 28 n_estimators = 100, max_depth =  6, max_features = 0.111640, Score = 1210327.52787, CV = 37
# 29 n_estimators = 100, max_depth =  5, max_features = 0.617810, Score = 1260915.18161, CV = 37
# 30 n_estimators = 100, max_depth =  7, max_features = 0.877629, Score = 1302965.08673, CV = 37
# 31 n_estimators = 100, max_depth =  6, max_features = 0.828999, Score = 1297613.55066, CV = 37
# 32 n_estimators = 100, max_depth =  5, max_features = 0.353629, Score = 1228004.32889, CV = 37
# 33 n_estimators = 100, max_depth =  7, max_features = 0.857075, Score = 1303688.33687, CV = 37
# 34 n_estimators = 100, max_depth =  8, max_features = 0.471939, Score = 1273067.75984, CV = 37
# 35 n_estimators = 100, max_depth =  2, max_features = 0.523848, Score = 1226025.69194, CV = 37
# 36 n_estimators = 100, max_depth =  2, max_features = 0.694045, Score = 1231826.65591, CV = 37
# 37 n_estimators = 100, max_depth =  7, max_features = 0.130379, Score = 1203055.19452, CV = 37
# 38 n_estimators = 100, max_depth =  3, max_features = 0.620288, Score = 1235346.99882, CV = 37
# 39 n_estimators = 100, max_depth =  9, max_features = 0.622248, Score = 1295465.92186, CV = 37
# 40 n_estimators = 100, max_depth =  6, max_features = 0.151844, Score = 1218107.59760, CV = 37
# 41 n_estimators = 100, max_depth =  4, max_features = 0.563656, Score = 1239651.53816, CV = 37
# 42 n_estimators = 100, max_depth =  8, max_features = 0.487558, Score = 1273067.75984, CV = 37
# 43 n_estimators = 100, max_depth =  2, max_features = 0.782743, Score = 1237091.41404, CV = 37
# 44 n_estimators = 100, max_depth =  8, max_features = 0.817648, Score = 1314745.74226, CV = 37
# 45 n_estimators = 100, max_depth =  3, max_features = 0.473051, Score = 1219174.62409, CV = 37
# 46 n_estimators = 100, max_depth =  2, max_features = 0.889345, Score = 1245379.73215, CV = 37
# 47 n_estimators = 100, max_depth =  5, max_features = 0.522273, Score = 1258098.34166, CV = 37
# 48 n_estimators = 100, max_depth =  5, max_features = 0.677748, Score = 1266671.18834, CV = 37
# 49 n_estimators = 100, max_depth =  2, max_features = 0.728985, Score = 1237091.41404, CV = 37
#  0 n_estimators = 100, max_depth =  4, max_features = 0.279447, Score = 1235612.39865, CV = 38
#  1 n_estimators = 100, max_depth =  8, max_features = 0.635627, Score = 1304506.97900, CV = 38
#  2 n_estimators = 100, max_depth =  9, max_features = 0.759870, Score = 1336884.55026, CV = 38
#  3 n_estimators = 100, max_depth =  6, max_features = 0.924083, Score = 1293504.68466, CV = 38
#  4 n_estimators = 100, max_depth =  3, max_features = 0.665681, Score = 1253091.19117, CV = 38
#  5 n_estimators = 100, max_depth =  3, max_features = 0.447554, Score = 1246407.98405, CV = 38
#  6 n_estimators = 100, max_depth =  4, max_features = 0.225244, Score = 1235612.39865, CV = 38
#  7 n_estimators = 100, max_depth =  9, max_features = 0.201656, Score = 1229001.23809, CV = 38
#  8 n_estimators = 100, max_depth =  8, max_features = 0.924234, Score = 1316248.40016, CV = 38
#  9 n_estimators = 100, max_depth =  7, max_features = 0.943177, Score = 1323559.96924, CV = 38

# %%
display(cv_cv)

# %%
display(cv_cv)
# Out:
# [    epoch         score  n_estimators  max_depth  max_features  cv
#  60     60  1.267566e+06           100          5      0.221966  27,
#      epoch         score  n_estimators  max_depth  max_features  cv
#  54     54  1.246747e+06           100          7        0.1176  29,
#      epoch         score  n_estimators  max_depth  max_features  cv
#  17     17  1.259830e+06           100          9      0.142936  31,
#      epoch         score  n_estimators  max_depth  max_features  cv
#  88     88  1.235076e+06           100          6      0.233692  33,
#      epoch         score  n_estimators  max_depth  max_features  cv
#  67     67  1.229384e+06           100          6      0.170716  35]

# %%
display(cv_cv)
# Out:
# [    epoch         score  n_estimators  max_depth  max_features  cv
#  25     25  1.303383e+06           100          5      0.234854  19,
#      epoch         score  n_estimators  max_depth  max_features  cv
#  56     56  1.277253e+06           100          8      0.174468  21,
#      epoch         score  n_estimators  max_depth  max_features  cv
#  12     12  1.328894e+06           100          7      0.178809  23,
#      epoch         score  n_estimators  max_depth  max_features  cv
#  60     60  1.266826e+06           100          9      0.110251  25]

# %%
# 가장 정확도가 높은 하이퍼패러미터를 저장
best_hyperparameters = finer_hyperparameters_list.iloc[0]

best_max_depth = best_hyperparameters["max_depth"]
best_max_features = best_hyperparameters["max_features"]

print(f"max_depth(best) = {best_max_depth}, max_features(best) = {best_max_features:.6f}")

# %%
from sklearn.ensemble import RandomForestRegressor

best_n_estimators = 3000
model = RandomForestRegressor(n_estimators=best_n_estimators,
                              max_depth=best_max_depth,
                              max_features=best_max_features,
                              random_state=37,
                              n_jobs=-1)
model

# %%
model.fit(X_train, Y_train)
prediction = model.predict(X_test)

# %% [markdown]
# ## tensorflow

# %%
train_Y = df['box_off_num']
train_X = df.drop(['box_off_num'], axis=1)

test_X = testdf

# %%
import tensorflow as tf
import numpy as np

X = tf.placeholder(shape = [None,11], dtype=tf.float32)
Y = tf.placeholder(shape = [None,1], dtype=tf.float32)

W = tf.Variable(tf.random_normal([11,1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name = 'bias')

H = tf.matmul(X, W) + b
cost = tf.reduce_mean(tf.square(H-Y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.0000001)
train = optimizer.minimize(cost)


sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(5000) :
    _, cost_val = sess.run([train, cost],
                          feed_dict = {
                              X : train_X.values,
                              Y : train_Y.values.reshape(-1,1)
                          })
    if step % 500 == 0 :
        print('cost값은 : {}'.format(cost_val))
    
prediction = sess.run(H, feed_dict = {X : test_X.values, })
# Out:
# cost값은 : 3833388597248.0
# cost값은 : 2351955443712.0
# cost값은 : 2347802558464.0
# cost값은 : 2347764809728.0
# cost값은 : 2347744100352.0
# cost값은 : 2347723653120.0
# cost값은 : 2347703730176.0
# cost값은 : 2347683807232.0
# cost값은 : 2347663622144.0
# cost값은 : 2347643174912.0

# %% [markdown]
# # 저장

# %%
# 저장함수
def save_file(prediction, number) :
    sub = pd.read_csv('./data/submission.csv')
    sub['box_off_num'] = prediction
    sub.to_csv('./submission/submission' + str(number) + '.csv', index=False)
    return print('done')

# %%
save_file(prediction, 19)
# Out:
# done

# %%
a = 0
for i in range(len(prediction)) :
    if prediction[i] <= 0 :
        prediction[i] = 0
        a += 1

print(a)
#prediction = prediction.astype(int)
prediction
# Out:
# 71
# array([1115566.30565657, 1330898.07271574, 1956710.48447819,
#        2166859.56483689, 2080734.17510612,  346045.45931293,
#              0.        ,       0.        ,  112417.19426519,
#         951379.95868599, 1162406.66919744, 1679870.66858181,
#        1124792.64272501,   49453.00864089, 1559751.63842055,
#        2517328.07425241,       0.        , 1568512.0582598 ,
#        1354633.42175171,  243400.04957435,       0.        ,
#         450034.0288779 ,  454500.39016113,       0.        ,
#              0.        , 2425606.73876284,       0.        ,
#        1806573.56296934,   87379.25725834,  204802.27780387,
#        1488231.30625899,  218700.55519663,       0.        ,
#        1374517.85637328,   86868.77794634,       0.        ,
#              0.        ,       0.        ,   22318.97752276,
#              0.        ,  204638.03387941,  397508.22867611,
#         374282.20315428,  543604.79166777,  867479.27053258,
#        2054273.09964444,       0.        ,  273394.65591729,
#         314385.90759814,       0.        ,   21710.03930111,
#        1131871.11880189,       0.        , 1496151.65575613,
#        1624193.44579676,  196612.84126142,  175018.05754875,
#        1683928.05466701, 2206332.23162974, 1804422.95286106,
