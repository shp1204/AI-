# %%
import pandas as pd
df = pd.read_csv('./data/movies_train.csv')
testdf = pd.read_csv('./data/movies_test.csv')
# 지수 표현 제거
pd.options.display.float_format = '{:.5f}'.format

# %%
df.corr()
# Out:
#                   time  dir_prev_bfnum  dir_prev_num  num_staff  num_actor  \
# time           1.00000         0.26468       0.30673    0.62321    0.11415
# dir_prev_bfnum 0.26468         1.00000       0.13182    0.32352    0.08382
# dir_prev_num   0.30673         0.13182       1.00000    0.45071    0.01401
# num_staff      0.62321         0.32352       0.45071    1.00000    0.07787
# num_actor      0.11415         0.08382       0.01401    0.07787    1.00000
# box_off_num    0.44145         0.28318       0.25967    0.54426    0.11118
#
#                 box_off_num
# time                0.44145
# dir_prev_bfnum      0.28318
# dir_prev_num        0.25967
# num_staff           0.54426
# num_actor           0.11118
# box_off_num         1.00000

# %% [markdown]
# # 전처리

# %%
# column 생성
def make_col(dataframe, column_name, mapper) :
    new = []
    for i in dataframe[column_name] :
        if i in mapper.keys() :
            new.append(mapper.get(i))
        else :
            new.append(1)
    dataframe['new_' + str(column_name)] = pd.DataFrame(new)
    del dataframe[column_name]
    return dataframe

# %% [markdown]
# ## title
# title 은 제거

# %%
del df['title']
del testdf['title']

# %% [markdown]
# ## distributor

# %%
a = df.groupby(['distributor']).mean()['box_off_num'].sort_values(ascending=False)

distributor_mapper = {}
for i in range(len(a)) :
    if a[i] >= 1000000 :
        distributor_mapper.update({a.index[i] : 5 })
    elif a[i] >= 100000 :
        distributor_mapper.update({a.index[i] : 4 })
    elif a[i] >= 10000 :
        distributor_mapper.update({a.index[i] : 3 })
    elif a[i] >= 1000 :
        distributor_mapper.update({a.index[i] : 2 })
    else :
        distributor_mapper.update({a.index[i] : 1 })

df = make_col(df, 'distributor', distributor_mapper )
testdf = make_col(testdf, 'distributor', distributor_mapper )

# %% [markdown]
# ### 배급사별 box_off_num 의 평균에 따른 head, tail

# %%
df.groupby(['distributor']).mean()['box_off_num'].sort_values(ascending=False).head(20)
# Out:
# distributor
# CJ E&M Pictures    4.122337e+06
# (주)쇼박스             3.386656e+06
# (주)아이필름코퍼레이션       3.117859e+06
# 쇼박스(주)미디어플렉스       2.634823e+06
# 영구아트무비             2.541603e+06
# CJ E&M 영화부문        2.505309e+06
# (주)NEW             2.184405e+06
# CJ 엔터테인먼트          2.162742e+06
# 이십세기폭스코리아(주)       1.637046e+06
# SK텔레콤(주)           1.383867e+06
# CGV아트하우스           1.318189e+06
# 롯데엔터테인먼트           1.238149e+06
# 전망좋은영화사            1.214237e+06
# 주머니필름              1.201944e+06
# NEW                1.019017e+06
# 싸이더스               9.634390e+05
# 시네마서비스             8.968432e+05
# 보람엔터테인먼트           8.496350e+05
# 스튜디오 블루            7.716990e+05
# 씨네그루(주)키다리이엔티      7.551840e+05
# Name: box_off_num, dtype: float64

# %%
df.groupby(['distributor']).mean()['box_off_num'].sort_values(ascending=False).tail(20)
# Out:
# distributor
# 웃기씨네           464.5
# 판다미디어          432.0
# (주)더픽쳐스        429.0
# 이상우필름          339.0
# (주)온비즈넷        310.0
# (주)유비네트워크      303.0
# (주)휘엔터테인먼트     228.0
# 크리에이티브컴즈(주)    188.0
# ysfilm         172.0
# 에스와이코마드        163.0
# 건시네마           162.0
# (주)씨엠닉스        136.0
# 위더스필름           90.0
# 인터콘미디어          79.0
# 한국YWCA연합회       71.0
# 나우콘텐츠           54.0
# 위드시네마           46.0
# 사람과 사람들         42.0
# 고구마공작소           8.0
# 인피니티엔터테인먼트       2.0
# Name: box_off_num, dtype: float64

# %% [markdown]
# ## genre

# %% [markdown]
# ### genre 에 따른 box_off_num 평균 확인

# %%
df.groupby(['genre']).mean()['box_off_num'].sort_values(ascending=False).index
# Out:
# Index(['느와르', '액션', 'SF', '코미디', '드라마', '공포', '미스터리', '멜로/로맨스', '애니메이션',
#        '서스펜스', '다큐멘터리', '뮤지컬'],
#       dtype='object', name='genre')

# %%
df.groupby(['genre']).mean()['box_off_num'].sort_values(ascending=False)
# Out:
# genre
# 느와르       2.263695e+06
# 액션        2.203974e+06
# SF        1.788346e+06
# 코미디       1.193914e+06
# 드라마       6.256898e+05
# 공포        5.908325e+05
# 미스터리      5.275482e+05
# 멜로/로맨스    4.259680e+05
# 애니메이션     1.819267e+05
# 서스펜스      8.261100e+04
# 다큐멘터리     6.717226e+04
# 뮤지컬       6.627000e+03
# Name: box_off_num, dtype: float64

# %%
df['genre'].value_counts()
# Out:
# 드라마       221
# 다큐멘터리      93
# 멜로/로맨스     78
# 코미디        53
# 공포         42
# 액션         28
# 느와르        27
# 애니메이션      21
# 미스터리       17
# SF         13
# 뮤지컬         5
# 서스펜스        2
# Name: genre, dtype: int64

# %% [markdown]
# ### genre_version1

# %%
df = pd.get_dummies(df, columns=['genre'], prefix='genre')
testdf = pd.get_dummies(testdf, columns=['genre'], prefix='genre')

# %% [markdown]
# ### genre_version2
#
# version1, 3 보다 좋음
#
# 영화 종류 묶기 + box_off_num의 평균에 따라 비선호 영화 묶기
#
# => 1466134.4524178207
#
# * 드라마 멜로/로맨스6
#
# * 느와르 액션5
#
# * sf4
#
# * 코미디3
#
# * 공포 미스터리 서스펜스2
#
# * 애니메이션 다큐멘터리 뮤지컬1

# %%
genre_mapper = {'느와르' : 5 , '액션' : 5, 'SF' : 4, '코미디' : 3, '드라마' : 6, '공포' : 2, '미스터리' : 2, '멜로/로맨스' : 6, '애니메이션' : 1,
       '서스펜스' : 2, '다큐멘터리' : 1, '뮤지컬' : 1} 

df = make_col(df, 'genre', genre_mapper )
testdf = make_col(testdf, 'genre', genre_mapper )

# %% [markdown]
# ### genre_version3
#
# box_off_num 평균에 따라 임의로 분류
#
# => 1467553.925063711

# %%
느와르       4
액션        4
SF        3
코미디       3
드라마       2
공포        2
미스터리      2
멜로/로맨스    2
애니메이션     1
서스펜스     1
다큐멘터리     1
뮤지컬       1

# %%
genre_mapper = {'느와르' : 4 , '액션' : 4, 'SF' : 3, '코미디' : 3, '드라마' : 2, '공포' : 2, '미스터리' : 2, '멜로/로맨스' : 2, '애니메이션' : 1,
       '서스펜스' : 1, '다큐멘터리' : 1, '뮤지컬' : 1} 

df = make_col(df, 'genre', genre_mapper )
testdf = make_col(testdf, 'genre', genre_mapper )

# %% [markdown]
# ## release_time
#
# * days 그대로 사용해보자
#
# => sklearn,  1484884.4136596955
#
# => 전처리 하는 것이 더 좋음

# %%
def release_time(df) :
    years, months, days = [], [], []
    for line in df['release_time'] :
        a = line.split('-')
        years.append(int(a[0]))
        months.append(int(a[1]))
        days.append(int(a[2]))
        
    new_days = []
    for i in range(len(days)) :
        if int(days[i]) >= 20 :
            new_days.append(3)
        elif int(days[i]) >= 10 :
            new_days.append(2)
        else :
            new_days.append(1)    
            
    df['release_year'] = pd.DataFrame(years)
    df['release_month'] = pd.DataFrame(months)
    df['release_day'] = pd.DataFrame(new_days)

    del df['release_time']
    return df

df = release_time(df)
testdf = release_time(testdf)

# %% [markdown]
# ## time
#
# 전처리 이전과 비교하였을 때, box_off_num 과의 상관관계는 낮아졌다 ( 0.44 -> 0.29 )
#
# 하지만, 전처리 이후 성능이 개선됨
#
# => 1472434.761373017 ( 130, 70, ~ )
#
# => 1472973.0197688688 ( 130, 100, 70, ~ )

# %%
def time(df) :
    new_time = []
    for i in df['time'] :
        if i >= 130 :
            new_time.append(3)
        elif i > 70 : 
            new_time.append(2)
        else :
            new_time.append(1)

    df['new_time'] = pd.DataFrame(new_time)
    del df['time']
    return df

df = time(df)
testdf = time(testdf)

# %% [markdown]
# ## screening_rat

# %% [markdown]
# ### mapping_version1
#
# version1 이  version2보다 더 좋음

# %%
screening_rat_mapper = {'15세 관람가' : 3, '12세 관람가' : 2, '전체 관람가' : 2, '청소년 관람불가' : 1} 

df = make_col(df, 'screening_rat', screening_rat_mapper )
testdf = make_col(testdf, 'screening_rat', screening_rat_mapper )

# %% [markdown]
# ### mapping_version2

# %%
def screen_rat(df) :
    tmp = sorted(df['screening_rat'].unique(), reverse=False)

    mapping = {}
    num = 1
    for i in tmp :
        mapping.update({i : num})
        num += 1

    return make_col(df, 'screening_rat', mapping)

# %%
df = screen_rat(df)
testdf = screen_rat(testdf)

# %% [markdown]
# ### mapping_version3
#
# version1과 큰 차이는 나지 않지만 더 좋음
#
# => 1483501.7131900766

# %%
df = pd.get_dummies(df, columns=['screening_rat'], prefix='screening_rat')
testdf = pd.get_dummies(testdf, columns=['screening_rat'], prefix='screening_rat')

# %% [markdown]
# ### 관람 연령 제한에 따른 box_off_num 평균, 영화 수

# %%
df.groupby(['screening_rat']).mean()['box_off_num'].sort_values(ascending=False)
# Out:
# screening_rat
# 15세 관람가     1.247519e+06
# 12세 관람가     8.449809e+05
# 청소년 관람불가    3.641813e+05
# 전체 관람가      1.351005e+05
# Name: box_off_num, dtype: float64

# %%
df.groupby(['screening_rat']).count()['box_off_num'].sort_values(ascending=False)
# Out:
# screening_rat
# 청소년 관람불가    204
# 15세 관람가     202
# 12세 관람가     102
# 전체 관람가       92
# Name: box_off_num, dtype: int64

# %% [markdown]
# ## director

# %%
del df['director']
del testdf['director']

# %% [markdown]
# ## dir_prev_bfnum

# %% [markdown]
# ### version1
# * 결측치 0으로 채워 넣음

# %%
df = df.fillna(0)
testdf = testdf.fillna(0)

# %% [markdown]
# ### version2
# * 결측치가 많은 column이므로 제거
#
# => 1483572.7123881471

# %%
del df['dir_prev_bfnum']
del testdf['dir_prev_bfnum']

# %% [markdown]
# ## dir_prev_num
#
# * column제거하였더니 점수 떨어짐
#
# => 1471931.2287102737

# %%
del df['dir_prev_num']
del testdf['dir_prev_num']

# %% [markdown]
# ## num_staff
#
# staff 는 범주화하지 않는 것이 더 좋다!
#
# =>	1536288.9882051074

# %% [markdown]
# ### staff_version1

# %%
def staff(dataframe) : 
    new_staff = []
    for i in dataframe['num_staff'] :
        if i == 0 :
            new_staff.append(0)
        elif i <= 100 :
            new_staff.append(1)
        elif i <= 300 :
            new_staff.append(2)        
        elif i <= 500 :
            new_staff.append(3)
        else :
            new_staff.append(4)
    dataframe['new_staff'] = pd.DataFrame(new_staff)
    del dataframe['num_staff']
    
    return dataframe

# %%
df = staff(df)
testdf = staff(testdf)

# %%
df.groupby(['new_staff']).mean()['box_off_num'].sort_values(ascending=False)
# Out:
# new_staff
# 4    4.132596e+06
# 3    1.980997e+06
# 2    6.495566e+05
# 1    1.164862e+05
# 0    7.805562e+03
# Name: box_off_num, dtype: float64

# %% [markdown]
# ## num_actor
#
# column 제거했더니 ?
#
# => sklearn, 1470532.643567296

# %%
del df['num_actor']
del testdf['num_actor']

# %%
df
# Out:
#      num_staff  box_off_num  new_distributor  new_genre  release_year  \
# 0           91        23398                5          5          2012
# 1          387      7072501                5          5          2015
# 2          343      6959083                5          5          2013
# 3           20       217866                5          3          2012
# 4          251       483387                5          3          2010
# ..         ...          ...              ...        ...           ...
# 595        510      1475091                5          6          2014
# 596        286      1716438                5          6          2013
# 597        123         2475                3          2          2010
# 598        431      2192525                5          5          2015
# 599        363      7166532                5          5          2013
#
#      release_month  release_day  new_time  screening_rat_12세 관람가  \
# 0               11            3         2                      0
# 1               11            2         3                      0
# 2                6            1         2                      0
# 3                7            2         2                      0
# 4               11            1         2                      0
# ..             ...          ...       ...                    ...
# 595              8            2         2                      0
# 596              3            2         2                      0
# 597              9            3         2                      0
# 598              5            2         2                      0
# 599              1            3         2                      0
#
#      screening_rat_15세 관람가  screening_rat_전체 관람가  screening_rat_청소년 관람불가
# 0                        0                     0                       1
# 1                        0                     0                       1
# 2                        1                     0                       0
# 3                        0                     1                       0
# 4                        1                     0                       0
# ..                     ...                   ...                     ...
# 595                      0                     0                       1
# 596                      1                     0                       0
# 597                      0                     0                       1
# 598                      1                     0                       0
# 599                      1                     0                       0
#
# [600 rows x 12 columns]

# %% [markdown]
# # 상관관계

# %%
df.corr().sort_values(by='box_off_num', ascending = False)
# Out:
#                         num_staff  box_off_num  new_distributor  new_genre  \
# box_off_num               0.54426      1.00000          0.45016    0.09595
# num_staff                 1.00000      0.54426          0.69184    0.26775
# new_distributor           0.69184      0.45016          1.00000    0.08755
# new_time                  0.32914      0.29498          0.25603    0.10255
# screening_rat_15세 관람가     0.24653      0.21037          0.25791    0.06829
# new_genre                 0.26775      0.09595          0.08755    1.00000
# screening_rat_12세 관람가     0.06047      0.03390          0.03496    0.01585
# release_month            -0.00284      0.01910         -0.02799   -0.02042
# release_year             -0.03289     -0.00250         -0.05986   -0.01883
# release_day               0.00825     -0.01102         -0.02770    0.00124
# screening_rat_전체 관람가     -0.27374     -0.13353         -0.16415   -0.43499
# screening_rat_청소년 관람불가   -0.08569     -0.13518         -0.16016    0.25017
#
#                         release_year  release_month  release_day  new_time  \
# box_off_num                 -0.00250        0.01910     -0.01102   0.29498
# num_staff                   -0.03289       -0.00284      0.00825   0.32914
# new_distributor             -0.05986       -0.02799     -0.02770   0.25603
# new_time                    -0.05254        0.00813      0.02927   1.00000
# screening_rat_15세 관람가       -0.07186       -0.05132     -0.01894   0.04755
# new_genre                   -0.01883       -0.02042      0.00124   0.10255
# screening_rat_12세 관람가       -0.02142        0.04292     -0.02659  -0.03082
# release_month                0.04663        1.00000     -0.05270   0.00813
# release_year                 1.00000        0.04663      0.02214  -0.05254
# release_day                  0.02214       -0.05270      1.00000   0.02927
# screening_rat_전체 관람가        -0.06660       -0.00010      0.03884  -0.07623
# screening_rat_청소년 관람불가       0.13932        0.01724      0.01043   0.03498
#
#                         screening_rat_12세 관람가  screening_rat_15세 관람가  \
# box_off_num                           0.03390                0.21037
# num_staff                             0.06047                0.24653
# new_distributor                       0.03496                0.25791
# new_time                             -0.03082                0.04755
# screening_rat_15세 관람가                -0.32242                1.00000
# new_genre                             0.01585                0.06829
# screening_rat_12세 관람가                 1.00000               -0.32242
# release_month                         0.04292               -0.05132
# release_year                         -0.02142               -0.07186
# release_day                          -0.02659               -0.01894
# screening_rat_전체 관람가                 -0.19260               -0.30318
# screening_rat_청소년 관람불가               -0.32483               -0.51133
#
#                         screening_rat_전체 관람가  screening_rat_청소년 관람불가
# box_off_num                         -0.13353                -0.13518
# num_staff                           -0.27374                -0.08569
# new_distributor                     -0.16415                -0.16016
# new_time                            -0.07623                 0.03498
# screening_rat_15세 관람가               -0.30318                -0.51133
# new_genre                           -0.43499                 0.25017
# screening_rat_12세 관람가               -0.19260                -0.32483
# release_month                       -0.00010                 0.01724
# release_year                        -0.06660                 0.13932
# release_day                          0.03884                 0.01043
# screening_rat_전체 관람가                 1.00000                -0.30544
# screening_rat_청소년 관람불가              -0.30544                 1.00000

# %% [markdown]
# # 모델링

# %%
import numpy as np
from sklearn.metrics import make_scorer

def rmse(predict, actual):
    predict = np.array(predict)
    actual = np.array(actual)

    distance = predict - actual
    square_distance = distance ** 2
    mean_square_distance = square_distance.mean()
    score = np.sqrt(mean_square_distance)
    
    return score

rmse_score = make_scorer(rmse)
rmse_score
# Out:
# make_scorer(rmse)

# %% [markdown]
# ## sklearn_Linear Regression

# %%
train_Y = df['box_off_num']
train_X = df.drop(['box_off_num'], axis=1)

test_X = testdf

# %%
from sklearn import linear_model

lm = linear_model.LinearRegression()
lm.fit(train_X, train_Y)

prediction = lm.predict(test_X)

# %% [markdown]
# ## sklearn_RandomForestRegressor
#
# => 1528294.5021972428	 ( epoch X )

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

model = RandomForestRegressor(n_estimators=300,
                              n_jobs=-1,
                              random_state=46)
#score = cross_val_score(model, X_train, y_train, cv=20, scoring=rmse_score).mean()

# %%
train_Y = df['box_off_num']
train_X = df.drop(['box_off_num'], axis=1)

test_X = testdf

model.fit(train_X, train_Y)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=300, n_jobs=-1, oob_score=False,
#                       random_state=46, verbose=0, warm_start=False)

# %%
prediction = model.predict(test_X)
# Out:
# array([1.37224077e+06, 1.37712202e+06, 2.91496949e+06, 2.35731362e+06,
#        2.18836183e+06, 3.83021800e+04, 3.05253000e+03, 1.25348333e+03,
#        4.89507000e+03, 2.70432873e+05, 4.52084997e+05, 1.09368079e+06,
#        2.43055558e+06, 3.80952000e+03, 1.54969315e+06, 2.49022232e+06,
#        4.11237000e+03, 2.80051673e+06, 9.91018117e+05, 4.01313674e+06,
#        3.31340000e+02, 2.75170133e+04, 1.04387323e+05, 2.15437233e+04,
#        2.86300000e+02, 3.14427729e+06, 2.01759000e+03, 2.63354868e+06,
#        9.63927000e+03, 7.76519000e+03, 4.01482357e+06, 2.53251757e+05,
#        3.11146333e+03, 5.57792827e+05, 6.60871667e+03, 2.34236933e+04,
#        1.94996333e+03, 4.38108000e+03, 4.30301000e+03, 3.68430000e+02,
#        5.67607333e+03, 2.82403647e+05, 9.73643447e+05, 3.93951430e+05,
#        1.67400333e+03, 1.45000667e+03, 3.06379333e+03, 2.89755128e+06,
#        1.26663133e+04, 1.13483140e+06, 4.01049667e+03, 4.33217614e+06,
#        1.29794000e+03, 1.19128180e+05, 1.13663000e+03, 8.96838333e+03,
#        1.95189343e+05, 1.18530259e+06, 2.51820696e+06, 1.34944434e+06,
#        4.82525667e+03, 2.54825860e+06, 1.40099420e+05, 1.58759561e+06,
#        2.76173406e+06, 8.25968200e+05, 1.41813257e+05, 6.81546667e+02,
#        1.58190981e+06, 2.49652567e+04, 6.64543333e+02, 4.57946667e+03,
#        2.17091213e+05, 2.70879024e+06, 1.64686904e+06, 1.27141257e+05,
#        9.91135333e+03, 3.25553333e+02, 6.77323333e+02, 9.99896117e+05,
#        2.44863633e+04, 2.12578334e+06, 6.58209333e+03, 1.27417313e+06,
#        2.24633023e+05, 7.16773333e+03, 4.01650000e+02, 8.60017000e+03,
#        9.04382800e+04, 3.30943333e+02, 2.76343333e+02, 5.20069667e+03,
#        1.87969113e+05, 1.00914000e+03, 1.45449000e+03])

# %% [markdown]
# ## LGBM
#
# => 1480188.794477261

# %%
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
k_fold = KFold(n_splits=10, shuffle=True, random_state = 777)

model = lgb.LGBMRegressor(random_state = 777, n_estimators=10000)
X_train, X_test, Y_train = df.drop(['box_off_num'], axis=1), testdf, df['box_off_num']


params = {
    'learning_rate' : [0.001, 0.0001, 0.00001],
    'min_child_samples' : [20, 30]}

gs = GridSearchCV(estimator=model,
                 param_grid = params,
                 scoring=rmse_score,
                 cv=k_fold)

# %%
gs.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=777, shuffle=True),
#              error_score=nan,
#              estimator=LGBMRegressor(boosting_type='gbdt', class_weight=None,
#                                      colsample_bytree=1.0,
#                                      importance_type='split', learning_rate=0.1,
#                                      max_depth=-1, min_child_samples=20,
#                                      min_child_weight=0.001, min_split_gain=0.0,
#                                      n_estimators=10000, n_jobs=-1,
#                                      num_leaves=31, objective=None,
#                                      random_state=777, reg_alpha=0.0,
#                                      reg_lambda=0.0, silent=True, subsample=1.0,
#                                      subsample_for_bin=200000,
#                                      subsample_freq=0),
#              iid='deprecated', n_jobs=None,
#              param_grid={'learning_rate': [0.001, 0.0001, 1e-05],
#                          'min_child_samples': [20, 30]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=make_scorer(rmse), verbose=0)

# %%
gs.best_params_
# Out:
# {'learning_rate': 1e-05, 'min_child_samples': 30}

# %%
model = lgb.LGBMRegressor(random_state = 777, n_estimators=10000, learning_rate= 1e-05, min_child_samples= 30)
models = []
for train_idx, val_idx in k_fold.split(X_train) :
    x_t = X_train.iloc[train_idx]
    y_t = Y_train.iloc[train_idx]
    x_val = X_train.iloc[val_idx]
    y_val = Y_train.iloc[val_idx]
    
    models.append(model.fit(x_t, y_t, eval_set = (x_val, y_val), early_stopping_rounds=1000, verbose=100))
# Out:
# Training until validation scores don't improve for 1000 rounds
# [100]	valid_0's l2: 4.39233e+12
# [200]	valid_0's l2: 4.39124e+12
# [300]	valid_0's l2: 4.39015e+12
# [400]	valid_0's l2: 4.38906e+12
# [500]	valid_0's l2: 4.38798e+12
# [600]	valid_0's l2: 4.3869e+12
# [700]	valid_0's l2: 4.38582e+12
# [800]	valid_0's l2: 4.38474e+12
# [900]	valid_0's l2: 4.38367e+12
# [1000]	valid_0's l2: 4.3826e+12
# [1100]	valid_0's l2: 4.38153e+12
# [1200]	valid_0's l2: 4.38047e+12
# [1300]	valid_0's l2: 4.37941e+12
# [1400]	valid_0's l2: 4.37835e+12
# [1500]	valid_0's l2: 4.37729e+12
# [1600]	valid_0's l2: 4.37623e+12
# [1700]	valid_0's l2: 4.37518e+12
# [1800]	valid_0's l2: 4.37413e+12
# [1900]	valid_0's l2: 4.37308e+12
# [2000]	valid_0's l2: 4.37204e+12
# [5600]	valid_0's l2: 1.13064e+12
# [5700]	valid_0's l2: 1.12962e+12
# [5800]	valid_0's l2: 1.1286e+12
# [5900]	valid_0's l2: 1.12759e+12
# [6000]	valid_0's l2: 1.12658e+12
# [6100]	valid_0's l2: 1.12557e+12
# [6200]	valid_0's l2: 1.12456e+12
# [6300]	valid_0's l2: 1.12356e+12
# [6400]	valid_0's l2: 1.12256e+12
# [6500]	valid_0's l2: 1.12156e+12
# [6600]	valid_0's l2: 1.12057e+12
# [6700]	valid_0's l2: 1.11958e+12
# [6800]	valid_0's l2: 1.11859e+12
# [6900]	valid_0's l2: 1.1176e+12
# [7000]	valid_0's l2: 1.11662e+12
# [7100]	valid_0's l2: 1.11564e+12
# [7200]	valid_0's l2: 1.11466e+12
# [7300]	valid_0's l2: 1.11369e+12
# [7400]	valid_0's l2: 1.11272e+12
# [7500]	valid_0's l2: 1.11176e+12
# [7600]	valid_0's l2: 1.11083e+12
# [7700]	valid_0's l2: 1.1099e+12
# [7800]	valid_0's l2: 1.10897e+12
# [7900]	valid_0's l2: 1.10805e+12
# [8000]	valid_0's l2: 1.10713e+12
# [8100]	valid_0's l2: 1.10622e+12
# [8200]	valid_0's l2: 1.1053e+12
# [8300]	valid_0's l2: 1.10439e+12
# [8400]	valid_0's l2: 1.10348e+12
# [8500]	valid_0's l2: 1.10258e+12
# [8600]	valid_0's l2: 1.10167e+12
# [8700]	valid_0's l2: 1.10077e+12
# [8800]	valid_0's l2: 1.09988e+12
# [8900]	valid_0's l2: 1.09898e+12
# [9000]	valid_0's l2: 1.09809e+12
# [9100]	valid_0's l2: 1.0972e+12
# [9200]	valid_0's l2: 1.09631e+12
# [9300]	valid_0's l2: 1.09543e+12
# [9400]	valid_0's l2: 1.09454e+12
# [9500]	valid_0's l2: 1.09367e+12
# [9600]	valid_0's l2: 1.09279e+12
# [9700]	valid_0's l2: 1.09192e+12
# [9800]	valid_0's l2: 1.09104e+12
# [9900]	valid_0's l2: 1.09018e+12
# [10000]	valid_0's l2: 1.08931e+12
# Did not meet early stopping. Best iteration is:
# [10000]	valid_0's l2: 1.08931e+12
# Training until validation scores don't improve for 1000 rounds
# [100]	valid_0's l2: 5.55181e+12
# [200]	valid_0's l2: 5.55025e+12
# [300]	valid_0's l2: 5.5487e+12
# [400]	valid_0's l2: 5.54696e+12
# [500]	valid_0's l2: 5.54502e+12
# [600]	valid_0's l2: 5.54307e+12
# [700]	valid_0's l2: 5.54113e+12
# [800]	valid_0's l2: 5.5392e+12
# [900]	valid_0's l2: 5.53727e+12
# [1000]	valid_0's l2: 5.53534e+12
# [1100]	valid_0's l2: 5.53341e+12
# [1200]	valid_0's l2: 5.53149e+12
# [1300]	valid_0's l2: 5.52957e+12
# [1400]	valid_0's l2: 5.52766e+12
# [1500]	valid_0's l2: 5.52575e+12
# [1600]	valid_0's l2: 5.52384e+12
# [1700]	valid_0's l2: 5.52193e+12
# [1800]	valid_0's l2: 5.52003e+12
# [1900]	valid_0's l2: 5.51813e+12
# [2000]	valid_0's l2: 5.51624e+12
# [2100]	valid_0's l2: 5.51436e+12
# [2200]	valid_0's l2: 5.51247e+12
# [2300]	valid_0's l2: 5.51059e+12
# [6800]	valid_0's l2: 3.55563e+12
# [6900]	valid_0's l2: 3.55275e+12
# [7000]	valid_0's l2: 3.54988e+12
# [7100]	valid_0's l2: 3.54701e+12
# [7200]	valid_0's l2: 3.54415e+12
# [7300]	valid_0's l2: 3.5413e+12
# [7400]	valid_0's l2: 3.53845e+12
# [7500]	valid_0's l2: 3.5356e+12
# [7600]	valid_0's l2: 3.53276e+12
# [7700]	valid_0's l2: 3.52993e+12
# [7800]	valid_0's l2: 3.5271e+12
# [7900]	valid_0's l2: 3.52428e+12
# [8000]	valid_0's l2: 3.52146e+12
# [8100]	valid_0's l2: 3.51865e+12
# [8200]	valid_0's l2: 3.51584e+12
# [8300]	valid_0's l2: 3.51304e+12
# [8400]	valid_0's l2: 3.51024e+12
# [8500]	valid_0's l2: 3.50745e+12
# [8600]	valid_0's l2: 3.50466e+12
# [8700]	valid_0's l2: 3.50188e+12
# [8800]	valid_0's l2: 3.49911e+12
# [8900]	valid_0's l2: 3.49634e+12
# [9000]	valid_0's l2: 3.49357e+12
# [9100]	valid_0's l2: 3.49081e+12
# [9200]	valid_0's l2: 3.48806e+12
# [9300]	valid_0's l2: 3.48531e+12
# [9400]	valid_0's l2: 3.48257e+12
# [9500]	valid_0's l2: 3.47983e+12
# [9600]	valid_0's l2: 3.47712e+12
# [9700]	valid_0's l2: 3.4745e+12
# [9800]	valid_0's l2: 3.47188e+12
# [9900]	valid_0's l2: 3.46927e+12
# [10000]	valid_0's l2: 3.46666e+12
# Did not meet early stopping. Best iteration is:
# [10000]	valid_0's l2: 3.46666e+12

# %%
preds = []
for model in models :
    preds.append(model.predict(X_test))
len(preds)
# Out:
# 10

# %%
import numpy as np
prediction = np.mean(preds, axis=0)

# %%
prediction
# Out:
# array([691695.2517164 , 672319.21502713, 851316.339441  , 903897.40003323,
#        903897.40003323, 635577.41282796, 626110.17356157, 625556.93486383,
#        625560.00726256, 691239.28514796, 635820.24005134, 691695.2517164 ,
#        691695.2517164 , 625676.61787807, 851316.339441  , 955633.49804001,
#        625999.87401811, 851316.339441  , 672319.21502713, 757723.25541921,
#        625556.93486383, 627289.84345835, 635820.24005134, 625556.93486383,
#        625556.93486383, 955633.49804001, 625808.53751061, 903897.40003323,
#        625999.8043815 , 625556.93486383, 851316.339441  , 627269.50418685,
#        626109.65018459, 691239.28514796, 626110.17356157, 627251.25526062,
#        625676.54824146, 626109.65018459, 625999.8043815 , 625556.93486383,
#        625556.93486383, 627251.25526062, 757723.25541921, 630908.00879904,
#        757723.25541921, 851316.339441  , 625556.93486383, 635577.41282796,
#        757723.25541921, 625560.00726256, 627269.50418685, 757723.25541921,
#        625999.8043815 , 757723.25541921, 672319.21502713, 635577.41282796,
#        626109.65018459, 903897.40003323, 903897.40003323, 851316.339441  ,
#        903897.40003323, 903897.40003323, 635579.41035238, 625556.93486383,
#        635579.41035238, 625556.93486383, 852641.11758969, 672319.21502713,
#        672319.21502713, 635579.41035238, 851316.339441  , 757723.25541921,
#        625808.53751061, 851788.03603721, 625808.53751061, 625556.93486383,
#        757723.25541921, 635621.02988268, 635820.24005134, 626110.17356157,


X_train, X_test, Y_train = df.drop(['box_off_num'], axis=1), testdf, df['box_off_num']

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

n_estimators = 300

# 랜덤 서치 횟수
num_epoch = 100

# hyperparameter 탐색 결과가 저장될 리스트
coarse_hyperparameters_list = []

for epoch in range(num_epoch):
    # max depth의 값을 2~100으로 설정
    max_depth = np.random.randint(low=2, high=100)

    # 적용할 feature의 비율을 0.1~1.0로 설정
    max_features = np.random.uniform(low=0.1, high=1.0)

    model = RandomForestRegressor(n_estimators=n_estimators,
                                  max_depth=max_depth,
                                  max_features=max_features,
                                  n_jobs=-1,
                                  random_state=37)

    # cross_val_score를 실행하여 rmse의 평균 계산
    # cv는 데이터 조각 개수
    score = cross_val_score(model, X_train, Y_train, cv=19, scoring=rmse_score).mean() 
    
    # hyperparameter 탐색 결과를 저장할 딕셔너리
    hyperparameters = {
        'epoch': epoch,
        'score': score,
        'n_estimators': n_estimators,
        'max_depth': max_depth,
        'max_features': max_features,
        
    }

    # hyperparameter 탐색 결과 저장
    coarse_hyperparameters_list.append(hyperparameters)

    # hyperparameter 탐색 결과를 출력
    print(f"{epoch:2} n_estimators = {n_estimators}, max_depth = {max_depth:2}, max_features = {max_features:.6f}, Score = {score:.5f}")

# coarse_hyperparameters_list를 DataFrame으로 변환
coarse_hyperparameters_list = pd.DataFrame.from_dict(coarse_hyperparameters_list)

# coarse_hyperparameters_list를 score가 낮은 순으로 정렬
coarse_hyperparameters_list = coarse_hyperparameters_list.sort_values(by="score")

print(coarse_hyperparameters_list.shape)

# coarse_hyperparameters_list의 상위 10개 출력
coarse_hyperparameters_list.head(10)
# Out:
#  0 n_estimators = 300, max_depth = 64, max_features = 0.833205, Score = 1393512.61763
#  1 n_estimators = 300, max_depth = 43, max_features = 0.159416, Score = 1284537.78454
#  2 n_estimators = 300, max_depth =  8, max_features = 0.428368, Score = 1321274.82064
#  3 n_estimators = 300, max_depth = 69, max_features = 0.260081, Score = 1293895.62730
#  4 n_estimators = 300, max_depth = 85, max_features = 0.734574, Score = 1375368.10514
#  5 n_estimators = 300, max_depth = 20, max_features = 0.114196, Score = 1281946.95469
#  6 n_estimators = 300, max_depth = 96, max_features = 0.429968, Score = 1318467.36775
#  7 n_estimators = 300, max_depth = 88, max_features = 0.968638, Score = 1392045.60814
#  8 n_estimators = 300, max_depth = 58, max_features = 0.171294, Score = 1284537.78454
#  9 n_estimators = 300, max_depth = 67, max_features = 0.381196, Score = 1318467.36775
# 10 n_estimators = 300, max_depth = 28, max_features = 0.673549, Score = 1367013.29754
# 11 n_estimators = 300, max_depth = 62, max_features = 0.855297, Score = 1393512.61763
# 12 n_estimators = 300, max_depth = 68, max_features = 0.319137, Score = 1302042.82100
# 13 n_estimators = 300, max_depth = 33, max_features = 0.993271, Score = 1392045.60814
# 14 n_estimators = 300, max_depth = 23, max_features = 0.878531, Score = 1391641.51010
# 15 n_estimators = 300, max_depth = 51, max_features = 0.533578, Score = 1342341.51274
# 16 n_estimators = 300, max_depth = 51, max_features = 0.863219, Score = 1393512.61763
# 17 n_estimators = 300, max_depth = 13, max_features = 0.781838, Score = 1376764.00721
# 18 n_estimators = 300, max_depth = 67, max_features = 0.490758, Score = 1342341.51274
# 19 n_estimators = 300, max_depth = 99, max_features = 0.623812, Score = 1352552.41936
# 20 n_estimators = 300, max_depth = 85, max_features = 0.778472, Score = 1375368.10514
# 21 n_estimators = 300, max_depth = 98, max_features = 0.372300, Score = 1318467.36775
# 22 n_estimators = 300, max_depth = 87, max_features = 0.304009, Score = 1302042.82100
# 23 n_estimators = 300, max_depth = 70, max_features = 0.674140, Score = 1367013.29754
# 24 n_estimators = 300, max_depth = 63, max_features = 0.323061, Score = 1302042.82100
# 25 n_estimators = 300, max_depth = 25, max_features = 0.626485, Score = 1352508.05701
# 26 n_estimators = 300, max_depth =  3, max_features = 0.129884, Score = 1385747.23488
# 27 n_estimators = 300, max_depth = 81, max_features = 0.913471, Score = 1392045.60814
# 28 n_estimators = 300, max_depth =  6, max_features = 0.546739, Score = 1335111.85610
# 29 n_estimators = 300, max_depth =  9, max_features = 0.490648, Score = 1338859.28624
# 30 n_estimators = 300, max_depth =  4, max_features = 0.640149, Score = 1324357.89256
# 31 n_estimators = 300, max_depth =  5, max_features = 0.329235, Score = 1296170.02197
# 32 n_estimators = 300, max_depth = 11, max_features = 0.156681, Score = 1282871.78494
# 33 n_estimators = 300, max_depth = 83, max_features = 0.762622, Score = 1375368.10514
# 34 n_estimators = 300, max_depth = 15, max_features = 0.655046, Score = 1359734.81979
# 35 n_estimators = 300, max_depth = 53, max_features = 0.926011, Score = 1392045.60814
# 36 n_estimators = 300, max_depth = 34, max_features = 0.820165, Score = 1393512.61763
# 37 n_estimators = 300, max_depth = 79, max_features = 0.452734, Score = 1318467.36775
# 38 n_estimators = 300, max_depth = 65, max_features = 0.965209, Score = 1392045.60814
# 39 n_estimators = 300, max_depth = 50, max_features = 0.975015, Score = 1392045.60814
# 40 n_estimators = 300, max_depth = 50, max_features = 0.545912, Score = 1352552.41936
# 41 n_estimators = 300, max_depth = 47, max_features = 0.774592, Score = 1375368.10514
# 42 n_estimators = 300, max_depth = 11, max_features = 0.218403, Score = 1300860.84358
# 43 n_estimators = 300, max_depth = 90, max_features = 0.968887, Score = 1392045.60814
# 44 n_estimators = 300, max_depth = 25, max_features = 0.290471, Score = 1301943.47197
# 45 n_estimators = 300, max_depth =  7, max_features = 0.909174, Score = 1374348.81459
# 46 n_estimators = 300, max_depth = 79, max_features = 0.785716, Score = 1375368.10514
# 47 n_estimators = 300, max_depth = 50, max_features = 0.834150, Score = 1393512.61763
# 48 n_estimators = 300, max_depth = 28, max_features = 0.753904, Score = 1375368.10514
# 49 n_estimators = 300, max_depth =  2, max_features = 0.191237, Score = 1367570.04583
# 50 n_estimators = 300, max_depth = 48, max_features = 0.973700, Score = 1392045.60814
# 51 n_estimators = 300, max_depth = 61, max_features = 0.250648, Score = 1293895.62730
# 52 n_estimators = 300, max_depth = 50, max_features = 0.979415, Score = 1392045.60814
# 53 n_estimators = 300, max_depth = 61, max_features = 0.781408, Score = 1375368.10514
# 54 n_estimators = 300, max_depth = 32, max_features = 0.753141, Score = 1375368.10514
# 55 n_estimators = 300, max_depth = 30, max_features = 0.623746, Score = 1352552.41936
# 56 n_estimators = 300, max_depth = 45, max_features = 0.517643, Score = 1342341.51274
# 57 n_estimators = 300, max_depth = 51, max_features = 0.657809, Score = 1367013.29754
# 58 n_estimators = 300, max_depth = 56, max_features = 0.843795, Score = 1393512.61763
# 59 n_estimators = 300, max_depth = 34, max_features = 0.900932, Score = 1393512.61763
# 60 n_estimators = 300, max_depth = 55, max_features = 0.657002, Score = 1367013.29754
# 61 n_estimators = 300, max_depth = 19, max_features = 0.360011, Score = 1301284.21981
# 62 n_estimators = 300, max_depth =  4, max_features = 0.617468, Score = 1316303.84710
# 63 n_estimators = 300, max_depth = 11, max_features = 0.439838, Score = 1326008.66255
# 64 n_estimators = 300, max_depth = 76, max_features = 0.447482, Score = 1318467.36775
# 65 n_estimators = 300, max_depth = 59, max_features = 0.283607, Score = 1302042.82100
# 66 n_estimators = 300, max_depth = 42, max_features = 0.662176, Score = 1367013.29754
# 67 n_estimators = 300, max_depth = 88, max_features = 0.467586, Score = 1342341.51274
# 68 n_estimators = 300, max_depth = 67, max_features = 0.105716, Score = 1284537.78454
# 69 n_estimators = 300, max_depth = 86, max_features = 0.219355, Score = 1293895.62730
# 70 n_estimators = 300, max_depth = 91, max_features = 0.441063, Score = 1318467.36775
# 71 n_estimators = 300, max_depth = 46, max_features = 0.658006, Score = 1367013.29754
# 72 n_estimators = 300, max_depth = 51, max_features = 0.458097, Score = 1342341.51274
# 73 n_estimators = 300, max_depth = 92, max_features = 0.394504, Score = 1318467.36775
# 74 n_estimators = 300, max_depth = 98, max_features = 0.619706, Score = 1352552.41936
# 75 n_estimators = 300, max_depth = 44, max_features = 0.596650, Score = 1352552.41936
# 76 n_estimators = 300, max_depth = 27, max_features = 0.227567, Score = 1293974.75516
# 77 n_estimators = 300, max_depth = 48, max_features = 0.737077, Score = 1375368.10514
# 78 n_estimators = 300, max_depth = 62, max_features = 0.684944, Score = 1367013.29754
# 79 n_estimators = 300, max_depth = 37, max_features = 0.567247, Score = 1352552.41936
# 80 n_estimators = 300, max_depth = 80, max_features = 0.328944, Score = 1302042.82100
# 81 n_estimators = 300, max_depth = 19, max_features = 0.323265, Score = 1301284.21981
# 82 n_estimators = 300, max_depth = 80, max_features = 0.453705, Score = 1318467.36775
# 83 n_estimators = 300, max_depth = 13, max_features = 0.598807, Score = 1362879.88245
# 84 n_estimators = 300, max_depth = 89, max_features = 0.626131, Score = 1352552.41936
# 85 n_estimators = 300, max_depth = 70, max_features = 0.549903, Score = 1352552.41936
# 86 n_estimators = 300, max_depth = 61, max_features = 0.384842, Score = 1318467.36775
# 87 n_estimators = 300, max_depth = 27, max_features = 0.781779, Score = 1375350.28053
# 88 n_estimators = 300, max_depth = 79, max_features = 0.633931, Score = 1352552.41936
# 89 n_estimators = 300, max_depth = 79, max_features = 0.261435, Score = 1293895.62730
# 90 n_estimators = 300, max_depth = 76, max_features = 0.543863, Score = 1342341.51274
# 91 n_estimators = 300, max_depth = 58, max_features = 0.676427, Score = 1367013.29754
# 92 n_estimators = 300, max_depth = 37, max_features = 0.841046, Score = 1393512.61763
# 93 n_estimators = 300, max_depth = 19, max_features = 0.766183, Score = 1378129.83778
# 94 n_estimators = 300, max_depth = 45, max_features = 0.629259, Score = 1352552.41936
# 95 n_estimators = 300, max_depth = 63, max_features = 0.689165, Score = 1367013.29754
# 96 n_estimators = 300, max_depth = 99, max_features = 0.649146, Score = 1367013.29754
# 97 n_estimators = 300, max_depth = 52, max_features = 0.399596, Score = 1318467.36775
# 98 n_estimators = 300, max_depth = 37, max_features = 0.957899, Score = 1392045.60814
# 99 n_estimators = 300, max_depth = 12, max_features = 0.797452, Score = 1375839.73108
# (100, 5)
#     epoch         score  n_estimators  max_depth  max_features
# 5       5 1281946.95469           300         20       0.11420
# 32     32 1282871.78494           300         11       0.15668
# 8       8 1284537.78454           300         58       0.17129
# 1       1 1284537.78454           300         43       0.15942
# 68     68 1284537.78454           300         67       0.10572
# 69     69 1293895.62730           300         86       0.21936
# 3       3 1293895.62730           300         69       0.26008
# 89     89 1293895.62730           300         79       0.26143
# 51     51 1293895.62730           300         61       0.25065
# 76     76 1293974.75516           300         27       0.22757

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

n_estimators = 300
num_epoch = 100
finer_hyperparameters_list = []

for epoch in range(num_epoch):
    # coarse 단계에서 찾은 뎁스와 피쳐비율 구간을 적용
    max_depth = np.random.randint(low=5, high=35)
    max_features = np.random.uniform(low=0.1, high=0.3)
    
    model = RandomForestRegressor(n_estimators=n_estimators,
                                  max_depth=max_depth,
                                  max_features=max_features,
                                  n_jobs=-1,
                                  random_state=37)

    score = cross_val_score(model, X_train, Y_train, cv=19, scoring=rmse_score).mean()
    hyperparameters = {
        'epoch': epoch,
        'score': score,
        'n_estimators': n_estimators,
        'max_depth': max_depth,
        'max_features': max_features,
    }

    finer_hyperparameters_list.append(hyperparameters)
    print(f"{epoch:2} n_estimators = {n_estimators}, max_depth = {max_depth:2}, max_features = {max_features:.6f}, Score = {score:.5f}")

finer_hyperparameters_list = pd.DataFrame.from_dict(finer_hyperparameters_list)
finer_hyperparameters_list = finer_hyperparameters_list.sort_values(by="score")
print(finer_hyperparameters_list.shape)

finer_hyperparameters_list.head(10)
# Out:
#  0 n_estimators = 300, max_depth = 23, max_features = 0.276752, Score = 1300059.63731
#  1 n_estimators = 300, max_depth = 13, max_features = 0.214328, Score = 1301754.25086
#  2 n_estimators = 300, max_depth = 16, max_features = 0.130952, Score = 1293295.32604
#  3 n_estimators = 300, max_depth = 16, max_features = 0.227167, Score = 1297058.31702
#  4 n_estimators = 300, max_depth = 18, max_features = 0.205171, Score = 1287083.80645
#  5 n_estimators = 300, max_depth = 20, max_features = 0.190094, Score = 1292194.46021
#  6 n_estimators = 300, max_depth = 30, max_features = 0.185979, Score = 1293895.62730
#  7 n_estimators = 300, max_depth = 31, max_features = 0.222023, Score = 1293895.62730
#  8 n_estimators = 300, max_depth = 13, max_features = 0.136155, Score = 1286084.40575
#  9 n_estimators = 300, max_depth = 23, max_features = 0.179795, Score = 1285070.24183
# 10 n_estimators = 300, max_depth =  6, max_features = 0.286767, Score = 1291691.32530
# 11 n_estimators = 300, max_depth =  9, max_features = 0.192398, Score = 1292220.23618
# 12 n_estimators = 300, max_depth = 30, max_features = 0.151740, Score = 1284537.78454
# 13 n_estimators = 300, max_depth = 28, max_features = 0.260932, Score = 1293927.69298
# 14 n_estimators = 300, max_depth = 28, max_features = 0.213818, Score = 1293927.69298
# 15 n_estimators = 300, max_depth = 16, max_features = 0.174032, Score = 1293295.32604
# 16 n_estimators = 300, max_depth = 14, max_features = 0.265948, Score = 1295756.68896
# 17 n_estimators = 300, max_depth = 32, max_features = 0.217746, Score = 1293895.62730
# 18 n_estimators = 300, max_depth = 13, max_features = 0.211554, Score = 1301754.25086
# 19 n_estimators = 300, max_depth =  7, max_features = 0.250082, Score = 1298264.62332
# 20 n_estimators = 300, max_depth =  8, max_features = 0.272958, Score = 1302250.39834
# 21 n_estimators = 300, max_depth = 32, max_features = 0.196622, Score = 1293895.62730
# 22 n_estimators = 300, max_depth = 20, max_features = 0.151584, Score = 1281946.95469
# 23 n_estimators = 300, max_depth = 11, max_features = 0.231054, Score = 1300860.84358
# 24 n_estimators = 300, max_depth = 26, max_features = 0.288477, Score = 1301319.24784
# 25 n_estimators = 300, max_depth = 28, max_features = 0.261869, Score = 1293927.69298
# 26 n_estimators = 300, max_depth = 32, max_features = 0.135471, Score = 1284537.78454
# 27 n_estimators = 300, max_depth = 30, max_features = 0.292508, Score = 1302042.82100
# 28 n_estimators = 300, max_depth =  6, max_features = 0.162527, Score = 1290559.33407
# 29 n_estimators = 300, max_depth = 10, max_features = 0.129870, Score = 1286799.48805
# 30 n_estimators = 300, max_depth = 34, max_features = 0.220990, Score = 1293895.62730
# 31 n_estimators = 300, max_depth = 32, max_features = 0.194119, Score = 1293895.62730
# 32 n_estimators = 300, max_depth = 21, max_features = 0.291592, Score = 1302612.80592
# 33 n_estimators = 300, max_depth = 15, max_features = 0.104718, Score = 1286816.02712
# 34 n_estimators = 300, max_depth = 30, max_features = 0.269092, Score = 1293895.62730
# 35 n_estimators = 300, max_depth = 32, max_features = 0.118952, Score = 1284537.78454
# 36 n_estimators = 300, max_depth =  7, max_features = 0.172202, Score = 1287924.84326
# 37 n_estimators = 300, max_depth = 30, max_features = 0.156335, Score = 1284537.78454
# 38 n_estimators = 300, max_depth = 30, max_features = 0.109449, Score = 1284537.78454
# 39 n_estimators = 300, max_depth = 24, max_features = 0.176828, Score = 1284985.44210
# 40 n_estimators = 300, max_depth = 29, max_features = 0.280300, Score = 1302042.82100
# 41 n_estimators = 300, max_depth = 34, max_features = 0.183798, Score = 1293895.62730
# 42 n_estimators = 300, max_depth =  6, max_features = 0.272340, Score = 1290721.78758
# 43 n_estimators = 300, max_depth = 25, max_features = 0.273809, Score = 1301943.47197
# 44 n_estimators = 300, max_depth =  5, max_features = 0.236169, Score = 1294110.52331
# 45 n_estimators = 300, max_depth = 20, max_features = 0.134953, Score = 1281946.95469
# 46 n_estimators = 300, max_depth = 21, max_features = 0.289922, Score = 1302612.80592
# 47 n_estimators = 300, max_depth =  5, max_features = 0.205371, Score = 1294110.52331
# 48 n_estimators = 300, max_depth = 32, max_features = 0.205317, Score = 1293895.62730
# 49 n_estimators = 300, max_depth = 14, max_features = 0.229479, Score = 1295756.68896
# 50 n_estimators = 300, max_depth = 24, max_features = 0.183842, Score = 1294121.91703
# 51 n_estimators = 300, max_depth = 22, max_features = 0.277986, Score = 1302162.34063
# 52 n_estimators = 300, max_depth = 13, max_features = 0.276508, Score = 1308852.71567
# 53 n_estimators = 300, max_depth = 10, max_features = 0.287608, Score = 1312142.92815
# 54 n_estimators = 300, max_depth = 27, max_features = 0.150596, Score = 1284537.78454
# 55 n_estimators = 300, max_depth = 34, max_features = 0.236737, Score = 1293895.62730
# 56 n_estimators = 300, max_depth = 15, max_features = 0.297644, Score = 1310674.61474
# 57 n_estimators = 300, max_depth =  8, max_features = 0.111507, Score = 1284210.64475
# 58 n_estimators = 300, max_depth = 10, max_features = 0.242257, Score = 1286109.19923
# 59 n_estimators = 300, max_depth = 31, max_features = 0.266885, Score = 1293895.62730
# 60 n_estimators = 300, max_depth = 12, max_features = 0.183975, Score = 1296524.99491
# 61 n_estimators = 300, max_depth = 24, max_features = 0.127978, Score = 1284985.44210
# 62 n_estimators = 300, max_depth = 19, max_features = 0.115344, Score = 1282480.78231
# 63 n_estimators = 300, max_depth = 34, max_features = 0.260241, Score = 1293895.62730
# 64 n_estimators = 300, max_depth = 32, max_features = 0.189163, Score = 1293895.62730
# 65 n_estimators = 300, max_depth = 34, max_features = 0.156953, Score = 1284537.78454
# 66 n_estimators = 300, max_depth = 26, max_features = 0.160705, Score = 1284537.78454
# 67 n_estimators = 300, max_depth = 11, max_features = 0.115876, Score = 1282871.78494
# 68 n_estimators = 300, max_depth = 22, max_features = 0.129879, Score = 1284242.21376
# 69 n_estimators = 300, max_depth = 31, max_features = 0.193687, Score = 1293895.62730
# 70 n_estimators = 300, max_depth = 23, max_features = 0.210113, Score = 1294429.97583
# 71 n_estimators = 300, max_depth = 29, max_features = 0.195659, Score = 1293895.62730
# 72 n_estimators = 300, max_depth = 26, max_features = 0.120938, Score = 1284537.78454
# 73 n_estimators = 300, max_depth = 13, max_features = 0.244904, Score = 1301754.25086
# 74 n_estimators = 300, max_depth = 15, max_features = 0.198525, Score = 1306147.50952
# 75 n_estimators = 300, max_depth = 33, max_features = 0.274468, Score = 1302042.82100
# 76 n_estimators = 300, max_depth = 12, max_features = 0.234086, Score = 1296524.99491
# 77 n_estimators = 300, max_depth = 19, max_features = 0.182158, Score = 1295023.44011
# 78 n_estimators = 300, max_depth = 13, max_features = 0.167727, Score = 1286084.40575
# 79 n_estimators = 300, max_depth = 30, max_features = 0.118861, Score = 1284537.78454
# 80 n_estimators = 300, max_depth = 17, max_features = 0.116597, Score = 1287475.82412
# 81 n_estimators = 300, max_depth = 11, max_features = 0.218116, Score = 1300860.84358
# 82 n_estimators = 300, max_depth = 17, max_features = 0.274257, Score = 1298160.95022
# 83 n_estimators = 300, max_depth = 22, max_features = 0.270781, Score = 1293363.02974
# 84 n_estimators = 300, max_depth = 20, max_features = 0.266876, Score = 1292194.46021
# 85 n_estimators = 300, max_depth =  9, max_features = 0.244982, Score = 1292220.23618
# 86 n_estimators = 300, max_depth = 19, max_features = 0.163716, Score = 1282480.78231
# 87 n_estimators = 300, max_depth = 29, max_features = 0.148410, Score = 1284537.78454
# 88 n_estimators = 300, max_depth = 29, max_features = 0.102649, Score = 1284537.78454
# 89 n_estimators = 300, max_depth = 10, max_features = 0.121364, Score = 1286799.48805
# 90 n_estimators = 300, max_depth = 23, max_features = 0.262336, Score = 1294429.97583
# 91 n_estimators = 300, max_depth = 26, max_features = 0.224482, Score = 1293813.43126
# 92 n_estimators = 300, max_depth = 17, max_features = 0.146520, Score = 1287475.82412
# 93 n_estimators = 300, max_depth = 18, max_features = 0.132207, Score = 1283026.32190
# 94 n_estimators = 300, max_depth = 15, max_features = 0.127123, Score = 1286816.02712
# 95 n_estimators = 300, max_depth = 10, max_features = 0.203529, Score = 1286109.19923
# 96 n_estimators = 300, max_depth =  9, max_features = 0.189880, Score = 1292220.23618
# 97 n_estimators = 300, max_depth = 16, max_features = 0.134160, Score = 1293295.32604
# 98 n_estimators = 300, max_depth = 26, max_features = 0.183615, Score = 1293813.43126
# 99 n_estimators = 300, max_depth = 18, max_features = 0.202963, Score = 1287083.80645
# (100, 5)
#     epoch         score  n_estimators  max_depth  max_features
#


X_train, X_test, Y_train = df.drop(['box_off_num'], axis=1), testdf, df['box_off_num']

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

n_estimators = 100

# 랜덤 서치 횟수
num_epoch = 100

# %%
cv_cv = []
for cv_turn in range(27, 36, 2) : # 5, 7, 9, 11, 13, 15, 17, 19


# hyperparameter 탐색 결과가 저장될 리스트
    coarse_hyperparameters_list = []

    for epoch in range(num_epoch):
        # max depth의 값을 2~100으로 설정
        max_depth = np.random.randint(low=2, high=10)

        # 적용할 feature의 비율을 0.1~1.0로 설정
        max_features = np.random.uniform(low=0.1, high=1.0)

        model = RandomForestRegressor(n_estimators=n_estimators,
                                      max_depth=max_depth,
                                      max_features=max_features,
                                      n_jobs=-1,
                                      random_state=37)

        # cross_val_score를 실행하여 rmse의 평균 계산
        # cv는 데이터 조각 개수
        score = cross_val_score(model, X_train, Y_train, cv=cv_turn, scoring=rmse_score).mean() 

        # hyperparameter 탐색 결과를 저장할 딕셔너리
        hyperparameters = {
            'epoch': epoch,
            'score': score,
            'n_estimators': n_estimators,
            'max_depth': max_depth,
            'max_features': max_features,
            'cv' : cv_turn
        }

        # hyperparameter 탐색 결과 저장
        coarse_hyperparameters_list.append(hyperparameters)

        # hyperparameter 탐색 결과를 출력
        print(f"{epoch:2} n_estimators = {n_estimators}, max_depth = {max_depth:2}, max_features = {max_features:.6f}, Score = {score:.5f}, CV = {cv_turn}")

    # coarse_hyperparameters_list를 DataFrame으로 변환
    coarse_hyperparameters_list = pd.DataFrame.from_dict(coarse_hyperparameters_list)

    # coarse_hyperparameters_list를 score가 낮은 순으로 정렬
    coarse_hyperparameters_list = coarse_hyperparameters_list.sort_values(by="score")

    # coarse_hyperparameters_list의 상위 1개 저장
    cv_cv.append(coarse_hyperparameters_list.head(1))
# Out:
#  0 n_estimators = 100, max_depth =  5, max_features = 0.509878, Score = 1325695.48753, CV = 27
#  1 n_estimators = 100, max_depth =  8, max_features = 0.127115, Score = 1281109.04509, CV = 27
#  2 n_estimators = 100, max_depth =  7, max_features = 0.803308, Score = 1366464.20371, CV = 27
#  3 n_estimators = 100, max_depth =  3, max_features = 0.754579, Score = 1309221.80309, CV = 27
#  4 n_estimators = 100, max_depth =  4, max_features = 0.544358, Score = 1302641.26623, CV = 27
#  5 n_estimators = 100, max_depth =  4, max_features = 0.369654, Score = 1302376.31148, CV = 27
#  6 n_estimators = 100, max_depth =  2, max_features = 0.488633, Score = 1296731.61885, CV = 27
#  7 n_estimators = 100, max_depth =  4, max_features = 0.983320, Score = 1323776.82688, CV = 27
#  8 n_estimators = 100, max_depth =  6, max_features = 0.630222, Score = 1349240.69718, CV = 27
#  9 n_estimators = 100, max_depth =  4, max_features = 0.498273, Score = 1302641.26623, CV = 27
# 10 n_estimators = 100, max_depth =  4, max_features = 0.458481, Score = 1302641.26623, CV = 27
# 11 n_estimators = 100, max_depth =  2, max_features = 0.453169, Score = 1301338.32269, CV = 27
# 12 n_estimators = 100, max_depth =  9, max_features = 0.666264, Score = 1374790.49872, CV = 27
# 13 n_estimators = 100, max_depth =  2, max_features = 0.437332, Score = 1301338.32269, CV = 27
# 14 n_estimators = 100, max_depth =  2, max_features = 0.214604, Score = 1309493.38578, CV = 27
# 15 n_estimators = 100, max_depth =  5, max_features = 0.115901, Score = 1284353.16313, CV = 27
# 16 n_estimators = 100, max_depth =  5, max_features = 0.635855, Score = 1313414.14146, CV = 27
# 17 n_estimators = 100, max_depth =  3, max_features = 0.172337, Score = 1328328.69545, CV = 27
# 18 n_estimators = 100, max_depth =  7, max_features = 0.151457, Score = 1272491.88551, CV = 27
# 19 n_estimators = 100, max_depth =  3, max_features = 0.565859, Score = 1289700.66265, CV = 27
# 20 n_estimators = 100, max_depth =  2, max_features = 0.309700, Score = 1305332.92316, CV = 27
# 21 n_estimators = 100, max_depth =  3, max_features = 0.924104, Score = 1320606.08328, CV = 27
# 22 n_estimators = 100, max_depth =  6, max_features = 0.824923, Score = 1351518.95305, CV = 27
# 23 n_estimators = 100, max_depth =  2, max_features = 0.165050, Score = 1365526.28137, CV = 27
# 24 n_estimators = 100, max_depth =  9, max_features = 0.483897, Score = 1370102.21906, CV = 27
# 25 n_estimators = 100, max_depth =  5, max_features = 0.433708, Score = 1327217.75717, CV = 27
# 26 n_estimators = 100, max_depth =  7, max_features = 0.150391, Score = 1272491.88551, CV = 27
# 27 n_estimators = 100, max_depth =  4, max_features = 0.269948, Score = 1296613.84999, CV = 27
# 28 n_estimators = 100, max_depth =  4, max_features = 0.526455, Score = 1302641.26623, CV = 27
# 29 n_estimators = 100, max_depth =  2, max_features = 0.725830, Score = 1301297.45411, CV = 27
# 30 n_estimators = 100, max_depth =  6, max_features = 0.480875, Score = 1333298.11534, CV = 27
# 31 n_estimators = 100, max_depth =  3, max_features = 0.251352, Score = 1286170.18701, CV = 27
# 32 n_estimators = 100, max_depth =  2, max_features = 0.317645, Score = 1305332.92316, CV = 27
# 33 n_estimators = 100, max_depth =  4, max_features = 0.866331, Score = 1318746.29997, CV = 27
# 34 n_estimators = 100, max_depth =  4, max_features = 0.928359, Score = 1323776.82688, CV = 27
# 35 n_estimators = 100, max_depth =  7, max_features = 0.913473, Score = 1375522.74230, CV = 27
# 36 n_estimators = 100, max_depth =  2, max_features = 0.648131, Score = 1301297.45411, CV = 27
# 37 n_estimators = 100, max_depth =  5, max_features = 0.306110, Score = 1304460.41510, CV = 27
# 38 n_estimators = 100, max_depth =  8, max_features = 0.815015, Score = 1378742.81141, CV = 27
# 39 n_estimators = 100, max_depth =  2, max_features = 0.522459, Score = 1296731.61885, CV = 27
# 40 n_estimators = 100, max_depth =  9, max_features = 0.868450, Score = 1386075.48816, CV = 27
# 41 n_estimators = 100, max_depth =  9, max_features = 0.783145, Score = 1379685.02316, CV = 27
# 42 n_estimators = 100, max_depth =  4, max_features = 0.902751, Score = 1318746.29997, CV = 27
# 43 n_estimators = 100, max_depth =  9, max_features = 0.174837, Score = 1285809.47482, CV = 27
# 44 n_estimators = 100, max_depth =  9, max_features = 0.449937, Score = 1342025.82729, CV = 27
# 45 n_estimators = 100, max_depth =  4, max_features = 0.637546, Score = 1305951.66676, CV = 27
# 46 n_estimators = 100, max_depth =  2, max_features = 0.988633, Score = 1307238.09225, CV = 27
# 47 n_estimators = 100, max_depth =  4, max_features = 0.727147, Score = 1305951.66676, CV = 27
# 48 n_estimators = 100, max_depth =  3, max_features = 0.859565, Score = 1310003.55313, CV = 27
# 49 n_estimators = 100, max_depth =  2, max_features = 0.886666, Score = 1303459.31051, CV = 27
# 50 n_estimators = 100, max_depth =  8, max_features = 0.567423, Score = 1359104.05732, CV = 27
# 51 n_estimators = 100, max_depth =  8, max_features = 0.811371, Score = 1378742.81141, CV = 27
# 52 n_estimators = 100, max_depth =  5, max_features = 0.390535, Score = 1327217.75717, CV = 27
# 53 n_estimators = 100, max_depth =  2, max_features = 0.638920, Score = 1301297.45411, CV = 27
# 54 n_estimators = 100, max_depth =  3, max_features = 0.214529, Score = 1286170.18701, CV = 27
# 55 n_estimators = 100, max_depth =  9, max_features = 0.877516, Score = 1386075.48816, CV = 27
# 56 n_estimators = 100, max_depth =  5, max_features = 0.338764, Score = 1304460.41510, CV = 27
# 57 n_estimators = 100, max_depth =  6, max_features = 0.866646, Score = 1351518.95305, CV = 27
# 58 n_estimators = 100, max_depth =  8, max_features = 0.426917, Score = 1345729.71667, CV = 27
# 59 n_estimators = 100, max_depth =  3, max_features = 0.991005, Score = 1320606.08328, CV = 27
# 60 n_estimators = 100, max_depth =  5, max_features = 0.221966, Score = 1267566.08883, CV = 27
# 61 n_estimators = 100, max_depth =  3, max_features = 0.883985, Score = 1310003.55313, CV = 27
# 62 n_estimators = 100, max_depth =  4, max_features = 0.132299, Score = 1303322.35693, CV = 27
# 63 n_estimators = 100, max_depth =  6, max_features = 0.815233, Score = 1343921.21009, CV = 27
# 64 n_estimators = 100, max_depth =  7, max_features = 0.950043, Score = 1375522.74230, CV = 27
# 65 n_estimators = 100, max_depth =  3, max_features = 0.180101, Score = 1328328.69545, CV = 27
# 66 n_estimators = 100, max_depth =  5, max_features = 0.405834, Score = 1327217.75717, CV = 27
# 67 n_estimators = 100, max_depth =  5, max_features = 0.395820, Score = 1327217.75717, CV = 27
# 68 n_estimators = 100, max_depth =  4, max_features = 0.938249, Score = 1323776.82688, CV = 27
# 69 n_estimators = 100, max_depth =  7, max_features = 0.464800, Score = 1332726.97367, CV = 27
# 70 n_estimators = 100, max_depth =  4, max_features = 0.281154, Score = 1290925.81208, CV = 27
# 71 n_estimators = 100, max_depth =  9, max_features = 0.329326, Score = 1320147.31614, CV = 27
# 72 n_estimators = 100, max_depth =  9, max_features = 0.317324, Score = 1320147.31614, CV = 27
# 73 n_estimators = 100, max_depth =  3, max_features = 0.190499, Score = 1286170.18701, CV = 27
# 74 n_estimators = 100, max_depth =  4, max_features = 0.902774, Score = 1318746.29997, CV = 27
# 75 n_estimators = 100, max_depth =  7, max_features = 0.909729, Score = 1375522.74230, CV = 27
# 76 n_estimators = 100, max_depth =  6, max_features = 0.351400, Score = 1310626.74715, CV = 27
# 77 n_estimators = 100, max_depth =  3, max_features = 0.741648, Score = 1309221.80309, CV = 27
# 78 n_estimators = 100, max_depth =  6, max_features = 0.530214, Score = 1333298.11534, CV = 27
# 79 n_estimators = 100, max_depth =  2, max_features = 0.326915, Score = 1305332.92316, CV = 27
# 80 n_estimators = 100, max_depth =  9, max_features = 0.860385, Score = 1386075.48816, CV = 27
# 81 n_estimators = 100, max_depth =  4, max_features = 0.102319, Score = 1303322.35693, CV = 27
# 82 n_estimators = 100, max_depth =  2, max_features = 0.931719, Score = 1307238.09225, CV = 27
# 83 n_estimators = 100, max_depth =  9, max_features = 0.405018, Score = 1342025.82729, CV = 27
# 84 n_estimators = 100, max_depth =  8, max_features = 0.474981, Score = 1340538.31632, CV = 27
# 85 n_estimators = 100, max_depth =  6, max_features = 0.733939, Score = 1343921.21009, CV = 27
# 86 n_estimators = 100, max_depth =  7, max_features = 0.974826, Score = 1375522.74230, CV = 27
# 87 n_estimators = 100, max_depth =  9, max_features = 0.521090, Score = 1370102.21906, CV = 27
# 88 n_estimators = 100, max_depth =  6, max_features = 0.963370, Score = 1361834.88721, CV = 27
# 89 n_estimators = 100, max_depth =  8, max_features = 0.215690, Score = 1311723.68964, CV = 27
# 90 n_estimators = 100, max_depth =  8, max_features = 0.206673, Score = 1311723.68964, CV = 27
# 91 n_estimators = 100, max_depth =  6, max_features = 0.723667, Score = 1358743.19192, CV = 27
# 92 n_estimators = 100, max_depth =  6, max_features = 0.381862, Score = 1307298.46729, CV = 27
# 93 n_estimators = 100, max_depth =  6, max_features = 0.438002, Score = 1307298.46729, CV = 27
# 94 n_estimators = 100, max_depth =  9, max_features = 0.246318, Score = 1293461.15986, CV = 27
# 95 n_estimators = 100, max_depth =  6, max_features = 0.530163, Score = 1333298.11534, CV = 27
# 96 n_estimators = 100, max_depth =  3, max_features = 0.912272, Score = 1320606.08328, CV = 27
# 97 n_estimators = 100, max_depth =  9, max_features = 0.819801, Score = 1386075.48816, CV = 27
# 98 n_estimators = 100, max_depth =  9, max_features = 0.364743, Score = 1342025.82729, CV = 27
# 99 n_estimators = 100, max_depth =  7, max_features = 0.157360, Score = 1272491.88551, CV = 27
#  0 n_estimators = 100, max_depth =  4, max_features = 0.460087, Score = 1260996.90477, CV = 29
#  1 n_estimators = 100, max_depth =  4, max_features = 0.723182, Score = 1276955.50144, CV = 29
#  2 n_estimators = 100, max_depth =  3, max_features = 0.668979, Score = 1258163.41859, CV = 29
#  3 n_estimators = 100, max_depth =  7, max_features = 0.746564, Score = 1333997.09398, CV = 29
#  4 n_estimators = 100, max_depth =  5, max_features = 0.931774, Score = 1293611.66895, CV = 29
#  5 n_estimators = 100, max_depth =  3, max_features = 0.738087, Score = 1263120.64817, CV = 29
#  6 n_estimators = 100, max_depth =  7, max_features = 0.499876, Score = 1301614.92489, CV = 29
#  7 n_estimators = 100, max_depth =  6, max_features = 0.728630, Score = 1303771.70180, CV = 29
#  8 n_estimators = 100, max_depth =  3, max_features = 0.250395, Score = 1267357.89088, CV = 29
#  9 n_estimators = 100, max_depth =  5, max_features = 0.482202, Score = 1282939.02966, CV = 29
# 10 n_estimators = 100, max_depth =  2, max_features = 0.829991, Score = 1274906.21747, CV = 29
# 11 n_estimators = 100, max_depth =  3, max_features = 0.833659, Score = 1263976.17165, CV = 29
# 12 n_estimators = 100, max_depth =  5, max_features = 0.135637, Score = 1257864.88683, CV = 29
# 13 n_estimators = 100, max_depth =  8, max_features = 0.999881, Score = 1334796.29407, CV = 29
# 14 n_estimators = 100, max_depth =  3, max_features = 0.806065, Score = 1263120.64817, CV = 29
# 15 n_estimators = 100, max_depth =  5, max_features = 0.353935, Score = 1262819.04734, CV = 29
# 16 n_estimators = 100, max_depth =  7, max_features = 0.182719, Score = 1259159.01618, CV = 29
# 17 n_estimators = 100, max_depth =  3, max_features = 0.612816, Score = 1259885.23832, CV = 29
# 18 n_estimators = 100, max_depth =  6, max_features = 0.896887, Score = 1307064.41934, CV = 29
# 19 n_estimators = 100, max_depth =  2, max_features = 0.245107, Score = 1289412.77044, CV = 29
# 20 n_estimators = 100, max_depth =  7, max_features = 0.648442, Score = 1313940.63929, CV = 29
# 21 n_estimators = 100, max_depth =  6, max_features = 0.613690, Score = 1289417.51430, CV = 29
# 22 n_estimators = 100, max_depth =  6, max_features = 0.361474, Score = 1267413.63334, CV = 29
# 23 n_estimators = 100, max_depth =  9, max_features = 0.441843, Score = 1333030.11289, CV = 29
# 24 n_estimators = 100, max_depth =  9, max_features = 0.405859, Score = 1333030.11289, CV = 29
# 25 n_estimators = 100, max_depth =  8, max_features = 0.116668, Score = 1246764.43875, CV = 29
# 26 n_estimators = 100, max_depth =  9, max_features = 0.708676, Score = 1330853.19475, CV = 29
# 27 n_estimators = 100, max_depth =  2, max_features = 0.102074, Score = 1348597.50903, CV = 29
# 28 n_estimators = 100, max_depth =  3, max_features = 0.153775, Score = 1305338.01857, CV = 29
# 29 n_estimators = 100, max_depth =  6, max_features = 0.165809, Score = 1265572.22308, CV = 29
# 30 n_estimators = 100, max_depth =  9, max_features = 0.711331, Score = 1330853.19475, CV = 29
# 31 n_estimators = 100, max_depth =  6, max_features = 0.479010, Score = 1276222.81074, CV = 29
# 32 n_estimators = 100, max_depth =  8, max_features = 0.367283, Score = 1300676.48351, CV = 29
# 33 n_estimators = 100, max_depth =  5, max_features = 0.402305, Score = 1273304.73295, CV = 29
# 34 n_estimators = 100, max_depth =  7, max_features = 0.416369, Score = 1287373.93046, CV = 29
# 35 n_estimators = 100, max_depth =  4, max_features = 0.159952, Score = 1262585.23881, CV = 29
# 36 n_estimators = 100, max_depth =  9, max_features = 0.974026, Score = 1353082.84087, CV = 29
# 37 n_estimators = 100, max_depth =  3, max_features = 0.170729, Score = 1305338.01857, CV = 29
# 38 n_estimators = 100, max_depth =  6, max_features = 0.371086, Score = 1273137.46624, CV = 29
# 39 n_estimators = 100, max_depth =  2, max_features = 0.828824, Score = 1274906.21747, CV = 29
# 40 n_estimators = 100, max_depth =  7, max_features = 0.871723, Score = 1327226.50824, CV = 29
# 41 n_estimators = 100, max_depth =  3, max_features = 0.337522, Score = 1254311.52610, CV = 29
# 42 n_estimators = 100, max_depth =  5, max_features = 0.106354, Score = 1257864.88683, CV = 29
# 43 n_estimators = 100, max_depth =  7, max_features = 0.197275, Score = 1259159.01618, CV = 29
# 44 n_estimators = 100, max_depth =  6, max_features = 0.358614, Score = 1267413.63334, CV = 29
# 45 n_estimators = 100, max_depth =  5, max_features = 0.696211, Score = 1297836.95350, CV = 29
# 46 n_estimators = 100, max_depth =  7, max_features = 0.933497, Score = 1332311.19633, CV = 29
# 47 n_estimators = 100, max_depth =  4, max_features = 0.122415, Score = 1262585.23881, CV = 29
# 48 n_estimators = 100, max_depth =  4, max_features = 0.640710, Score = 1276955.50144, CV = 29
# 49 n_estimators = 100, max_depth =  7, max_features = 0.512248, Score = 1301614.92489, CV = 29
# 50 n_estimators = 100, max_depth =  5, max_features = 0.218229, Score = 1249968.44620, CV = 29
# 51 n_estimators = 100, max_depth =  2, max_features = 0.523311, Score = 1260831.81881, CV = 29
# 52 n_estimators = 100, max_depth =  8, max_features = 0.346868, Score = 1280627.18171, CV = 29
# 53 n_estimators = 100, max_depth =  2, max_features = 0.681870, Score = 1264369.73800, CV = 29
# 54 n_estimators = 100, max_depth =  7, max_features = 0.117600, Score = 1246747.18031, CV = 29
# 55 n_estimators = 100, max_depth =  4, max_features = 0.328426, Score = 1256632.15991, CV = 29
# 56 n_estimators = 100, max_depth =  7, max_features = 0.670990, Score = 1313940.63929, CV = 29
# 57 n_estimators = 100, max_depth =  8, max_features = 0.695622, Score = 1327528.80608, CV = 29
# 58 n_estimators = 100, max_depth =  8, max_features = 0.226486, Score = 1253951.14701, CV = 29
# 59 n_estimators = 100, max_depth =  4, max_features = 0.758877, Score = 1268445.94179, CV = 29
# 60 n_estimators = 100, max_depth =  8, max_features = 0.570347, Score = 1324000.27535, CV = 29
# 61 n_estimators = 100, max_depth =  6, max_features = 0.821550, Score = 1307064.41934, CV = 29
# 62 n_estimators = 100, max_depth =  8, max_features = 0.913581, Score = 1334796.29407, CV = 29
# 63 n_estimators = 100, max_depth =  9, max_features = 0.811966, Score = 1337361.86530, CV = 29
# 64 n_estimators = 100, max_depth =  3, max_features = 0.633808, Score = 1259885.23832, CV = 29
# 65 n_estimators = 100, max_depth =  4, max_features = 0.990981, Score = 1283764.96612, CV = 29
# 66 n_estimators = 100, max_depth =  3, max_features = 0.633849, Score = 1259885.23832, CV = 29
# 67 n_estimators = 100, max_depth =  6, max_features = 0.965185, Score = 1314138.55384, CV = 29
# 68 n_estimators = 100, max_depth =  3, max_features = 0.777971, Score = 1263120.64817, CV = 29
# 69 n_estimators = 100, max_depth =  8, max_features = 0.923881, Score = 1334796.29407, CV = 29
# 70 n_estimators = 100, max_depth =  8, max_features = 0.647630, Score = 1327528.80608, CV = 29
# 71 n_estimators = 100, max_depth =  8, max_features = 0.115422, Score = 1246764.43875, CV = 29
# 72 n_estimators = 100, max_depth =  6, max_features = 0.745762, Score = 1303771.70180, CV = 29
# 73 n_estimators = 100, max_depth =  7, max_features = 0.743458, Score = 1333997.09398, CV = 29
# 74 n_estimators = 100, max_depth =  5, max_features = 0.404324, Score = 1273304.73295, CV = 29
# 75 n_estimators = 100, max_depth =  2, max_features = 0.996799, Score = 1275429.37831, CV = 29
# 76 n_estimators = 100, max_depth =  9, max_features = 0.407121, Score = 1333030.11289, CV = 29
# 77 n_estimators = 100, max_depth =  8, max_features = 0.232042, Score = 1253951.14701, CV = 29
# 78 n_estimators = 100, max_depth =  2, max_features = 0.926369, Score = 1275429.37831, CV = 29
# 79 n_estimators = 100, max_depth =  6, max_features = 0.152489, Score = 1265572.22308, CV = 29
# 80 n_estimators = 100, max_depth =  9, max_features = 0.877073, Score = 1346614.88957, CV = 29
# 81 n_estimators = 100, max_depth =  6, max_features = 0.233670, Score = 1255456.23439, CV = 29
# 82 n_estimators = 100, max_depth =  8, max_features = 0.916982, Score = 1334796.29407, CV = 29
# 83 n_estimators = 100, max_depth =  8, max_features = 0.395373, Score = 1300676.48351, CV = 29
# 84 n_estimators = 100, max_depth =  9, max_features = 0.108615, Score = 1250080.74910, CV = 29
# 85 n_estimators = 100, max_depth =  4, max_features = 0.769976, Score = 1268445.94179, CV = 29
# 86 n_estimators = 100, max_depth =  4, max_features = 0.789868, Score = 1268445.94179, CV = 29
# 87 n_estimators = 100, max_depth =  6, max_features = 0.727323, Score = 1303771.70180, CV = 29
# 88 n_estimators = 100, max_depth =  2, max_features = 0.181483, Score = 1348597.50903, CV = 29
# 89 n_estimators = 100, max_depth =  6, max_features = 0.435164, Score = 1273137.46624, CV = 29
# 90 n_estimators = 100, max_depth =  8, max_features = 0.151653, Score = 1246764.43875, CV = 29
# 91 n_estimators = 100, max_depth =  7, max_features = 0.853143, Score = 1327226.50824, CV = 29
# 92 n_estimators = 100, max_depth =  4, max_features = 0.276891, Score = 1256632.15991, CV = 29
# 93 n_estimators = 100, max_depth =  5, max_features = 0.785681, Score = 1288335.36341, CV = 29
# 94 n_estimators = 100, max_depth =  9, max_features = 0.509303, Score = 1304203.52711, CV = 29
# 95 n_estimators = 100, max_depth =  8, max_features = 0.558382, Score = 1324000.27535, CV = 29
# 96 n_estimators = 100, max_depth =  8, max_features = 0.330196, Score = 1280627.18171, CV = 29
# 97 n_estimators = 100, max_depth =  6, max_features = 0.262389, Score = 1255456.23439, CV = 29
# 98 n_estimators = 100, max_depth =  8, max_features = 0.463409, Score = 1335637.01101, CV = 29
# 99 n_estimators = 100, max_depth =  5, max_features = 0.517627, Score = 1282939.02966, CV = 29
#  0 n_estimators = 100, max_depth =  5, max_features = 0.600117, Score = 1281085.21173, CV = 31
#  1 n_estimators = 100, max_depth =  5, max_features = 0.904082, Score = 1312961.15411, CV = 31
#  2 n_estimators = 100, max_depth =  6, max_features = 0.706098, Score = 1312761.76395, CV = 31
#  3 n_estimators = 100, max_depth =  8, max_features = 0.948791, Score = 1341857.10794, CV = 31
#  4 n_estimators = 100, max_depth =  5, max_features = 0.948276, Score = 1308988.50281, CV = 31
#  5 n_estimators = 100, max_depth =  7, max_features = 0.669701, Score = 1327253.86884, CV = 31
#  6 n_estimators = 100, max_depth =  8, max_features = 0.604807, Score = 1338349.15365, CV = 31
#  7 n_estimators = 100, max_depth =  5, max_features = 0.523173, Score = 1290299.62981, CV = 31
#  8 n_estimators = 100, max_depth =  3, max_features = 0.620923, Score = 1285465.90932, CV = 31
#  9 n_estimators = 100, max_depth =  6, max_features = 0.761134, Score = 1308568.11854, CV = 31
# 10 n_estimators = 100, max_depth =  4, max_features = 0.592219, Score = 1278078.17664, CV = 31
# 11 n_estimators = 100, max_depth =  2, max_features = 0.940444, Score = 1315227.00308, CV = 31
# 12 n_estimators = 100, max_depth =  8, max_features = 0.147414, Score = 1262915.63975, CV = 31
# 13 n_estimators = 100, max_depth =  2, max_features = 0.834207, Score = 1309376.84594, CV = 31
# 14 n_estimators = 100, max_depth =  5, max_features = 0.682560, Score = 1308699.61290, CV = 31
# 15 n_estimators = 100, max_depth =  9, max_features = 0.820453, Score = 1347934.54856, CV = 31
# 16 n_estimators = 100, max_depth =  5, max_features = 0.210376, Score = 1271857.50336, CV = 31
# 17 n_estimators = 100, max_depth =  9, max_features = 0.142936, Score = 1259830.45652, CV = 31
# 18 n_estimators = 100, max_depth =  2, max_features = 0.831214, Score = 1309376.84594, CV = 31
# 19 n_estimators = 100, max_depth =  5, max_features = 0.294654, Score = 1282583.25173, CV = 31
# 20 n_estimators = 100, max_depth =  8, max_features = 0.220239, Score = 1282781.41353, CV = 31
# 21 n_estimators = 100, max_depth =  8, max_features = 0.127672, Score = 1262915.63975, CV = 31
# 22 n_estimators = 100, max_depth =  5, max_features = 0.748292, Score = 1301312.25955, CV = 31
# 23 n_estimators = 100, max_depth =  4, max_features = 0.454416, Score = 1279908.46186, CV = 31
# 24 n_estimators = 100, max_depth =  5, max_features = 0.957056, Score = 1308988.50281, CV = 31
# 25 n_estimators = 100, max_depth =  7, max_features = 0.685298, Score = 1327253.86884, CV = 31
# 26 n_estimators = 100, max_depth =  9, max_features = 0.969836, Score = 1363535.20101, CV = 31
# 27 n_estimators = 100, max_depth =  4, max_features = 0.233783, Score = 1288913.99012, CV = 31
# 28 n_estimators = 100, max_depth =  8, max_features = 0.480785, Score = 1323028.52384, CV = 31
# 29 n_estimators = 100, max_depth =  7, max_features = 0.887305, Score = 1341461.29081, CV = 31
# 30 n_estimators = 100, max_depth =  4, max_features = 0.917249, Score = 1308634.35723, CV = 31
# 31 n_estimators = 100, max_depth =  8, max_features = 0.942493, Score = 1341857.10794, CV = 31
# 32 n_estimators = 100, max_depth =  4, max_features = 0.144171, Score = 1299831.05488, CV = 31
# 33 n_estimators = 100, max_depth =  5, max_features = 0.282066, Score = 1282583.25173, CV = 31
# 34 n_estimators = 100, max_depth =  5, max_features = 0.378362, Score = 1293033.08447, CV = 31
# 35 n_estimators = 100, max_depth =  5, max_features = 0.348086, Score = 1282583.25173, CV = 31
# 36 n_estimators = 100, max_depth =  2, max_features = 0.154170, Score = 1376707.81149, CV = 31
# 37 n_estimators = 100, max_depth =  8, max_features = 0.423542, Score = 1317670.46484, CV = 31
# 38 n_estimators = 100, max_depth =  8, max_features = 0.212210, Score = 1282781.41353, CV = 31
# 39 n_estimators = 100, max_depth =  9, max_features = 0.537230, Score = 1324469.08389, CV = 31
# 40 n_estimators = 100, max_depth =  5, max_features = 0.523340, Score = 1290299.62981, CV = 31
# 41 n_estimators = 100, max_depth =  6, max_features = 0.757800, Score = 1308568.11854, CV = 31
# 42 n_estimators = 100, max_depth =  8, max_features = 0.104283, Score = 1262915.63975, CV = 31
# 43 n_estimators = 100, max_depth =  7, max_features = 0.228720, Score = 1297103.50872, CV = 31
# 44 n_estimators = 100, max_depth =  2, max_features = 0.953410, Score = 1315227.00308, CV = 31
# 45 n_estimators = 100, max_depth =  3, max_features = 0.893057, Score = 1297131.28189, CV = 31
# 46 n_estimators = 100, max_depth =  6, max_features = 0.436018, Score = 1306307.44646, CV = 31
# 47 n_estimators = 100, max_depth =  2, max_features = 0.607321, Score = 1301692.21640, CV = 31
# 48 n_estimators = 100, max_depth =  9, max_features = 0.451364, Score = 1336109.38798, CV = 31
# 49 n_estimators = 100, max_depth =  9, max_features = 0.840118, Score = 1347934.54856, CV = 31
# 50 n_estimators = 100, max_depth =  9, max_features = 0.719986, Score = 1331237.51934, CV = 31
# 51 n_estimators = 100, max_depth =  8, max_features = 0.373506, Score = 1317670.46484, CV = 31
# 52 n_estimators = 100, max_depth =  6, max_features = 0.749683, Score = 1308568.11854, CV = 31
# 53 n_estimators = 100, max_depth =  4, max_features = 0.851603, Score = 1296350.98008, CV = 31
# 54 n_estimators = 100, max_depth =  8, max_features = 0.765666, Score = 1337073.83588, CV = 31
# 55 n_estimators = 100, max_depth =  3, max_features = 0.890997, Score = 1297131.28189, CV = 31
# 56 n_estimators = 100, max_depth =  3, max_features = 0.605642, Score = 1285465.90932, CV = 31
# 57 n_estimators = 100, max_depth =  7, max_features = 0.520738, Score = 1316840.27666, CV = 31
# 58 n_estimators = 100, max_depth =  6, max_features = 0.820889, Score = 1314073.71769, CV = 31
# 59 n_estimators = 100, max_depth =  4, max_features = 0.298260, Score = 1276562.76122, CV = 31
# 60 n_estimators = 100, max_depth =  8, max_features = 0.198227, Score = 1282781.41353, CV = 31
# 61 n_estimators = 100, max_depth =  9, max_features = 0.328982, Score = 1305329.26460, CV = 31
# 62 n_estimators = 100, max_depth =  6, max_features = 0.832604, Score = 1314073.71769, CV = 31
# 63 n_estimators = 100, max_depth =  2, max_features = 0.160584, Score = 1376707.81149, CV = 31
# 64 n_estimators = 100, max_depth =  5, max_features = 0.213008, Score = 1271857.50336, CV = 31
# 65 n_estimators = 100, max_depth =  9, max_features = 0.445805, Score = 1336109.38798, CV = 31
# 66 n_estimators = 100, max_depth =  4, max_features = 0.883636, Score = 1296350.98008, CV = 31
# 67 n_estimators = 100, max_depth =  6, max_features = 0.484503, Score = 1305406.05898, CV = 31
# 68 n_estimators = 100, max_depth =  6, max_features = 0.524694, Score = 1305406.05898, CV = 31
# 69 n_estimators = 100, max_depth =  5, max_features = 0.554337, Score = 1281085.21173, CV = 31
# 70 n_estimators = 100, max_depth =  2, max_features = 0.120180, Score = 1376707.81149, CV = 31
# 71 n_estimators = 100, max_depth =  8, max_features = 0.549343, Score = 1338349.15365, CV = 31
# 72 n_estimators = 100, max_depth =  3, max_features = 0.632142, Score = 1285465.90932, CV = 31
# 73 n_estimators = 100, max_depth =  5, max_features = 0.173984, Score = 1277251.01561, CV = 31
# 74 n_estimators = 100, max_depth =  4, max_features = 0.618780, Score = 1278078.17664, CV = 31
# 75 n_estimators = 100, max_depth =  5, max_features = 0.982079, Score = 1308988.50281, CV = 31
# 76 n_estimators = 100, max_depth =  8, max_features = 0.467602, Score = 1323028.52384, CV = 31
# 77 n_estimators = 100, max_depth =  7, max_features = 0.243099, Score = 1297103.50872, CV = 31
# 78 n_estimators = 100, max_depth =  7, max_features = 0.280136, Score = 1291253.51125, CV = 31
# 79 n_estimators = 100, max_depth =  3, max_features = 0.942673, Score = 1302886.11050, CV = 31
# 80 n_estimators = 100, max_depth =  4, max_features = 0.257261, Score = 1288913.99012, CV = 31
# 81 n_estimators = 100, max_depth =  4, max_features = 0.622350, Score = 1278078.17664, CV = 31
# 82 n_estimators = 100, max_depth =  6, max_features = 0.542732, Score = 1305406.05898, CV = 31
# 83 n_estimators = 100, max_depth =  6, max_features = 0.995272, Score = 1325285.17590, CV = 31
# 84 n_estimators = 100, max_depth =  2, max_features = 0.661273, Score = 1300218.24561, CV = 31
# 85 n_estimators = 100, max_depth =  5, max_features = 0.931619, Score = 1308988.50281, CV = 31
# 86 n_estimators = 100, max_depth =  5, max_features = 0.659854, Score = 1308699.61290, CV = 31
# 87 n_estimators = 100, max_depth =  2, max_features = 0.812080, Score = 1307040.29865, CV = 31
# 88 n_estimators = 100, max_depth =  4, max_features = 0.373681, Score = 1279908.46186, CV = 31
# 89 n_estimators = 100, max_depth =  3, max_features = 0.966275, Score = 1302886.11050, CV = 31
# 90 n_estimators = 100, max_depth =  8, max_features = 0.716584, Score = 1323943.31356, CV = 31
# 91 n_estimators = 100, max_depth =  5, max_features = 0.443562, Score = 1293033.08447, CV = 31
# 92 n_estimators = 100, max_depth =  7, max_features = 0.851646, Score = 1341461.29081, CV = 31
# 93 n_estimators = 100, max_depth =  3, max_features = 0.318101, Score = 1283691.82887, CV = 31
# 94 n_estimators = 100, max_depth =  3, max_features = 0.697711, Score = 1283373.73761, CV = 31
# 95 n_estimators = 100, max_depth =  3, max_features = 0.184679, Score = 1291711.17096, CV = 31
# 96 n_estimators = 100, max_depth =  7, max_features = 0.723382, Score = 1327253.86884, CV = 31
# 97 n_estimators = 100, max_depth =  7, max_features = 0.307663, Score = 1291253.51125, CV = 31
# 98 n_estimators = 100, max_depth =  3, max_features = 0.577881, Score = 1285465.90932, CV = 31
# 99 n_estimators = 100, max_depth =  7, max_features = 0.904873, Score = 1341461.29081, CV = 31
#  0 n_estimators = 100, max_depth =  6, max_features = 0.575059, Score = 1296718.28303, CV = 33
#  1 n_estimators = 100, max_depth =  2, max_features = 0.197180, Score = 1274463.21777, CV = 33
#  2 n_estimators = 100, max_depth =  7, max_features = 0.192255, Score = 1256199.00852, CV = 33
#  3 n_estimators = 100, max_depth =  5, max_features = 0.690528, Score = 1288549.60623, CV = 33
#  4 n_estimators = 100, max_depth =  3, max_features = 0.851778, Score = 1276443.02565, CV = 33
#  5 n_estimators = 100, max_depth =  6, max_features = 0.343149, Score = 1279614.73851, CV = 33
#  6 n_estimators = 100, max_depth =  9, max_features = 0.218911, Score = 1267953.55490, CV = 33
#  7 n_estimators = 100, max_depth =  7, max_features = 0.988838, Score = 1353602.57103, CV = 33
#  8 n_estimators = 100, max_depth =  8, max_features = 0.947206, Score = 1355716.72394, CV = 33
#  9 n_estimators = 100, max_depth =  8, max_features = 0.443051, Score = 1305044.56299, CV = 33
# 10 n_estimators = 100, max_depth =  8, max_features = 0.544387, Score = 1317424.42356, CV = 33
# 11 n_estimators = 100, max_depth =  4, max_features = 0.782866, Score = 1281910.63540, CV = 33
# 12 n_estimators = 100, max_depth =  9, max_features = 0.847710, Score = 1358120.74494, CV = 33
# 13 n_estimators = 100, max_depth =  4, max_features = 0.515678, Score = 1256337.08710, CV = 33
# 14 n_estimators = 100, max_depth =  8, max_features = 0.252181, Score = 1249285.75680, CV = 33
# 15 n_estimators = 100, max_depth =  4, max_features = 0.712191, Score = 1284129.41788, CV = 33
# 16 n_estimators = 100, max_depth =  3, max_features = 0.626454, Score = 1266971.74049, CV = 33
# 17 n_estimators = 100, max_depth =  9, max_features = 0.572982, Score = 1319099.31840, CV = 33
# 18 n_estimators = 100, max_depth =  3, max_features = 0.451931, Score = 1256299.85184, CV = 33
# 19 n_estimators = 100, max_depth =  7, max_features = 0.388903, Score = 1305772.04029, CV = 33
# 20 n_estimators = 100, max_depth =  5, max_features = 0.692034, Score = 1288549.60623, CV = 33
# 21 n_estimators = 100, max_depth =  9, max_features = 0.148485, Score = 1256229.58968, CV = 33
# 22 n_estimators = 100, max_depth =  3, max_features = 0.522851, Score = 1253332.92646, CV = 33
# 23 n_estimators = 100, max_depth =  4, max_features = 0.544342, Score = 1256337.08710, CV = 33
# 24 n_estimators = 100, max_depth =  8, max_features = 0.473274, Score = 1317424.42356, CV = 33
# 25 n_estimators = 100, max_depth =  9, max_features = 0.747503, Score = 1332073.24947, CV = 33
# 26 n_estimators = 100, max_depth =  2, max_features = 0.418870, Score = 1264384.98919, CV = 33
# 27 n_estimators = 100, max_depth =  7, max_features = 0.905221, Score = 1341208.09817, CV = 33
# 28 n_estimators = 100, max_depth =  2, max_features = 0.772271, Score = 1279748.78263, CV = 33
# 29 n_estimators = 100, max_depth =  3, max_features = 0.545546, Score = 1266971.74049, CV = 33
# 30 n_estimators = 100, max_depth =  7, max_features = 0.959923, Score = 1353602.57103, CV = 33
# 31 n_estimators = 100, max_depth =  5, max_features = 0.578300, Score = 1285968.12654, CV = 33
# 32 n_estimators = 100, max_depth =  7, max_features = 0.677140, Score = 1321021.67336, CV = 33
# 33 n_estimators = 100, max_depth =  4, max_features = 0.320575, Score = 1245699.04129, CV = 33
# 34 n_estimators = 100, max_depth =  2, max_features = 0.865832, Score = 1281420.32385, CV = 33
# 35 n_estimators = 100, max_depth =  8, max_features = 0.715296, Score = 1333205.47040, CV = 33
# 36 n_estimators = 100, max_depth =  6, max_features = 0.495858, Score = 1307279.86108, CV = 33
# 37 n_estimators = 100, max_depth =  5, max_features = 0.700734, Score = 1288549.60623, CV = 33
# 38 n_estimators = 100, max_depth =  8, max_features = 0.251380, Score = 1249285.75680, CV = 33
# 39 n_estimators = 100, max_depth =  4, max_features = 0.834349, Score = 1280468.81923, CV = 33
# 40 n_estimators = 100, max_depth =  6, max_features = 0.987494, Score = 1328914.62115, CV = 33
# 41 n_estimators = 100, max_depth =  2, max_features = 0.227865, Score = 1274463.21777, CV = 33
# 42 n_estimators = 100, max_depth =  6, max_features = 0.797189, Score = 1323252.57793, CV = 33
# 43 n_estimators = 100, max_depth =  3, max_features = 0.133820, Score = 1287813.41290, CV = 33
# 44 n_estimators = 100, max_depth =  8, max_features = 0.161400, Score = 1243240.80852, CV = 33
# 45 n_estimators = 100, max_depth =  5, max_features = 0.971128, Score = 1310921.69709, CV = 33
# 46 n_estimators = 100, max_depth =  7, max_features = 0.583224, Score = 1320995.05879, CV = 33
# 47 n_estimators = 100, max_depth =  9, max_features = 0.897567, Score = 1358120.74494, CV = 33
# 48 n_estimators = 100, max_depth =  5, max_features = 0.108224, Score = 1250081.28961, CV = 33
# 49 n_estimators = 100, max_depth =  9, max_features = 0.361902, Score = 1299165.12864, CV = 33
# 50 n_estimators = 100, max_depth =  4, max_features = 0.186818, Score = 1244136.16291, CV = 33
# 51 n_estimators = 100, max_depth =  5, max_features = 0.529432, Score = 1295755.60739, CV = 33
# 52 n_estimators = 100, max_depth =  5, max_features = 0.733720, Score = 1299846.09778, CV = 33
# 53 n_estimators = 100, max_depth =  7, max_features = 0.263430, Score = 1256199.00852, CV = 33
# 54 n_estimators = 100, max_depth =  7, max_features = 0.386467, Score = 1305772.04029, CV = 33
# 55 n_estimators = 100, max_depth =  9, max_features = 0.535032, Score = 1323601.30685, CV = 33
# 56 n_estimators = 100, max_depth =  4, max_features = 0.165351, Score = 1252993.08216, CV = 33
# 57 n_estimators = 100, max_depth =  6, max_features = 0.803342, Score = 1323252.57793, CV = 33
# 58 n_estimators = 100, max_depth =  6, max_features = 0.519860, Score = 1307279.86108, CV = 33
# 59 n_estimators = 100, max_depth =  5, max_features = 0.781861, Score = 1299846.09778, CV = 33
# 60 n_estimators = 100, max_depth =  4, max_features = 0.355834, Score = 1245699.04129, CV = 33
# 61 n_estimators = 100, max_depth =  8, max_features = 0.394269, Score = 1305044.56299, CV = 33
# 62 n_estimators = 100, max_depth =  5, max_features = 0.214251, Score = 1245713.42456, CV = 33
# 63 n_estimators = 100, max_depth =  7, max_features = 0.129059, Score = 1241473.28706, CV = 33
# 64 n_estimators = 100, max_depth =  6, max_features = 0.960866, Score = 1328914.62115, CV = 33
# 65 n_estimators = 100, max_depth =  5, max_features = 0.107171, Score = 1250081.28961, CV = 33
# 66 n_estimators = 100, max_depth =  4, max_features = 0.476034, Score = 1256337.08710, CV = 33
# 67 n_estimators = 100, max_depth =  8, max_features = 0.729446, Score = 1338527.80190, CV = 33
# 68 n_estimators = 100, max_depth =  2, max_features = 0.479729, Score = 1265612.76985, CV = 33
# 69 n_estimators = 100, max_depth =  5, max_features = 0.970879, Score = 1310921.69709, CV = 33
# 70 n_estimators = 100, max_depth =  7, max_features = 0.473032, Score = 1299954.13621, CV = 33
# 71 n_estimators = 100, max_depth =  6, max_features = 0.897378, Score = 1309708.59101, CV = 33
# 72 n_estimators = 100, max_depth =  5, max_features = 0.119666, Score = 1250081.28961, CV = 33
# 73 n_estimators = 100, max_depth =  8, max_features = 0.916612, Score = 1355716.72394, CV = 33
# 74 n_estimators = 100, max_depth =  7, max_features = 0.976314, Score = 1353602.57103, CV = 33
# 75 n_estimators = 100, max_depth =  2, max_features = 0.149065, Score = 1331492.24227, CV = 33
# 76 n_estimators = 100, max_depth =  9, max_features = 0.242964, Score = 1267953.55490, CV = 33
# 77 n_estimators = 100, max_depth =  7, max_features = 0.443396, Score = 1305772.04029, CV = 33
# 78 n_estimators = 100, max_depth =  7, max_features = 0.829489, Score = 1341208.09817, CV = 33
# 79 n_estimators = 100, max_depth =  5, max_features = 0.659053, Score = 1288549.60623, CV = 33
# 80 n_estimators = 100, max_depth =  3, max_features = 0.260187, Score = 1249326.23162, CV = 33
# 81 n_estimators = 100, max_depth =  5, max_features = 0.402485, Score = 1277364.03941, CV = 33
# 82 n_estimators = 100, max_depth =  4, max_features = 0.323818, Score = 1245699.04129, CV = 33
# 83 n_estimators = 100, max_depth =  8, max_features = 0.349253, Score = 1302070.02075, CV = 33
# 84 n_estimators = 100, max_depth =  3, max_features = 0.586818, Score = 1266971.74049, CV = 33
# 85 n_estimators = 100, max_depth =  4, max_features = 0.305062, Score = 1245699.04129, CV = 33
# 86 n_estimators = 100, max_depth =  7, max_features = 0.213216, Score = 1256199.00852, CV = 33
# 87 n_estimators = 100, max_depth =  7, max_features = 0.761921, Score = 1340697.31597, CV = 33
# 88 n_estimators = 100, max_depth =  6, max_features = 0.233692, Score = 1235075.99371, CV = 33
# 89 n_estimators = 100, max_depth =  8, max_features = 0.997470, Score = 1355716.72394, CV = 33
# 90 n_estimators = 100, max_depth =  6, max_features = 0.379197, Score = 1278691.68838, CV = 33
# 91 n_estimators = 100, max_depth =  6, max_features = 0.230165, Score = 1235075.99371, CV = 33
# 92 n_estimators = 100, max_depth =  9, max_features = 0.500405, Score = 1323601.30685, CV = 33
# 93 n_estimators = 100, max_depth =  3, max_features = 0.240919, Score = 1249326.23162, CV = 33
# 94 n_estimators = 100, max_depth =  4, max_features = 0.602093, Score = 1268443.17054, CV = 33
# 95 n_estimators = 100, max_depth =  7, max_features = 0.778655, Score = 1340697.31597, CV = 33
# 96 n_estimators = 100, max_depth =  3, max_features = 0.363866, Score = 1256299.85184, CV = 33
# 97 n_estimators = 100, max_depth =  8, max_features = 0.229287, Score = 1249285.75680, CV = 33
# 98 n_estimators = 100, max_depth =  4, max_features = 0.791675, Score = 1281910.63540, CV = 33
# 99 n_estimators = 100, max_depth =  6, max_features = 0.451251, Score = 1278691.68838, CV = 33
#  0 n_estimators = 100, max_depth =  6, max_features = 0.334507, Score = 1279762.31221, CV = 35
#  1 n_estimators = 100, max_depth =  5, max_features = 0.237444, Score = 1241520.97320, CV = 35
#  2 n_estimators = 100, max_depth =  5, max_features = 0.395551, Score = 1263509.32351, CV = 35
#  3 n_estimators = 100, max_depth =  5, max_features = 0.192433, Score = 1241520.97320, CV = 35
#  4 n_estimators = 100, max_depth =  9, max_features = 0.276601, Score = 1276639.68187, CV = 35
#  5 n_estimators = 100, max_depth =  2, max_features = 0.712235, Score = 1260845.37865, CV = 35
#  6 n_estimators = 100, max_depth =  9, max_features = 0.554169, Score = 1318969.57230, CV = 35
#  7 n_estimators = 100, max_depth =  2, max_features = 0.933221, Score = 1281902.81307, CV = 35
#  8 n_estimators = 100, max_depth =  3, max_features = 0.761944, Score = 1267592.69671, CV = 35
#  9 n_estimators = 100, max_depth =  4, max_features = 0.162976, Score = 1254907.67246, CV = 35
# 10 n_estimators = 100, max_depth =  2, max_features = 0.651963, Score = 1260845.37865, CV = 35
# 11 n_estimators = 100, max_depth =  8, max_features = 0.751171, Score = 1333203.96023, CV = 35
# 12 n_estimators = 100, max_depth =  7, max_features = 0.867521, Score = 1339784.63148, CV = 35
# 13 n_estimators = 100, max_depth =  9, max_features = 0.683001, Score = 1315680.34168, CV = 35
# 14 n_estimators = 100, max_depth =  6, max_features = 0.705062, Score = 1286347.58686, CV = 35
# 15 n_estimators = 100, max_depth =  6, max_features = 0.466414, Score = 1268083.49344, CV = 35
# 16 n_estimators = 100, max_depth =  2, max_features = 0.646713, Score = 1260845.37865, CV = 35
# 17 n_estimators = 100, max_depth =  3, max_features = 0.355600, Score = 1248330.84100, CV = 35
# 18 n_estimators = 100, max_depth =  2, max_features = 0.913930, Score = 1281902.81307, CV = 35
# 19 n_estimators = 100, max_depth =  9, max_features = 0.752623, Score = 1361646.04076, CV = 35
# 20 n_estimators = 100, max_depth =  4, max_features = 0.734348, Score = 1288404.63912, CV = 35
# 21 n_estimators = 100, max_depth =  7, max_features = 0.150218, Score = 1235446.76377, CV = 35
# 22 n_estimators = 100, max_depth =  6, max_features = 0.248613, Score = 1250736.37807, CV = 35
# 23 n_estimators = 100, max_depth =  8, max_features = 0.881030, Score = 1344343.73668, CV = 35
# 24 n_estimators = 100, max_depth =  2, max_features = 0.267425, Score = 1269113.05798, CV = 35
# 25 n_estimators = 100, max_depth =  8, max_features = 0.208633, Score = 1254559.58820, CV = 35
# 26 n_estimators = 100, max_depth =  2, max_features = 0.459488, Score = 1252416.64171, CV = 35
# 27 n_estimators = 100, max_depth =  6, max_features = 0.890857, Score = 1303906.66434, CV = 35
# 28 n_estimators = 100, max_depth =  2, max_features = 0.318483, Score = 1263268.70901, CV = 35
# 29 n_estimators = 100, max_depth =  5, max_features = 0.352918, Score = 1251316.56534, CV = 35
# 30 n_estimators = 100, max_depth =  5, max_features = 0.949160, Score = 1300796.66613, CV = 35
# 31 n_estimators = 100, max_depth =  7, max_features = 0.172253, Score = 1235446.76377, CV = 35
# 32 n_estimators = 100, max_depth =  3, max_features = 0.129152, Score = 1288087.97943, CV = 35
# 33 n_estimators = 100, max_depth =  7, max_features = 0.529728, Score = 1296121.38972, CV = 35
# 34 n_estimators = 100, max_depth =  5, max_features = 0.851720, Score = 1297585.18344, CV = 35
# 35 n_estimators = 100, max_depth =  6, max_features = 0.301754, Score = 1279762.31221, CV = 35
# 36 n_estimators = 100, max_depth =  4, max_features = 0.886479, Score = 1287447.99745, CV = 35
# 37 n_estimators = 100, max_depth =  4, max_features = 0.272271, Score = 1244291.83599, CV = 35
# 38 n_estimators = 100, max_depth =  3, max_features = 0.327067, Score = 1248330.84100, CV = 35
# 39 n_estimators = 100, max_depth =  8, max_features = 0.492819, Score = 1309643.76943, CV = 35
# 40 n_estimators = 100, max_depth =  5, max_features = 0.309829, Score = 1251316.56534, CV = 35
# 41 n_estimators = 100, max_depth =  2, max_features = 0.636533, Score = 1260845.37865, CV = 35
# 42 n_estimators = 100, max_depth =  2, max_features = 0.352842, Score = 1263268.70901, CV = 35
# 43 n_estimators = 100, max_depth =  5, max_features = 0.356045, Score = 1251316.56534, CV = 35
# 44 n_estimators = 100, max_depth =  7, max_features = 0.250349, Score = 1253568.87927, CV = 35
# 45 n_estimators = 100, max_depth =  3, max_features = 0.516240, Score = 1250068.24674, CV = 35
# 46 n_estimators = 100, max_depth =  8, max_features = 0.250057, Score = 1254559.58820, CV = 35
# 47 n_estimators = 100, max_depth =  4, max_features = 0.121703, Score = 1254907.67246, CV = 35
# 48 n_estimators = 100, max_depth =  5, max_features = 0.522400, Score = 1268152.89396, CV = 35
# 49 n_estimators = 100, max_depth =  5, max_features = 0.485323, Score = 1268152.89396, CV = 35
# 50 n_estimators = 100, max_depth =  2, max_features = 0.621657, Score = 1257032.80315, CV = 35
# 51 n_estimators = 100, max_depth =  9, max_features = 0.498433, Score = 1311475.50860, CV = 35
# 52 n_estimators = 100, max_depth =  6, max_features = 0.528995, Score = 1268083.49344, CV = 35
# 53 n_estimators = 100, max_depth =  8, max_features = 0.110820, Score = 1230555.89469, CV = 35
# 54 n_estimators = 100, max_depth =  2, max_features = 0.440221, Score = 1255828.03401, CV = 35
# 55 n_estimators = 100, max_depth =  5, max_features = 0.138293, Score = 1247062.45023, CV = 35
# 56 n_estimators = 100, max_depth =  6, max_features = 0.877970, Score = 1303906.66434, CV = 35
# 57 n_estimators = 100, max_depth =  5, max_features = 0.109933, Score = 1247062.45023, CV = 35
# 58 n_estimators = 100, max_depth =  6, max_features = 0.407824, Score = 1284127.51014, CV = 35
# 59 n_estimators = 100, max_depth =  8, max_features = 0.925250, Score = 1344783.24955, CV = 35
# 60 n_estimators = 100, max_depth =  6, max_features = 0.585143, Score = 1300884.39474, CV = 35
# 61 n_estimators = 100, max_depth =  4, max_features = 0.495644, Score = 1275748.32333, CV = 35
# 62 n_estimators = 100, max_depth =  8, max_features = 0.262832, Score = 1254559.58820, CV = 35
# 63 n_estimators = 100, max_depth =  2, max_features = 0.285431, Score = 1263268.70901, CV = 35
# 64 n_estimators = 100, max_depth =  4, max_features = 0.183998, Score = 1244291.83599, CV = 35
# 65 n_estimators = 100, max_depth =  2, max_features = 0.741438, Score = 1268599.91390, CV = 35
# 66 n_estimators = 100, max_depth =  5, max_features = 0.741102, Score = 1292177.72952, CV = 35
# 67 n_estimators = 100, max_depth =  6, max_features = 0.170716, Score = 1229383.95655, CV = 35
# 68 n_estimators = 100, max_depth =  2, max_features = 0.180029, Score = 1319919.91229, CV = 35
# 69 n_estimators = 100, max_depth =  5, max_features = 0.308045, Score = 1251316.56534, CV = 35
# 70 n_estimators = 100, max_depth =  5, max_features = 0.220435, Score = 1241520.97320, CV = 35
# 71 n_estimators = 100, max_depth =  5, max_features = 0.242245, Score = 1241520.97320, CV = 35
# 72 n_estimators = 100, max_depth =  9, max_features = 0.101948, Score = 1238184.38806, CV = 35
# 73 n_estimators = 100, max_depth =  5, max_features = 0.959734, Score = 1300796.66613, CV = 35
# 74 n_estimators = 100, max_depth =  2, max_features = 0.298968, Score = 1263268.70901, CV = 35
# 75 n_estimators = 100, max_depth =  2, max_features = 0.253005, Score = 1269113.05798, CV = 35
# 76 n_estimators = 100, max_depth =  4, max_features = 0.431632, Score = 1263696.30702, CV = 35
# 77 n_estimators = 100, max_depth =  3, max_features = 0.471938, Score = 1250068.24674, CV = 35
# 78 n_estimators = 100, max_depth =  7, max_features = 0.186332, Score = 1253568.87927, CV = 35
# 79 n_estimators = 100, max_depth =  8, max_features = 0.171988, Score = 1230555.89469, CV = 35
# 80 n_estimators = 100, max_depth =  4, max_features = 0.138403, Score = 1254907.67246, CV = 35
# 81 n_estimators = 100, max_depth =  7, max_features = 0.203999, Score = 1253568.87927, CV = 35
# 82 n_estimators = 100, max_depth =  4, max_features = 0.791358, Score = 1288404.63912, CV = 35
# 83 n_estimators = 100, max_depth =  7, max_features = 0.412953, Score = 1286498.28841, CV = 35
# 84 n_estimators = 100, max_depth =  3, max_features = 0.709268, Score = 1263188.64753, CV = 35
# 85 n_estimators = 100, max_depth =  6, max_features = 0.598592, Score = 1300884.39474, CV = 35
# 86 n_estimators = 100, max_depth =  6, max_features = 0.575423, Score = 1300884.39474, CV = 35
# 87 n_estimators = 100, max_depth =  9, max_features = 0.288254, Score = 1276639.68187, CV = 35
# 88 n_estimators = 100, max_depth =  7, max_features = 0.900798, Score = 1339784.63148, CV = 35
# 89 n_estimators = 100, max_depth =  8, max_features = 0.430261, Score = 1294882.98853, CV = 35
# 90 n_estimators = 100, max_depth =  4, max_features = 0.465837, Score = 1275748.32333, CV = 35
# 91 n_estimators = 100, max_depth =  8, max_features = 0.991699, Score = 1344783.24955, CV = 35
# 92 n_estimators = 100, max_depth =  7, max_features = 0.981476, Score = 1330187.41734, CV = 35
# 93 n_estimators = 100, max_depth =  2, max_features = 0.379789, Score = 1255828.03401, CV = 35
# 94 n_estimators = 100, max_depth =  4, max_features = 0.586094, Score = 1269210.46281, CV = 35
# 95 n_estimators = 100, max_depth =  9, max_features = 0.522547, Score = 1311475.50860, CV = 35
# 96 n_estimators = 100, max_depth =  8, max_features = 0.154651, Score = 1230555.89469, CV = 35
# 97 n_estimators = 100, max_depth =  9, max_features = 0.436697, Score = 1301076.61923, CV = 35
# 98 n_estimators = 100, max_depth =  9, max_features = 0.381529, Score = 1301076.61923, CV = 35
# 99 n_estimators = 100, max_depth =  7, max_features = 0.821004, Score = 1339784.63148, CV = 35

# %%
display(cv_cv)
# Out:
# [    epoch         score  n_estimators  max_depth  max_features  cv
#  60     60  1.267566e+06           100          5      0.221966  27,
#      epoch         score  n_estimators  max_depth  max_features  cv
#  54     54  1.246747e+06           100          7        0.1176  29,
#      epoch         score  n_estimators  max_depth  max_features  cv
#  17     17  1.259830e+06           100          9      0.142936  31,
#      epoch         score  n_estimators  max_depth  max_features  cv
#  88     88  1.235076e+06           100          6      0.233692  33,
#      epoch         score  n_estimators  max_depth  max_features  cv
#  67     67  1.229384e+06           100          6      0.170716  35]

# %%
display(cv_cv)
# Out:
# [    epoch         score  n_estimators  max_depth  max_features  cv
#  25     25  1.303383e+06           100          5      0.234854  19,
#      epoch         score  n_estimators  max_depth  max_features  cv
#  56     56  1.277253e+06           100          8      0.174468  21,
#      epoch         score  n_estimators  max_depth  max_features  cv
#  12     12  1.328894e+06           100          7      0.178809  23,
#      epoch         score  n_estimators  max_depth  max_features  cv
#  60     60  1.266826e+06           100          9      0.110251  25]

# %%
# 가장 정확도가 높은 하이퍼패러미터를 저장
best_hyperparameters = finer_hyperparameters_list.iloc[0]

best_max_depth = best_hyperparameters["max_depth"]
best_max_features = best_hyperparameters["max_features"]

print(f"max_depth(best) = {best_max_depth}, max_features(best) = {best_max_features:.6f}")

# %%
from sklearn.ensemble import RandomForestRegressor

best_n_estimators = 3000
model = RandomForestRegressor(n_estimators=best_n_estimators,
                              max_depth=best_max_depth,
                              max_features=best_max_features,
                              random_state=37,
                              n_jobs=-1)
model

# %%
model.fit(X_train, Y_train)
prediction = model.predict(X_test)

# %% [markdown]
# ## tensorflow

# %%
train_Y = df['box_off_num']
train_X = df.drop(['box_off_num'], axis=1)

test_X = testdf

# %%
import tensorflow as tf
import numpy as np

X = tf.placeholder(shape = [None,11], dtype=tf.float32)
Y = tf.placeholder(shape = [None,1], dtype=tf.float32)

W = tf.Variable(tf.random_normal([11,1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name = 'bias')

H = tf.matmul(X, W) + b
cost = tf.reduce_mean(tf.square(H-Y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.0000001)
train = optimizer.minimize(cost)


sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(5000) :
    _, cost_val = sess.run([train, cost],
                          feed_dict = {
                              X : train_X.values,
                              Y : train_Y.values.reshape(-1,1)
                          })
    if step % 500 == 0 :
        print('cost값은 : {}'.format(cost_val))
    
prediction = sess.run(H, feed_dict = {X : test_X.values, })
# Out:
# cost값은 : 3833388597248.0
# cost값은 : 2351955443712.0
# cost값은 : 2347802558464.0
# cost값은 : 2347764809728.0
# cost값은 : 2347744100352.0
# cost값은 : 2347723653120.0
# cost값은 : 2347703730176.0
# cost값은 : 2347683807232.0
# cost값은 : 2347663622144.0
# cost값은 : 2347643174912.0

# %% [markdown]
# # 저장

# %%
# 저장함수
def save_file(prediction, number) :
    sub = pd.read_csv('./data/submission.csv')
    sub['box_off_num'] = prediction
    sub.to_csv('./submission/submission' + str(number) + '.csv', index=False)
    return print('done')

# %%
save_file(prediction, 111)
# Out:
# done

# %%
a = 0
for i in range(len(prediction)) :
    if prediction[i] <= 0 :
        prediction[i] = 0
        a += 1

print(a)
#prediction = prediction.astype(int)
prediction
# Out:
# 71
# array([1115566.30565657, 1330898.07271574, 1956710.48447819,
#        2166859.56483689, 2080734.17510612,  346045.45931293,
#              0.        ,       0.        ,  112417.19426519,
#         951379.95868599, 1162406.66919744, 1679870.66858181,
#        1124792.64272501,   49453.00864089, 1559751.63842055,
#        2517328.07425241,       0.        , 1568512.0582598 ,
#        1354633.42175171,  243400.04957435,       0.        ,
#         450034.0288779 ,  454500.39016113,       0.        ,
#              0.        , 2425606.73876284,       0.        ,
#        1806573.56296934,   87379.25725834,  204802.27780387,
#        1488231.30625899,  218700.55519663,       0.        ,
#        1374517.85637328,   86868.77794634,       0.        ,
#              0.        ,       0.        ,   22318.97752276,
#              0.        ,  204638.03387941,  397508.22867611,
#         374282.20315428,  543604.79166777,  867479.27053258,
#        2054273.09964444,       0.        ,  273394.65591729,
#         314385.90759814,       0.        ,   21710.03930111,
#        1131871.11880189,       0.        , 1496151.65575613,
#        1624193.44579676,  196612.84126142,  175018.05754875,
#        1683928.05466701, 2206332.23162974, 1804422.95286106,
