# %%
import pandas as pd
df = pd.read_csv('./data/movies_train.csv')
testdf = pd.read_csv('./data/movies_test.csv')

# %% [markdown]
# # 전처리

# %%
# column 생성
def make_col(dataframe, column_name, mapper) :
    new = []
    for i in dataframe[column_name] :
        if i in mapper.keys() :
            new.append(mapper.get(i))
        else :
            new.append(1)
    dataframe['new_' + str(column_name)] = pd.DataFrame(new)
    del dataframe[column_name]
    return dataframe

# %% [markdown]
# ## title
# title 은 제거

# %%
del df['title']
del testdf['title']

# %% [markdown]
# ## distributor

# %%
a = df.groupby(['distributor']).mean()['box_off_num'].sort_values(ascending=False)

distributor_mapper = {}
for i in range(len(a)) :
    if a[i] >= 1000000 :
        distributor_mapper.update({a.index[i] : 5 })
    elif a[i] >= 100000 :
        distributor_mapper.update({a.index[i] : 4 })
    elif a[i] >= 10000 :
        distributor_mapper.update({a.index[i] : 3 })
    elif a[i] >= 1000 :
        distributor_mapper.update({a.index[i] : 2 })
    else :
        distributor_mapper.update({a.index[i] : 1 })

df = make_col(df, 'distributor', distributor_mapper )
testdf = make_col(testdf, 'distributor', distributor_mapper )

# %% [markdown]
# ### 배급사별 box_off_num 의 평균에 따른 head, tail

# %%
df.groupby(['distributor']).mean()['box_off_num'].sort_values(ascending=False).head(20)
# Out:
# distributor
# CJ E&M Pictures    4.122337e+06
# (주)쇼박스             3.386656e+06
# (주)아이필름코퍼레이션       3.117859e+06
# 쇼박스(주)미디어플렉스       2.634823e+06
# 영구아트무비             2.541603e+06
# CJ E&M 영화부문        2.505309e+06
# (주)NEW             2.184405e+06
# CJ 엔터테인먼트          2.162742e+06
# 이십세기폭스코리아(주)       1.637046e+06
# SK텔레콤(주)           1.383867e+06
# CGV아트하우스           1.318189e+06
# 롯데엔터테인먼트           1.238149e+06
# 전망좋은영화사            1.214237e+06
# 주머니필름              1.201944e+06
# NEW                1.019017e+06
# 싸이더스               9.634390e+05
# 시네마서비스             8.968432e+05
# 보람엔터테인먼트           8.496350e+05
# 스튜디오 블루            7.716990e+05
# 씨네그루(주)키다리이엔티      7.551840e+05
# Name: box_off_num, dtype: float64

# %%
df.groupby(['distributor']).mean()['box_off_num'].sort_values(ascending=False).tail(20)
# Out:
# distributor
# 웃기씨네           464.5
# 판다미디어          432.0
# (주)더픽쳐스        429.0
# 이상우필름          339.0
# (주)온비즈넷        310.0
# (주)유비네트워크      303.0
# (주)휘엔터테인먼트     228.0
# 크리에이티브컴즈(주)    188.0
# ysfilm         172.0
# 에스와이코마드        163.0
# 건시네마           162.0
# (주)씨엠닉스        136.0
# 위더스필름           90.0
# 인터콘미디어          79.0
# 한국YWCA연합회       71.0
# 나우콘텐츠           54.0
# 위드시네마           46.0
# 사람과 사람들         42.0
# 고구마공작소           8.0
# 인피니티엔터테인먼트       2.0
# Name: box_off_num, dtype: float64

# %% [markdown]
# ## genre

# %% [markdown]
# ### genre 에 따른 box_off_num 평균 확인

# %%
df.groupby(['genre']).mean()['box_off_num'].sort_values(ascending=False).index
# Out:
# Index(['느와르', '액션', 'SF', '코미디', '드라마', '공포', '미스터리', '멜로/로맨스', '애니메이션',
#        '서스펜스', '다큐멘터리', '뮤지컬'],
#       dtype='object', name='genre')

# %%
df.groupby(['genre']).mean()['box_off_num'].sort_values(ascending=False)
# Out:
# genre
# 느와르       2.263695e+06
# 액션        2.203974e+06
# SF        1.788346e+06
# 코미디       1.193914e+06
# 드라마       6.256898e+05
# 공포        5.908325e+05
# 미스터리      5.275482e+05
# 멜로/로맨스    4.259680e+05
# 애니메이션     1.819267e+05
# 서스펜스      8.261100e+04
# 다큐멘터리     6.717226e+04
# 뮤지컬       6.627000e+03
# Name: box_off_num, dtype: float64

# %%
df['genre'].value_counts()
# Out:
# 드라마       221
# 다큐멘터리      93
# 멜로/로맨스     78
# 코미디        53
# 공포         42
# 액션         28
# 느와르        27
# 애니메이션      21
# 미스터리       17
# SF         13
# 뮤지컬         5
# 서스펜스        2
# Name: genre, dtype: int64

# %% [markdown]
# ### genre_version1

# %%
df = pd.get_dummies(df, columns=['genre'], prefix='genre')
testdf = pd.get_dummies(testdf, columns=['genre'], prefix='genre')

# %% [markdown]
# ### genre_version2
#
# version1, 3 보다 좋음
#
# 영화 종류 묶기 + box_off_num의 평균에 따라 비선호 영화 묶기
#
# => 1466134.4524178207
#
# * 드라마 멜로/로맨스6
#
# * 느와르 액션5
#
# * sf4
#
# * 코미디3
#
# * 공포 미스터리 서스펜스2
#
# * 애니메이션 다큐멘터리 뮤지컬1

# %%
genre_mapper = {'느와르' : 5 , '액션' : 5, 'SF' : 4, '코미디' : 3, '드라마' : 6, '공포' : 2, '미스터리' : 2, '멜로/로맨스' : 6, '애니메이션' : 1,
       '서스펜스' : 2, '다큐멘터리' : 1, '뮤지컬' : 1} 

df = make_col(df, 'genre', genre_mapper )
testdf = make_col(testdf, 'genre', genre_mapper )

# %% [markdown]
# ### genre_version3
#
# box_off_num 평균에 따라 임의로 분류
#
# => 1467553.925063711

# %%
느와르       4
액션        4
SF        3
코미디       3
드라마       2
공포        2
미스터리      2
멜로/로맨스    2
애니메이션     1
서스펜스     1
다큐멘터리     1
뮤지컬       1

# %%
genre_mapper = {'느와르' : 4 , '액션' : 4, 'SF' : 3, '코미디' : 3, '드라마' : 2, '공포' : 2, '미스터리' : 2, '멜로/로맨스' : 2, '애니메이션' : 1,
       '서스펜스' : 1, '다큐멘터리' : 1, '뮤지컬' : 1} 

df = make_col(df, 'genre', genre_mapper )
testdf = make_col(testdf, 'genre', genre_mapper )

# %% [markdown]
# ## release_time

# %%
def release_time(df) :
    years, months, days = [], [], []
    for line in df['release_time'] :
        a = line.split('-')
        years.append(int(a[0]))
        months.append(int(a[1]))
        days.append(a[2])
        
    new_days = []
    for i in range(len(days)) :
        if int(days[i]) >= 20 :
            new_days.append(3)
        elif int(days[i]) >= 10 :
            new_days.append(2)
        else :
            new_days.append(1)    
            
    df['release_year'] = pd.DataFrame(years)
    df['release_month'] = pd.DataFrame(months)
    df['release_day'] = pd.DataFrame(new_days)

    del df['release_time']
    return df

df = release_time(df)
testdf = release_time(testdf)

# %% [markdown]
# ## time
#
# 전처리 이전과 비교하였을 때, box_off_num 과의 상관관계는 낮아졌다 ( 0.44 -> 0.29 )
#
# 하지만, 전처리 이후 성능이 개선됨
#
# => 1472434.761373017 ( 130, 70, ~ )
#
# => 1472973.0197688688 ( 130, 100, 70, ~ )

# %%
def time(df) :
    new_time = []
    for i in df['time'] :
        if i >= 130 :
            new_time.append(3)
        elif i > 70 : 
            new_time.append(2)
        else :
            new_time.append(1)

    df['new_time'] = pd.DataFrame(new_time)
    del df['time']
    return df

df = time(df)
testdf = time(testdf)

# %% [markdown]
# ## screening_rat

# %% [markdown]
# ### mapping_version1
#
# version1 이 더 좋음

# %%
screening_rat_mapper = {'15세 관람가' : 3, '12세 관람가' : 2, '전체 관람가' : 2, '청소년 관람불가' : 1} 

df = make_col(df, 'screening_rat', screening_rat_mapper )
testdf = make_col(testdf, 'screening_rat', screening_rat_mapper )

# %% [markdown]
# ### mapping_version2

# %%
def screen_rat(df) :
    tmp = sorted(df['screening_rat'].unique(), reverse=False)

    mapping = {}
    num = 1
    for i in tmp :
        mapping.update({i : num})
        num += 1

    return make_col(df, 'screening_rat', mapping)

# %%
df = screen_rat(df)
testdf = screen_rat(testdf)

# %% [markdown]
# ### 관람 연령 제한에 따른 box_off_num 평균, 영화 수

# %%
df.groupby(['screening_rat']).mean()['box_off_num'].sort_values(ascending=False)
# Out:
# screening_rat
# 15세 관람가     1.247519e+06
# 12세 관람가     8.449809e+05
# 청소년 관람불가    3.641813e+05
# 전체 관람가      1.351005e+05
# Name: box_off_num, dtype: float64

# %%
df.groupby(['screening_rat']).count()['box_off_num'].sort_values(ascending=False)
# Out:
# screening_rat
# 청소년 관람불가    204
# 15세 관람가     202
# 12세 관람가     102
# 전체 관람가       92
# Name: box_off_num, dtype: int64

# %% [markdown]
# ## director

# %%
del df['director']
del testdf['director']

# %% [markdown]
# ## dir_prev_bfnum

# %%
# 결측치 0으로 채워 넣음
df = df.fillna(0)
testdf = testdf.fillna(0)

# %% [markdown]
# ## dir_prev_num

# %%
# 그대로 사용
# Out:
# dir_prev_num
# 0    330
# 1    113
# 2     86
# 3     47
# 4     20
# 5      4
# Name: box_off_num, dtype: int64

# %% [markdown]
# ## num_staff

# %%
# 그대로 사용

# %% [markdown]
# ## num_actor

# %%
# 그대로 사용

# %% [markdown]
# # 상관관계

# %%
df.corr().sort_values(by='box_off_num', ascending = False)
# Out:
#                    dir_prev_bfnum  dir_prev_num  num_staff  num_actor  \
# box_off_num              0.293791      0.259674   0.544265   0.111179
# num_staff                0.369657      0.450706   1.000000   0.077871
# new_distributor          0.273246      0.394395   0.691844   0.076260
# new_time                 0.197864      0.160672   0.329142   0.033701
# dir_prev_bfnum           1.000000      0.396616   0.369657   0.042491
# dir_prev_num             0.396616      1.000000   0.450706   0.014006
# new_screening_rat        0.074945      0.162363   0.190978   0.074099
# num_actor                0.042491      0.014006   0.077871   1.000000
# new_genre                0.074968      0.125345   0.267746  -0.034260
# release_month            0.047183      0.034019  -0.002841  -0.015063
# release_year             0.033592      0.132621  -0.032891  -0.098869
# release_day             -0.035287      0.030678   0.008254   0.009580
#
#                    box_off_num  new_distributor  new_genre  release_year  \
# box_off_num           1.000000         0.450164   0.095954     -0.002497
# num_staff             0.544265         0.691844   0.267746     -0.032891
# new_distributor       0.450164         1.000000   0.087552     -0.059856
# new_time              0.294977         0.256027   0.102547     -0.052543
# dir_prev_bfnum        0.293791         0.273246   0.074968      0.033592
# dir_prev_num          0.259674         0.394395   0.125345      0.132621
# new_screening_rat     0.198700         0.240402  -0.104835     -0.121516
# num_actor             0.111179         0.076260  -0.034260     -0.098869
# new_genre             0.095954         0.087552   1.000000     -0.018831
# release_month         0.019104        -0.027985  -0.020418      0.046627
# release_year         -0.002497        -0.059856  -0.018831      1.000000
# release_day          -0.011023        -0.027702   0.001243      0.022144
#
#                    release_month  release_day  new_time  new_screening_rat
# box_off_num             0.019104    -0.011023  0.294977           0.198700
# num_staff              -0.002841     0.008254  0.329142           0.190978
# new_distributor        -0.027985    -0.027702  0.256027           0.240402
# new_time                0.008131     0.029267  1.000000           0.007174
# dir_prev_bfnum          0.047183    -0.035287  0.197864           0.074945
# dir_prev_num            0.034019     0.030678  0.160672           0.162363
# new_screening_rat      -0.039411    -0.016887  0.007174           1.000000
# num_actor              -0.015063     0.009580  0.033701           0.074099
# new_genre              -0.020418     0.001243  0.102547          -0.104835
# release_month           1.000000    -0.052697  0.008131          -0.039411
# release_year            0.046627     0.022144 -0.052543          -0.121516
# release_day            -0.052697     1.000000  0.029267          -0.016887

# %% [markdown]
# # 모델링

# %%
# 저장함수
def save_file(prediction, number) :
    sub = pd.read_csv('./data/submission.csv')
    sub['box_off_num'] = prediction
    sub.to_csv('./submission/submission' + str(number) + '.csv', index=False)
    return print('done')

# %%
import numpy as np
from sklearn.metrics import make_scorer

def rmse(predict, actual):
    predict = np.array(predict)
    actual = np.array(actual)

    distance = predict - actual
    square_distance = distance ** 2
    mean_square_distance = square_distance.mean()
    score = np.sqrt(mean_square_distance)
    
    return score

rmse_score = make_scorer(rmse)
rmse_score
# Out:
# make_scorer(rmse)

# %% [markdown]
# ## sklearn_Linear Regression

# %%
train_Y = df['box_off_num']
train_X = df.drop(['box_off_num'], axis=1)

test_X = testdf

# %%
from sklearn import linear_model

lm = linear_model.LinearRegression()
lm.fit(train_X, train_Y)

prediction = lm.predict(test_X)

# %% [markdown]
# ## sklearn_RandomForestRegressor
#
# => 1528294.5021972428	 ( epoch X )

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

model = RandomForestRegressor(n_estimators=300,
                              n_jobs=-1,
                              random_state=46)
#score = cross_val_score(model, X_train, y_train, cv=20, scoring=rmse_score).mean()

# %%
train_Y = df['box_off_num']
train_X = df.drop(['box_off_num'], axis=1)

test_X = testdf

model.fit(train_X, train_Y)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=300, n_jobs=-1, oob_score=False,
#                       random_state=46, verbose=0, warm_start=False)

# %%
prediction = model.predict(test_X)
# Out:
# array([1.37224077e+06, 1.37712202e+06, 2.91496949e+06, 2.35731362e+06,
#        2.18836183e+06, 3.83021800e+04, 3.05253000e+03, 1.25348333e+03,
#        4.89507000e+03, 2.70432873e+05, 4.52084997e+05, 1.09368079e+06,
#        2.43055558e+06, 3.80952000e+03, 1.54969315e+06, 2.49022232e+06,
#        4.11237000e+03, 2.80051673e+06, 9.91018117e+05, 4.01313674e+06,
#        3.31340000e+02, 2.75170133e+04, 1.04387323e+05, 2.15437233e+04,
#        2.86300000e+02, 3.14427729e+06, 2.01759000e+03, 2.63354868e+06,
#        9.63927000e+03, 7.76519000e+03, 4.01482357e+06, 2.53251757e+05,
#        3.11146333e+03, 5.57792827e+05, 6.60871667e+03, 2.34236933e+04,
#        2.40023047e+06, 2.03624300e+04, 1.59361733e+04, 1.20390867e+04,
#        2.16140333e+03, 2.42111425e+06, 3.08000900e+04, 1.82426667e+03,
#        1.67400333e+03, 1.45000667e+03, 3.06379333e+03, 2.89755128e+06,
#        1.26663133e+04, 1.13483140e+06, 4.01049667e+03, 4.33217614e+06,
#        1.29794000e+03, 1.19128180e+05, 1.13663000e+03, 8.96838333e+03,
#        1.95189343e+05, 1.18530259e+06, 2.51820696e+06, 1.34944434e+06,
#        4.82525667e+03, 2.54825860e+06, 1.40099420e+05, 1.58759561e+06,
#        2.76173406e+06, 8.25968200e+05, 1.41813257e+05, 6.81546667e+02,
#        1.58190981e+06, 2.49652567e+04, 6.64543333e+02, 4.57946667e+03,
#        2.17091213e+05, 2.70879024e+06, 1.64686904e+06, 1.27141257e+05,
#        9.91135333e+03, 3.25553333e+02, 6.77323333e+02, 9.99896117e+05,
#        2.44863633e+04, 2.12578334e+06, 6.58209333e+03, 1.27417313e+06,
#        2.24633023e+05, 7.16773333e+03, 4.01650000e+02, 8.60017000e+03,
#        9.04382800e+04, 3.30943333e+02, 2.76343333e+02, 5.20069667e+03,
#        1.87969113e+05, 1.00914000e+03, 1.45449000e+03])

# %% [markdown]
# ## LGBM
#
# => 1480188.794477261

# %%
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
k_fold = KFold(n_splits=10, shuffle=True, random_state = 777)

model = lgb.LGBMRegressor(random_state = 777, n_estimators=10000)
X_train, X_test, Y_train = df.drop(['box_off_num'], axis=1), testdf, df['box_off_num']


params = {
    'learning_rate' : [0.001, 0.0001, 0.00001],
    'min_child_samples' : [20, 30]}

gs = GridSearchCV(estimator=model,
                 param_grid = params,
                 scoring=rmse_score,
                 cv=k_fold)

# %%
gs.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=777, shuffle=True),
#              error_score=nan,
#              estimator=LGBMRegressor(boosting_type='gbdt', class_weight=None,
#                                      colsample_bytree=1.0,
#                                      importance_type='split', learning_rate=0.1,
#                                      max_depth=-1, min_child_samples=20,
#                                      min_child_weight=0.001, min_split_gain=0.0,
#                                      n_estimators=10000, n_jobs=-1,
#                                      num_leaves=31, objective=None,
#                                      random_state=777, reg_alpha=0.0,
#                                      reg_lambda=0.0, silent=True, subsample=1.0,
#                                      subsample_for_bin=200000,
#                                      subsample_freq=0),
#              iid='deprecated', n_jobs=None,
#              param_grid={'learning_rate': [0.001, 0.0001, 1e-05],
#                          'min_child_samples': [20, 30]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=make_scorer(rmse), verbose=0)

# %%
gs.best_params_
# Out:
# {'learning_rate': 1e-05, 'min_child_samples': 30}

# %%
model = lgb.LGBMRegressor(random_state = 777, n_estimators=10000, learning_rate= 1e-05, min_child_samples= 30)
models = []
for train_idx, val_idx in k_fold.split(X_train) :
    x_t = X_train.iloc[train_idx]
    y_t = Y_train.iloc[train_idx]
    x_val = X_train.iloc[val_idx]
    y_val = Y_train.iloc[val_idx]
    
    models.append(model.fit(x_t, y_t, eval_set = (x_val, y_val), early_stopping_rounds=1000, verbose=100))
# Out:
# Training until validation scores don't improve for 1000 rounds
# [100]	valid_0's l2: 4.39233e+12
# [200]	valid_0's l2: 4.39124e+12
# [300]	valid_0's l2: 4.39015e+12
# [400]	valid_0's l2: 4.38906e+12
# [500]	valid_0's l2: 4.38798e+12
# [600]	valid_0's l2: 4.3869e+12
# [700]	valid_0's l2: 4.38582e+12
# [800]	valid_0's l2: 4.38474e+12
# [900]	valid_0's l2: 4.38367e+12
# [1000]	valid_0's l2: 4.3826e+12
# [1100]	valid_0's l2: 4.38153e+12
# [1200]	valid_0's l2: 4.38047e+12
# [1300]	valid_0's l2: 4.37941e+12
# [1400]	valid_0's l2: 4.37835e+12
# [4900]	valid_0's l2: 1.13788e+12
# [5000]	valid_0's l2: 1.13684e+12
# [5100]	valid_0's l2: 1.1358e+12
# [5200]	valid_0's l2: 1.13476e+12
# [5300]	valid_0's l2: 1.13373e+12
# [5400]	valid_0's l2: 1.1327e+12
# [5500]	valid_0's l2: 1.13167e+12
# [5600]	valid_0's l2: 1.13064e+12
# [5700]	valid_0's l2: 1.12962e+12
# [5800]	valid_0's l2: 1.1286e+12
# [5900]	valid_0's l2: 1.12759e+12
# [6000]	valid_0's l2: 1.12658e+12
# [6100]	valid_0's l2: 1.12557e+12
# [6200]	valid_0's l2: 1.12456e+12
# [6300]	valid_0's l2: 1.12356e+12
# [6400]	valid_0's l2: 1.12256e+12
# [6500]	valid_0's l2: 1.12156e+12
# [6600]	valid_0's l2: 1.12057e+12
# [6700]	valid_0's l2: 1.11958e+12
# [6800]	valid_0's l2: 1.11859e+12
# [6900]	valid_0's l2: 1.1176e+12
# [7000]	valid_0's l2: 1.11662e+12
# [7100]	valid_0's l2: 1.11564e+12
# [7200]	valid_0's l2: 1.11466e+12
# [7300]	valid_0's l2: 1.11369e+12
# [7400]	valid_0's l2: 1.11272e+12
# [7500]	valid_0's l2: 1.11176e+12
# [7600]	valid_0's l2: 1.11083e+12
# [7700]	valid_0's l2: 1.1099e+12
# [7800]	valid_0's l2: 1.10897e+12
# [7900]	valid_0's l2: 1.10805e+12
# [8000]	valid_0's l2: 1.10713e+12
# [8100]	valid_0's l2: 1.10622e+12
# [8200]	valid_0's l2: 1.1053e+12
# [8300]	valid_0's l2: 1.10439e+12
# [8400]	valid_0's l2: 1.10348e+12
# [8500]	valid_0's l2: 1.10258e+12
# [8600]	valid_0's l2: 1.10167e+12
# [8700]	valid_0's l2: 1.10077e+12
# [8800]	valid_0's l2: 1.09988e+12
# [8900]	valid_0's l2: 1.09898e+12
# [9000]	valid_0's l2: 1.09809e+12
# [9100]	valid_0's l2: 1.0972e+12
# [9200]	valid_0's l2: 1.09631e+12
# [9300]	valid_0's l2: 1.09543e+12
# [9400]	valid_0's l2: 1.09454e+12
# [9500]	valid_0's l2: 1.09367e+12
# [9600]	valid_0's l2: 1.09279e+12
# [9700]	valid_0's l2: 1.09192e+12
# [9800]	valid_0's l2: 1.09104e+12
# [9900]	valid_0's l2: 1.09018e+12
# [10000]	valid_0's l2: 1.08931e+12
# Did not meet early stopping. Best iteration is:
# [10000]	valid_0's l2: 1.08931e+12
# Training until validation scores don't improve for 1000 rounds
# [100]	valid_0's l2: 5.55181e+12
# [200]	valid_0's l2: 5.55025e+12
# [300]	valid_0's l2: 5.5487e+12
# [400]	valid_0's l2: 5.54696e+12
# [500]	valid_0's l2: 5.54502e+12
# [600]	valid_0's l2: 5.54307e+12
# [700]	valid_0's l2: 5.54113e+12
# [800]	valid_0's l2: 5.5392e+12
# [900]	valid_0's l2: 5.53727e+12
# [1000]	valid_0's l2: 5.53534e+12
# [1100]	valid_0's l2: 5.53341e+12
# [1200]	valid_0's l2: 5.53149e+12
# [1300]	valid_0's l2: 5.52957e+12
# [1400]	valid_0's l2: 5.52766e+12
# [1500]	valid_0's l2: 5.52575e+12
# [5000]	valid_0's l2: 3.60838e+12
# [5100]	valid_0's l2: 3.6054e+12
# [5200]	valid_0's l2: 3.60243e+12
# [5300]	valid_0's l2: 3.59946e+12
# [5400]	valid_0's l2: 3.5965e+12
# [5500]	valid_0's l2: 3.59354e+12
# [5600]	valid_0's l2: 3.59059e+12
# [5700]	valid_0's l2: 3.58765e+12
# [5800]	valid_0's l2: 3.58471e+12
# [5900]	valid_0's l2: 3.58178e+12
# [6000]	valid_0's l2: 3.57885e+12
# [6100]	valid_0's l2: 3.57593e+12
# [6200]	valid_0's l2: 3.57301e+12
# [6300]	valid_0's l2: 3.5701e+12
# [6400]	valid_0's l2: 3.56719e+12
# [6500]	valid_0's l2: 3.5643e+12
# [6600]	valid_0's l2: 3.5614e+12
# [6700]	valid_0's l2: 3.55851e+12
# [6800]	valid_0's l2: 3.55563e+12
# [6900]	valid_0's l2: 3.55275e+12
# [7000]	valid_0's l2: 3.54988e+12
# [7100]	valid_0's l2: 3.54701e+12
# [7200]	valid_0's l2: 3.54415e+12
# [7300]	valid_0's l2: 3.5413e+12
# [7400]	valid_0's l2: 3.53845e+12
# [7500]	valid_0's l2: 3.5356e+12
# [7600]	valid_0's l2: 3.53276e+12
# [7700]	valid_0's l2: 3.52993e+12
# [7800]	valid_0's l2: 3.5271e+12
# [7900]	valid_0's l2: 3.52428e+12
# [8000]	valid_0's l2: 3.52146e+12
# [8100]	valid_0's l2: 3.51865e+12
# [8200]	valid_0's l2: 3.51584e+12
# [8300]	valid_0's l2: 3.51304e+12
# [8400]	valid_0's l2: 3.51024e+12
# [8500]	valid_0's l2: 3.50745e+12
# [8600]	valid_0's l2: 3.50466e+12
# [8700]	valid_0's l2: 3.50188e+12
# [8800]	valid_0's l2: 3.49911e+12
# [8900]	valid_0's l2: 3.49634e+12
# [9000]	valid_0's l2: 3.49357e+12
# [9100]	valid_0's l2: 3.49081e+12
# [9200]	valid_0's l2: 3.48806e+12
# [9300]	valid_0's l2: 3.48531e+12
# [9400]	valid_0's l2: 3.48257e+12
# [9500]	valid_0's l2: 3.47983e+12
# [9600]	valid_0's l2: 3.47712e+12
# [9700]	valid_0's l2: 3.4745e+12
# [9800]	valid_0's l2: 3.47188e+12
# [9900]	valid_0's l2: 3.46927e+12
# [10000]	valid_0's l2: 3.46666e+12
# Did not meet early stopping. Best iteration is:
# [10000]	valid_0's l2: 3.46666e+12

# %%
preds = []
for model in models :
    preds.append(model.predict(X_test))
len(preds)
# Out:
# 10

# %%
import numpy as np
prediction = np.mean(preds, axis=0)

# %%
prediction
# Out:
# array([691695.2517164 , 672319.21502713, 851316.339441  , 903897.40003323,
#        903897.40003323, 635577.41282796, 626110.17356157, 625556.93486383,
#        625560.00726256, 691239.28514796, 635820.24005134, 691695.2517164 ,
#        691695.2517164 , 625676.61787807, 851316.339441  , 955633.49804001,
#        625999.87401811, 851316.339441  , 672319.21502713, 757723.25541921,
#        625556.93486383, 627289.84345835, 635820.24005134, 625556.93486383,
#        625556.93486383, 955633.49804001, 625808.53751061, 903897.40003323,
#        625999.87401811, 905222.17818192, 627251.25526062, 851788.03603721,
#        903524.13404399, 691239.28514796, 627269.50418685, 625556.93486383,
#        903524.13404399, 627269.50418685, 625560.00726256, 625998.10245973,
#        627251.25526062, 903524.13404399, 757723.25541921, 627289.84345835,
#        630926.25772527, 625556.93486383, 625556.93486383, 693020.0298651 ,
#        630926.25772527, 956958.27618871, 625998.10245973, 692166.94831261,
#        630946.59699677, 626110.17356157, 625556.93486383, 626110.17356157,
#        635577.41282796, 625556.93486383, 625556.93486383, 626110.17356157,
#        691239.28514796, 625556.93486383, 625806.83558885])

# %% [markdown]
# ## sklearn_RandomForestRegressor
# + RMSE + Hyper Parameter Tuning

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators=300,
                              n_jobs=-1,
                              random_state=46)

X_train, X_test, Y_train = df.drop(['box_off_num'], axis=1), testdf, df['box_off_num']

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

n_estimators = 300

# 랜덤 서치 횟수
num_epoch = 100

# hyperparameter 탐색 결과가 저장될 리스트
coarse_hyperparameters_list = []

for epoch in range(num_epoch):
    # max depth의 값을 2~100으로 설정
    max_depth = np.random.randint(low=2, high=100)

    # 적용할 feature의 비율을 0.1~1.0로 설정
    max_features = np.random.uniform(low=0.1, high=1.0)

    model = RandomForestRegressor(n_estimators=n_estimators,
                                  max_depth=max_depth,
                                  max_features=max_features,
                                  n_jobs=-1,
                                  random_state=37)

    # cross_val_score를 실행하여 rmse의 평균 계산
    # cv는 데이터 조각 개수
    score = cross_val_score(model, X_train, Y_train, cv=20, scoring=rmse_score).mean() 
    
    # hyperparameter 탐색 결과를 저장할 딕셔너리
    hyperparameters = {
        'epoch': epoch,
        'score': score,
        'n_estimators': n_estimators,
        'max_depth': max_depth,
        'max_features': max_features,
    }

    # hyperparameter 탐색 결과 저장
    coarse_hyperparameters_list.append(hyperparameters)

    # hyperparameter 탐색 결과를 출력
    print(f"{epoch:2} n_estimators = {n_estimators}, max_depth = {max_depth:2}, max_features = {max_features:.6f}, Score = {score:.5f}")

# coarse_hyperparameters_list를 DataFrame으로 변환
coarse_hyperparameters_list = pd.DataFrame.from_dict(coarse_hyperparameters_list)

# coarse_hyperparameters_list를 score가 낮은 순으로 정렬
coarse_hyperparameters_list = coarse_hyperparameters_list.sort_values(by="score")

print(coarse_hyperparameters_list.shape)

# coarse_hyperparameters_list의 상위 10개 출력
coarse_hyperparameters_list.head(10)
# Out:
#  0 n_estimators = 300, max_depth = 16, max_features = 0.409949, Score = 1402318.02266
#  1 n_estimators = 300, max_depth = 55, max_features = 0.422064, Score = 1395322.21371
#  2 n_estimators = 300, max_depth = 76, max_features = 0.612081, Score = 1416063.77616
#  3 n_estimators = 300, max_depth = 60, max_features = 0.189779, Score = 1386043.89438
#  4 n_estimators = 300, max_depth = 41, max_features = 0.621778, Score = 1416063.77616
#  5 n_estimators = 300, max_depth = 91, max_features = 0.314321, Score = 1398817.44390
#  6 n_estimators = 300, max_depth = 58, max_features = 0.504237, Score = 1399404.89278
#  7 n_estimators = 300, max_depth = 61, max_features = 0.290052, Score = 1398817.44390
#  8 n_estimators = 300, max_depth = 25, max_features = 0.447175, Score = 1397630.36966
#  9 n_estimators = 300, max_depth = 36, max_features = 0.638991, Score = 1411063.25289
# 10 n_estimators = 300, max_depth = 27, max_features = 0.205314, Score = 1385924.85140
# 11 n_estimators = 300, max_depth = 43, max_features = 0.605389, Score = 1416063.77616
# 12 n_estimators = 300, max_depth = 36, max_features = 0.180511, Score = 1370245.49179
# 13 n_estimators = 300, max_depth = 23, max_features = 0.126297, Score = 1370687.69112
# 14 n_estimators = 300, max_depth = 29, max_features = 0.925901, Score = 1437260.72053
# 15 n_estimators = 300, max_depth = 21, max_features = 0.692659, Score = 1412279.58869
# 16 n_estimators = 300, max_depth = 65, max_features = 0.627979, Score = 1416063.77616
# 17 n_estimators = 300, max_depth =  2, max_features = 0.843078, Score = 1410765.47184
# 18 n_estimators = 300, max_depth = 37, max_features = 0.457722, Score = 1399404.89278
# 19 n_estimators = 300, max_depth = 67, max_features = 0.540324, Score = 1399404.89278
# 20 n_estimators = 300, max_depth = 22, max_features = 0.949234, Score = 1438989.64924
# 21 n_estimators = 300, max_depth = 70, max_features = 0.955352, Score = 1437260.72053
# 22 n_estimators = 300, max_depth = 25, max_features = 0.948112, Score = 1436605.09752
# 23 n_estimators = 300, max_depth = 33, max_features = 0.319004, Score = 1398817.44390
# 24 n_estimators = 300, max_depth = 16, max_features = 0.749834, Score = 1430245.81746
# 25 n_estimators = 300, max_depth = 13, max_features = 0.824850, Score = 1434912.50893
# 26 n_estimators = 300, max_depth = 22, max_features = 0.438748, Score = 1393943.37090
# 27 n_estimators = 300, max_depth = 62, max_features = 0.390491, Score = 1395322.21371
# 28 n_estimators = 300, max_depth = 47, max_features = 0.376427, Score = 1395322.21371
# 29 n_estimators = 300, max_depth = 43, max_features = 0.157087, Score = 1370245.49179
# 30 n_estimators = 300, max_depth = 15, max_features = 0.120947, Score = 1373123.99616
# 31 n_estimators = 300, max_depth = 76, max_features = 0.108366, Score = 1370245.49179
# 32 n_estimators = 300, max_depth = 95, max_features = 0.482423, Score = 1399404.89278
# 33 n_estimators = 300, max_depth = 92, max_features = 0.998996, Score = 1437260.72053
# 34 n_estimators = 300, max_depth = 37, max_features = 0.226420, Score = 1386043.89438
# 35 n_estimators = 300, max_depth = 93, max_features = 0.315835, Score = 1398817.44390
# 36 n_estimators = 300, max_depth = 42, max_features = 0.140583, Score = 1370245.49179
# 37 n_estimators = 300, max_depth = 87, max_features = 0.622562, Score = 1416063.77616
# 38 n_estimators = 300, max_depth = 40, max_features = 0.388297, Score = 1395322.21371
# 39 n_estimators = 300, max_depth = 51, max_features = 0.219511, Score = 1386043.89438
# 40 n_estimators = 300, max_depth = 84, max_features = 0.495382, Score = 1399404.89278
# 41 n_estimators = 300, max_depth = 42, max_features = 0.595276, Score = 1416063.77616
# 42 n_estimators = 300, max_depth = 90, max_features = 0.816113, Score = 1426192.09304
# 43 n_estimators = 300, max_depth = 79, max_features = 0.877271, Score = 1424761.72107
# 44 n_estimators = 300, max_depth =  6, max_features = 0.417323, Score = 1394002.45044
# 45 n_estimators = 300, max_depth = 79, max_features = 0.617698, Score = 1416063.77616
# 46 n_estimators = 300, max_depth = 86, max_features = 0.834396, Score = 1424761.72107
# 47 n_estimators = 300, max_depth = 46, max_features = 0.341533, Score = 1398817.44390
# 48 n_estimators = 300, max_depth = 93, max_features = 0.192102, Score = 1386043.89438
# 49 n_estimators = 300, max_depth = 90, max_features = 0.190802, Score = 1386043.89438
# 50 n_estimators = 300, max_depth = 82, max_features = 0.527689, Score = 1399404.89278
# 51 n_estimators = 300, max_depth = 80, max_features = 0.377165, Score = 1395322.21371
# 52 n_estimators = 300, max_depth = 66, max_features = 0.323555, Score = 1398817.44390
# 53 n_estimators = 300, max_depth = 66, max_features = 0.711473, Score = 1411063.25289
# 54 n_estimators = 300, max_depth = 23, max_features = 0.979215, Score = 1435558.64835
# 55 n_estimators = 300, max_depth = 23, max_features = 0.469652, Score = 1396366.92066
# 56 n_estimators = 300, max_depth = 85, max_features = 0.225017, Score = 1386043.89438
# 57 n_estimators = 300, max_depth = 52, max_features = 0.772006, Score = 1426192.09304
# 58 n_estimators = 300, max_depth = 54, max_features = 0.601685, Score = 1416063.77616
# 59 n_estimators = 300, max_depth = 69, max_features = 0.775475, Score = 1426192.09304
# 60 n_estimators = 300, max_depth = 97, max_features = 0.293143, Score = 1398817.44390
# 61 n_estimators = 300, max_depth = 78, max_features = 0.370270, Score = 1395322.21371
# 62 n_estimators = 300, max_depth = 71, max_features = 0.525217, Score = 1399404.89278
# 63 n_estimators = 300, max_depth = 44, max_features = 0.654436, Score = 1411063.25289
# 64 n_estimators = 300, max_depth = 71, max_features = 0.941772, Score = 1437260.72053
# 65 n_estimators = 300, max_depth = 67, max_features = 0.667927, Score = 1411063.25289
# 66 n_estimators = 300, max_depth = 55, max_features = 0.834284, Score = 1424761.72107
# 67 n_estimators = 300, max_depth = 50, max_features = 0.770432, Score = 1426192.09304
# 68 n_estimators = 300, max_depth = 40, max_features = 0.131300, Score = 1370245.49179
# 69 n_estimators = 300, max_depth =  3, max_features = 0.693966, Score = 1391299.70995
# 70 n_estimators = 300, max_depth = 28, max_features = 0.143567, Score = 1370245.49179
# 71 n_estimators = 300, max_depth = 61, max_features = 0.278721, Score = 1398817.44390
# 72 n_estimators = 300, max_depth = 92, max_features = 0.304822, Score = 1398817.44390
# 73 n_estimators = 300, max_depth = 76, max_features = 0.156138, Score = 1370245.49179
# 74 n_estimators = 300, max_depth = 60, max_features = 0.599408, Score = 1416063.77616
# 75 n_estimators = 300, max_depth = 89, max_features = 0.844815, Score = 1424761.72107
# 76 n_estimators = 300, max_depth =  8, max_features = 0.254417, Score = 1384198.22841
# 77 n_estimators = 300, max_depth = 67, max_features = 0.878603, Score = 1424761.72107
# 78 n_estimators = 300, max_depth = 46, max_features = 0.486945, Score = 1399404.89278
# 79 n_estimators = 300, max_depth = 39, max_features = 0.795557, Score = 1426192.09304
# 80 n_estimators = 300, max_depth = 91, max_features = 0.521709, Score = 1399404.89278
# 81 n_estimators = 300, max_depth = 17, max_features = 0.819998, Score = 1428735.50810
# 82 n_estimators = 300, max_depth = 20, max_features = 0.205451, Score = 1382808.92413
# 83 n_estimators = 300, max_depth =  7, max_features = 0.708148, Score = 1411485.82137
# 84 n_estimators = 300, max_depth = 58, max_features = 0.901808, Score = 1424761.72107
# 85 n_estimators = 300, max_depth = 22, max_features = 0.660980, Score = 1411482.63413
# 86 n_estimators = 300, max_depth = 86, max_features = 0.233674, Score = 1386043.89438
# 87 n_estimators = 300, max_depth = 21, max_features = 0.503557, Score = 1400198.27984
# 88 n_estimators = 300, max_depth = 62, max_features = 0.998137, Score = 1437260.72053
# 89 n_estimators = 300, max_depth = 74, max_features = 0.855326, Score = 1424761.72107
# 90 n_estimators = 300, max_depth = 44, max_features = 0.918299, Score = 1437260.72053
# 91 n_estimators = 300, max_depth = 92, max_features = 0.276644, Score = 1398817.44390
# 92 n_estimators = 300, max_depth = 37, max_features = 0.785671, Score = 1426192.09304
# 93 n_estimators = 300, max_depth = 11, max_features = 0.978871, Score = 1431348.66188
# 94 n_estimators = 300, max_depth = 45, max_features = 0.599006, Score = 1416063.77616
# 95 n_estimators = 300, max_depth = 34, max_features = 0.968525, Score = 1437260.72053
# 96 n_estimators = 300, max_depth =  9, max_features = 0.306847, Score = 1392352.09396
# 97 n_estimators = 300, max_depth = 86, max_features = 0.881093, Score = 1424761.72107
# 98 n_estimators = 300, max_depth = 94, max_features = 0.876137, Score = 1424761.72107
# 99 n_estimators = 300, max_depth = 45, max_features = 0.996306, Score = 1437260.72053
# (100, 5)
#     epoch         score  n_estimators  max_depth  max_features
# 73     73  1.370245e+06           300         76      0.156138
# 70     70  1.370245e+06           300         28      0.143567
# 29     29  1.370245e+06           300         43      0.157087
# 12     12  1.370245e+06           300         36      0.180511
# 36     36  1.370245e+06           300         42      0.140583
# 31     31  1.370245e+06           300         76      0.108366
# 68     68  1.370245e+06           300         40      0.131300
# 13     13  1.370688e+06           300         23      0.126297
# 30     30  1.373124e+06           300         15      0.120947
# 82     82  1.382809e+06           300         20      0.205451

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

n_estimators = 300
num_epoch = 100
finer_hyperparameters_list = []

for epoch in range(num_epoch):
    # coarse 단계에서 찾은 뎁스와 피쳐비율 구간을 적용
    max_depth = np.random.randint(low=5, high=35)
    max_features = np.random.uniform(low=0.1, high=0.3)
    
    model = RandomForestRegressor(n_estimators=n_estimators,
                                  max_depth=max_depth,
                                  max_features=max_features,
                                  n_jobs=-1,
                                  random_state=37)

    score = cross_val_score(model, X_train, Y_train, cv=10, scoring=rmse_score).mean()
    hyperparameters = {
        'epoch': epoch,
        'score': score,
        'n_estimators': n_estimators,
        'max_depth': max_depth,
        'max_features': max_features,
    }

    finer_hyperparameters_list.append(hyperparameters)
    print(f"{epoch:2} n_estimators = {n_estimators}, max_depth = {max_depth:2}, max_features = {max_features:.6f}, Score = {score:.5f}")

finer_hyperparameters_list = pd.DataFrame.from_dict(finer_hyperparameters_list)
finer_hyperparameters_list = finer_hyperparameters_list.sort_values(by="score")
print(finer_hyperparameters_list.shape)

finer_hyperparameters_list.head(10)
# Out:
#  0 n_estimators = 300, max_depth =  7, max_features = 0.295491, Score = 1387576.52512
#  1 n_estimators = 300, max_depth = 28, max_features = 0.109466, Score = 1370245.49179
#  2 n_estimators = 300, max_depth = 25, max_features = 0.124711, Score = 1370257.05978
#  3 n_estimators = 300, max_depth = 30, max_features = 0.131238, Score = 1370245.49179
#  4 n_estimators = 300, max_depth = 23, max_features = 0.230181, Score = 1386999.99604
#  5 n_estimators = 300, max_depth = 12, max_features = 0.256265, Score = 1392230.07961
#  6 n_estimators = 300, max_depth = 31, max_features = 0.176817, Score = 1370245.49179
#  7 n_estimators = 300, max_depth =  8, max_features = 0.125674, Score = 1381108.73156
#  8 n_estimators = 300, max_depth = 28, max_features = 0.299237, Score = 1398533.24470
#  9 n_estimators = 300, max_depth = 28, max_features = 0.137459, Score = 1370245.49179
# 10 n_estimators = 300, max_depth = 25, max_features = 0.116580, Score = 1370257.05978
# 11 n_estimators = 300, max_depth = 14, max_features = 0.277214, Score = 1393907.82956
# 12 n_estimators = 300, max_depth =  9, max_features = 0.232167, Score = 1378708.20907
# 13 n_estimators = 300, max_depth = 34, max_features = 0.203879, Score = 1386043.89438
# 14 n_estimators = 300, max_depth = 33, max_features = 0.149006, Score = 1370245.49179
# 15 n_estimators = 300, max_depth = 30, max_features = 0.227266, Score = 1386043.89438
# 16 n_estimators = 300, max_depth = 34, max_features = 0.295482, Score = 1398817.44390
# 17 n_estimators = 300, max_depth = 32, max_features = 0.292626, Score = 1398817.44390
# 18 n_estimators = 300, max_depth = 23, max_features = 0.101924, Score = 1370687.69112
# 19 n_estimators = 300, max_depth = 32, max_features = 0.248766, Score = 1386043.89438
# 20 n_estimators = 300, max_depth = 21, max_features = 0.227927, Score = 1386410.72103
# 21 n_estimators = 300, max_depth = 26, max_features = 0.291427, Score = 1398169.27025
# 22 n_estimators = 300, max_depth = 26, max_features = 0.171735, Score = 1370245.49179
# 23 n_estimators = 300, max_depth = 15, max_features = 0.193202, Score = 1387506.41035
# 24 n_estimators = 300, max_depth = 27, max_features = 0.298098, Score = 1398796.73252
# 25 n_estimators = 300, max_depth = 17, max_features = 0.190673, Score = 1393927.48325
# 26 n_estimators = 300, max_depth = 14, max_features = 0.207186, Score = 1371017.12252
# 27 n_estimators = 300, max_depth = 17, max_features = 0.109756, Score = 1361943.06824
# 28 n_estimators = 300, max_depth = 18, max_features = 0.178450, Score = 1365153.38845
# 29 n_estimators = 300, max_depth = 12, max_features = 0.125983, Score = 1371420.90973
# 30 n_estimators = 300, max_depth = 19, max_features = 0.202928, Score = 1383696.18951
# 31 n_estimators = 300, max_depth = 31, max_features = 0.177373, Score = 1370245.49179
# 32 n_estimators = 300, max_depth =  5, max_features = 0.141104, Score = 1412761.79593
# 33 n_estimators = 300, max_depth = 20, max_features = 0.101863, Score = 1369232.13113
# 34 n_estimators = 300, max_depth = 21, max_features = 0.233151, Score = 1386410.72103
# 35 n_estimators = 300, max_depth = 30, max_features = 0.146019, Score = 1370245.49179
# 36 n_estimators = 300, max_depth = 26, max_features = 0.127442, Score = 1370245.49179
# 37 n_estimators = 300, max_depth = 25, max_features = 0.265336, Score = 1385117.50552
# 38 n_estimators = 300, max_depth =  9, max_features = 0.196403, Score = 1378708.20907
# 39 n_estimators = 300, max_depth = 13, max_features = 0.123975, Score = 1373691.45714
# 40 n_estimators = 300, max_depth = 19, max_features = 0.134455, Score = 1375029.73075
# 41 n_estimators = 300, max_depth =  8, max_features = 0.278228, Score = 1400961.15821
# 42 n_estimators = 300, max_depth = 23, max_features = 0.284758, Score = 1396632.64781
# 43 n_estimators = 300, max_depth = 22, max_features = 0.188885, Score = 1389438.80111
# 44 n_estimators = 300, max_depth = 23, max_features = 0.254336, Score = 1386999.99604
# 45 n_estimators = 300, max_depth = 23, max_features = 0.233408, Score = 1386999.99604
# 46 n_estimators = 300, max_depth = 28, max_features = 0.214522, Score = 1386043.89438
# 47 n_estimators = 300, max_depth = 32, max_features = 0.190179, Score = 1386043.89438
# 48 n_estimators = 300, max_depth = 23, max_features = 0.227617, Score = 1386999.99604
# 49 n_estimators = 300, max_depth =  7, max_features = 0.175015, Score = 1395780.12162
# 50 n_estimators = 300, max_depth = 15, max_features = 0.293024, Score = 1400153.38371
# 51 n_estimators = 300, max_depth =  5, max_features = 0.162103, Score = 1412761.79593
# 52 n_estimators = 300, max_depth = 17, max_features = 0.229746, Score = 1393927.48325
# 53 n_estimators = 300, max_depth =  9, max_features = 0.230083, Score = 1378708.20907
# 54 n_estimators = 300, max_depth = 26, max_features = 0.248335, Score = 1385119.00478
# 55 n_estimators = 300, max_depth = 28, max_features = 0.245316, Score = 1386043.89438
# 56 n_estimators = 300, max_depth = 29, max_features = 0.142623, Score = 1370245.49179
# 57 n_estimators = 300, max_depth = 13, max_features = 0.193922, Score = 1373391.82464
# 58 n_estimators = 300, max_depth =  9, max_features = 0.111685, Score = 1383000.31707
# 59 n_estimators = 300, max_depth =  6, max_features = 0.242699, Score = 1378408.19037
# 60 n_estimators = 300, max_depth = 31, max_features = 0.174602, Score = 1370245.49179
# 61 n_estimators = 300, max_depth = 19, max_features = 0.235548, Score = 1383696.18951
# 62 n_estimators = 300, max_depth = 25, max_features = 0.114185, Score = 1370257.05978
# 63 n_estimators = 300, max_depth = 15, max_features = 0.138837, Score = 1373123.99616
# 64 n_estimators = 300, max_depth = 34, max_features = 0.125146, Score = 1370245.49179
# 65 n_estimators = 300, max_depth =  9, max_features = 0.119236, Score = 1383000.31707
# 66 n_estimators = 300, max_depth = 30, max_features = 0.196973, Score = 1386043.89438
# 67 n_estimators = 300, max_depth = 26, max_features = 0.184404, Score = 1385119.00478
# 68 n_estimators = 300, max_depth = 14, max_features = 0.152656, Score = 1371130.16638
# 69 n_estimators = 300, max_depth = 15, max_features = 0.118144, Score = 1373123.99616
# 70 n_estimators = 300, max_depth = 26, max_features = 0.254827, Score = 1385119.00478
# 71 n_estimators = 300, max_depth =  8, max_features = 0.142220, Score = 1381108.73156
# 72 n_estimators = 300, max_depth = 12, max_features = 0.123610, Score = 1371420.90973
# 73 n_estimators = 300, max_depth = 19, max_features = 0.250507, Score = 1383696.18951
# 74 n_estimators = 300, max_depth = 20, max_features = 0.166322, Score = 1369232.13113
# 75 n_estimators = 300, max_depth = 25, max_features = 0.214916, Score = 1385117.50552
# 76 n_estimators = 300, max_depth = 25, max_features = 0.132387, Score = 1370257.05978
# 77 n_estimators = 300, max_depth = 17, max_features = 0.247154, Score = 1393927.48325
# 78 n_estimators = 300, max_depth = 10, max_features = 0.181792, Score = 1374240.95260
# 79 n_estimators = 300, max_depth = 23, max_features = 0.279633, Score = 1396632.64781
# 80 n_estimators = 300, max_depth =  9, max_features = 0.175501, Score = 1383000.31707
# 81 n_estimators = 300, max_depth = 13, max_features = 0.120626, Score = 1373691.45714
# 82 n_estimators = 300, max_depth = 34, max_features = 0.110388, Score = 1370245.49179
# 83 n_estimators = 300, max_depth =  8, max_features = 0.248701, Score = 1384198.22841
# 84 n_estimators = 300, max_depth =  9, max_features = 0.109589, Score = 1383000.31707
# 85 n_estimators = 300, max_depth = 10, max_features = 0.108725, Score = 1374240.95260
# 86 n_estimators = 300, max_depth = 32, max_features = 0.119901, Score = 1370245.49179
# 87 n_estimators = 300, max_depth = 17, max_features = 0.109632, Score = 1361943.06824
# 88 n_estimators = 300, max_depth =  8, max_features = 0.263897, Score = 1384198.22841
# 89 n_estimators = 300, max_depth =  8, max_features = 0.283704, Score = 1400961.15821
# 90 n_estimators = 300, max_depth = 24, max_features = 0.197572, Score = 1386226.75695
# 91 n_estimators = 300, max_depth = 14, max_features = 0.133223, Score = 1371130.16638
# 92 n_estimators = 300, max_depth =  5, max_features = 0.276558, Score = 1390145.39458
# 93 n_estimators = 300, max_depth = 22, max_features = 0.266463, Score = 1389438.80111
# 94 n_estimators = 300, max_depth =  5, max_features = 0.202467, Score = 1383488.49659
# 95 n_estimators = 300, max_depth = 27, max_features = 0.203567, Score = 1385924.85140
# 96 n_estimators = 300, max_depth = 22, max_features = 0.265469, Score = 1389438.80111
# 97 n_estimators = 300, max_depth =  7, max_features = 0.231431, Score = 1380476.95155
# 98 n_estimators = 300, max_depth = 18, max_features = 0.201538, Score = 1378757.53983
# 99 n_estimators = 300, max_depth = 15, max_features = 0.190725, Score = 1387506.41035
# (100, 5)
#     epoch         score  n_estimators  max_depth  max_features
# 27     27  1.361943e+06           300         17      0.109756
# 87     87  1.361943e+06           300         17      0.109632
# 28     28  1.365153e+06           300         18      0.178450
# 74     74  1.369232e+06           300         20      0.166322
# 33     33  1.369232e+06           300         20      0.101863
# 60     60  1.370245e+06           300         31      0.174602
# 86     86  1.370245e+06           300         32      0.119901
# 22     22  1.370245e+06           300         26      0.171735
# 82     82  1.370245e+06           300         34      0.110388
# 56     56  1.370245e+06           300         29      0.142623

# %%
# 가장 정확도가 높은 하이퍼패러미터를 저장
best_hyperparameters = finer_hyperparameters_list.iloc[0]

best_max_depth = best_hyperparameters["max_depth"]
best_max_features = best_hyperparameters["max_features"]

print(f"max_depth(best) = {best_max_depth}, max_features(best) = {best_max_features:.6f}")
# Out:
# max_depth(best) = 17.0, max_features(best) = 0.109756

# %%
from sklearn.ensemble import RandomForestRegressor

best_n_estimators = 3000
model = RandomForestRegressor(n_estimators=best_n_estimators,
                              max_depth=best_max_depth,
                              max_features=best_max_features,
                              random_state=37,
                              n_jobs=-1)
model
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=17.0, max_features=0.10975579145936998,
#                       max_leaf_nodes=None, max_samples=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=3000,
#                       n_jobs=-1, oob_score=False, random_state=37, verbose=0,
#                       warm_start=False)

# %%
model.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=17.0, max_features=0.10975579145936998,
#                       max_leaf_nodes=None, max_samples=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=3000,
#                       n_jobs=-1, oob_score=False, random_state=37, verbose=0,
#                       warm_start=False)

# %%
prediction = model.predict(X_test)

# %% [markdown]
# ## 최적의 cv 찾기

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators=100,
                              n_jobs=-1,
                              random_state=37)

X_train, X_test, Y_train = df.drop(['box_off_num'], axis=1), testdf, df['box_off_num']

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

n_estimators = 100

# 랜덤 서치 횟수
num_epoch = 100

# %%
cv_cv = []
for cv_turn in range(19, 26, 2) : # 5, 7, 9, 11, 13, 15, 17, 19


# hyperparameter 탐색 결과가 저장될 리스트
    coarse_hyperparameters_list = []

    for epoch in range(num_epoch):
        # max depth의 값을 2~100으로 설정
        max_depth = np.random.randint(low=2, high=10)

        # 적용할 feature의 비율을 0.1~1.0로 설정
        max_features = np.random.uniform(low=0.1, high=1.0)

        model = RandomForestRegressor(n_estimators=n_estimators,
                                      max_depth=max_depth,
                                      max_features=max_features,
                                      n_jobs=-1,
                                      random_state=37)

        # cross_val_score를 실행하여 rmse의 평균 계산
        # cv는 데이터 조각 개수
        score = cross_val_score(model, X_train, Y_train, cv=cv_turn, scoring=rmse_score).mean() 

        # hyperparameter 탐색 결과를 저장할 딕셔너리
        hyperparameters = {
            'epoch': epoch,
            'score': score,
            'n_estimators': n_estimators,
            'max_depth': max_depth,
            'max_features': max_features,
            'cv' : cv_turn
        }

        # hyperparameter 탐색 결과 저장
        coarse_hyperparameters_list.append(hyperparameters)

        # hyperparameter 탐색 결과를 출력
        print(f"{epoch:2} n_estimators = {n_estimators}, max_depth = {max_depth:2}, max_features = {max_features:.6f}, Score = {score:.5f}, CV = {cv_turn}")

    # coarse_hyperparameters_list를 DataFrame으로 변환
    coarse_hyperparameters_list = pd.DataFrame.from_dict(coarse_hyperparameters_list)

    # coarse_hyperparameters_list를 score가 낮은 순으로 정렬
    coarse_hyperparameters_list = coarse_hyperparameters_list.sort_values(by="score")

    # coarse_hyperparameters_list의 상위 1개 저장
    cv_cv.append(coarse_hyperparameters_list.head(1))
# Out:
#  0 n_estimators = 100, max_depth =  9, max_features = 0.588160, Score = 1368625.20496, CV = 19
#  1 n_estimators = 100, max_depth =  9, max_features = 0.186807, Score = 1331492.98623, CV = 19
#  2 n_estimators = 100, max_depth =  6, max_features = 0.277720, Score = 1334560.48737, CV = 19
#  3 n_estimators = 100, max_depth =  8, max_features = 0.488045, Score = 1380670.81703, CV = 19
#  4 n_estimators = 100, max_depth =  4, max_features = 0.156042, Score = 1327652.76016, CV = 19
#  5 n_estimators = 100, max_depth =  3, max_features = 0.139559, Score = 1368062.22583, CV = 19
#  6 n_estimators = 100, max_depth =  4, max_features = 0.647293, Score = 1339973.49555, CV = 19
#  7 n_estimators = 100, max_depth =  6, max_features = 0.154642, Score = 1312550.05171, CV = 19
#  8 n_estimators = 100, max_depth =  6, max_features = 0.208733, Score = 1328723.28628, CV = 19
#  9 n_estimators = 100, max_depth =  3, max_features = 0.668858, Score = 1328771.53426, CV = 19
# 10 n_estimators = 100, max_depth =  6, max_features = 0.161062, Score = 1312550.05171, CV = 19
# 11 n_estimators = 100, max_depth =  9, max_features = 0.606190, Score = 1368625.20496, CV = 19
# 12 n_estimators = 100, max_depth =  2, max_features = 0.619242, Score = 1320885.79362, CV = 19
# 13 n_estimators = 100, max_depth =  9, max_features = 0.659647, Score = 1397265.12979, CV = 19
# 14 n_estimators = 100, max_depth =  6, max_features = 0.544811, Score = 1328296.83668, CV = 19
# 15 n_estimators = 100, max_depth =  5, max_features = 0.925123, Score = 1371918.97653, CV = 19
# 16 n_estimators = 100, max_depth =  4, max_features = 0.552287, Score = 1336248.00468, CV = 19
# 17 n_estimators = 100, max_depth =  4, max_features = 0.428723, Score = 1322041.98539, CV = 19
# 18 n_estimators = 100, max_depth =  2, max_features = 0.840313, Score = 1331437.32700, CV = 19
# 19 n_estimators = 100, max_depth =  4, max_features = 0.629357, Score = 1336248.00468, CV = 19
# 20 n_estimators = 100, max_depth =  6, max_features = 0.899464, Score = 1382422.51010, CV = 19
# 21 n_estimators = 100, max_depth =  6, max_features = 0.124825, Score = 1312550.05171, CV = 19
# 22 n_estimators = 100, max_depth =  7, max_features = 0.922858, Score = 1403531.53429, CV = 19
# 23 n_estimators = 100, max_depth =  8, max_features = 0.428602, Score = 1341553.54264, CV = 19
# 24 n_estimators = 100, max_depth =  3, max_features = 0.504636, Score = 1319244.66305, CV = 19
# 25 n_estimators = 100, max_depth =  5, max_features = 0.234854, Score = 1303383.28636, CV = 19
# 26 n_estimators = 100, max_depth =  9, max_features = 0.358638, Score = 1328284.09108, CV = 19
# 27 n_estimators = 100, max_depth =  4, max_features = 0.949745, Score = 1355759.15969, CV = 19
# 28 n_estimators = 100, max_depth =  5, max_features = 0.298035, Score = 1326066.81436, CV = 19
# 29 n_estimators = 100, max_depth =  2, max_features = 0.118074, Score = 1405777.82172, CV = 19
# 30 n_estimators = 100, max_depth =  3, max_features = 0.114982, Score = 1368062.22583, CV = 19
# 31 n_estimators = 100, max_depth =  6, max_features = 0.539686, Score = 1328296.83668, CV = 19
# 32 n_estimators = 100, max_depth =  3, max_features = 0.485719, Score = 1319244.66305, CV = 19
# 33 n_estimators = 100, max_depth =  4, max_features = 0.717865, Score = 1339973.49555, CV = 19
# 34 n_estimators = 100, max_depth =  6, max_features = 0.622364, Score = 1358982.25882, CV = 19
# 35 n_estimators = 100, max_depth =  8, max_features = 0.735580, Score = 1397728.66759, CV = 19
# 36 n_estimators = 100, max_depth =  2, max_features = 0.255962, Score = 1343571.62213, CV = 19
# 37 n_estimators = 100, max_depth =  8, max_features = 0.493767, Score = 1380670.81703, CV = 19
# 38 n_estimators = 100, max_depth =  7, max_features = 0.691160, Score = 1390221.48129, CV = 19
# 39 n_estimators = 100, max_depth =  9, max_features = 0.832419, Score = 1402065.59628, CV = 19
# 40 n_estimators = 100, max_depth =  2, max_features = 0.654456, Score = 1330392.84184, CV = 19
# 41 n_estimators = 100, max_depth =  7, max_features = 0.725173, Score = 1390221.48129, CV = 19
# 42 n_estimators = 100, max_depth =  8, max_features = 0.349077, Score = 1347012.52951, CV = 19
# 43 n_estimators = 100, max_depth =  3, max_features = 0.146097, Score = 1368062.22583, CV = 19
# 44 n_estimators = 100, max_depth =  8, max_features = 0.545671, Score = 1377347.53715, CV = 19
# 45 n_estimators = 100, max_depth =  4, max_features = 0.502176, Score = 1319642.56235, CV = 19
# 46 n_estimators = 100, max_depth =  6, max_features = 0.860112, Score = 1382422.51010, CV = 19
# 47 n_estimators = 100, max_depth =  6, max_features = 0.339174, Score = 1334560.48737, CV = 19
# 48 n_estimators = 100, max_depth =  7, max_features = 0.486524, Score = 1354836.55807, CV = 19
# 49 n_estimators = 100, max_depth =  8, max_features = 0.432342, Score = 1341553.54264, CV = 19
# 50 n_estimators = 100, max_depth =  3, max_features = 0.313346, Score = 1310304.82626, CV = 19
# 51 n_estimators = 100, max_depth =  5, max_features = 0.652909, Score = 1358105.56355, CV = 19
# 52 n_estimators = 100, max_depth =  2, max_features = 0.761414, Score = 1328526.16631, CV = 19
# 53 n_estimators = 100, max_depth =  7, max_features = 0.450845, Score = 1340628.12700, CV = 19
# 54 n_estimators = 100, max_depth =  3, max_features = 0.569515, Score = 1322269.06678, CV = 19
# 55 n_estimators = 100, max_depth =  6, max_features = 0.638331, Score = 1353001.27126, CV = 19
# 56 n_estimators = 100, max_depth =  5, max_features = 0.715559, Score = 1358105.56355, CV = 19
# 57 n_estimators = 100, max_depth =  3, max_features = 0.747348, Score = 1341636.74678, CV = 19
# 58 n_estimators = 100, max_depth =  5, max_features = 0.476993, Score = 1345002.29123, CV = 19
# 59 n_estimators = 100, max_depth =  6, max_features = 0.654510, Score = 1353001.27126, CV = 19
# 60 n_estimators = 100, max_depth =  2, max_features = 0.924083, Score = 1335001.11273, CV = 19
# 61 n_estimators = 100, max_depth =  6, max_features = 0.316928, Score = 1334560.48737, CV = 19
# 62 n_estimators = 100, max_depth =  4, max_features = 0.736969, Score = 1342149.84364, CV = 19
# 63 n_estimators = 100, max_depth =  3, max_features = 0.738591, Score = 1341636.74678, CV = 19
# 64 n_estimators = 100, max_depth =  2, max_features = 0.434032, Score = 1320396.62043, CV = 19
# 65 n_estimators = 100, max_depth =  8, max_features = 0.784412, Score = 1397728.66759, CV = 19
# 66 n_estimators = 100, max_depth =  3, max_features = 0.755455, Score = 1341636.74678, CV = 19
# 67 n_estimators = 100, max_depth =  7, max_features = 0.521506, Score = 1354836.55807, CV = 19
# 68 n_estimators = 100, max_depth =  4, max_features = 0.499558, Score = 1319642.56235, CV = 19
# 69 n_estimators = 100, max_depth =  9, max_features = 0.490463, Score = 1392342.96372, CV = 19
# 70 n_estimators = 100, max_depth =  6, max_features = 0.271469, Score = 1328723.28628, CV = 19
# 71 n_estimators = 100, max_depth =  4, max_features = 0.438832, Score = 1322041.98539, CV = 19
# 72 n_estimators = 100, max_depth =  8, max_features = 0.833778, Score = 1401218.30261, CV = 19
# 73 n_estimators = 100, max_depth =  5, max_features = 0.117823, Score = 1314032.89339, CV = 19
# 74 n_estimators = 100, max_depth =  4, max_features = 0.802291, Score = 1342149.84364, CV = 19
# 75 n_estimators = 100, max_depth =  9, max_features = 0.638750, Score = 1397265.12979, CV = 19
# 76 n_estimators = 100, max_depth =  2, max_features = 0.188531, Score = 1343571.62213, CV = 19
# 77 n_estimators = 100, max_depth =  9, max_features = 0.648797, Score = 1397265.12979, CV = 19
# 78 n_estimators = 100, max_depth =  3, max_features = 0.112979, Score = 1368062.22583, CV = 19
# 79 n_estimators = 100, max_depth =  6, max_features = 0.201969, Score = 1328723.28628, CV = 19
# 80 n_estimators = 100, max_depth =  2, max_features = 0.672014, Score = 1330392.84184, CV = 19
# 81 n_estimators = 100, max_depth =  3, max_features = 0.849382, Score = 1335167.78830, CV = 19
# 82 n_estimators = 100, max_depth =  7, max_features = 0.169317, Score = 1318103.32010, CV = 19
# 83 n_estimators = 100, max_depth =  5, max_features = 0.901229, Score = 1362508.44110, CV = 19
# 84 n_estimators = 100, max_depth =  9, max_features = 0.810623, Score = 1402849.28759, CV = 19
# 85 n_estimators = 100, max_depth =  8, max_features = 0.440183, Score = 1341553.54264, CV = 19
# 86 n_estimators = 100, max_depth =  7, max_features = 0.428886, Score = 1340628.12700, CV = 19
# 87 n_estimators = 100, max_depth =  4, max_features = 0.210401, Score = 1311873.28647, CV = 19
# 88 n_estimators = 100, max_depth =  3, max_features = 0.797738, Score = 1341636.74678, CV = 19
# 89 n_estimators = 100, max_depth =  8, max_features = 0.674144, Score = 1397528.52901, CV = 19
# 90 n_estimators = 100, max_depth =  6, max_features = 0.661913, Score = 1353001.27126, CV = 19
# 91 n_estimators = 100, max_depth =  5, max_features = 0.614807, Score = 1340571.65959, CV = 19
# 92 n_estimators = 100, max_depth =  6, max_features = 0.375984, Score = 1325544.68272, CV = 19
# 93 n_estimators = 100, max_depth =  6, max_features = 0.363944, Score = 1325544.68272, CV = 19
# 94 n_estimators = 100, max_depth =  4, max_features = 0.308204, Score = 1311110.55394, CV = 19
# 95 n_estimators = 100, max_depth =  8, max_features = 0.734583, Score = 1397728.66759, CV = 19
# 96 n_estimators = 100, max_depth =  6, max_features = 0.513371, Score = 1328296.83668, CV = 19
# 97 n_estimators = 100, max_depth =  4, max_features = 0.117498, Score = 1327652.76016, CV = 19
# 98 n_estimators = 100, max_depth =  6, max_features = 0.622689, Score = 1358982.25882, CV = 19
# 99 n_estimators = 100, max_depth =  6, max_features = 0.260789, Score = 1328723.28628, CV = 19
#  0 n_estimators = 100, max_depth =  7, max_features = 0.896782, Score = 1370953.50469, CV = 21
#  1 n_estimators = 100, max_depth =  6, max_features = 0.235150, Score = 1303831.68755, CV = 21
#  2 n_estimators = 100, max_depth =  8, max_features = 0.758821, Score = 1372100.68420, CV = 21
#  3 n_estimators = 100, max_depth =  9, max_features = 0.913992, Score = 1398756.77456, CV = 21
#  4 n_estimators = 100, max_depth =  6, max_features = 0.453888, Score = 1320166.87248, CV = 21
#  5 n_estimators = 100, max_depth =  3, max_features = 0.268249, Score = 1309120.01523, CV = 21
#  6 n_estimators = 100, max_depth =  5, max_features = 0.571977, Score = 1331464.71505, CV = 21
#  7 n_estimators = 100, max_depth =  8, max_features = 0.145614, Score = 1277252.89212, CV = 21
#  8 n_estimators = 100, max_depth =  8, max_features = 0.258836, Score = 1313623.53996, CV = 21
#  9 n_estimators = 100, max_depth =  2, max_features = 0.876078, Score = 1325749.36134, CV = 21
# 10 n_estimators = 100, max_depth =  7, max_features = 0.549819, Score = 1362691.25901, CV = 21
# 11 n_estimators = 100, max_depth =  2, max_features = 0.746708, Score = 1320837.68861, CV = 21
# 12 n_estimators = 100, max_depth =  7, max_features = 0.839504, Score = 1370953.50469, CV = 21
# 13 n_estimators = 100, max_depth =  2, max_features = 0.479672, Score = 1319081.04998, CV = 21
# 14 n_estimators = 100, max_depth =  4, max_features = 0.146986, Score = 1312123.41171, CV = 21
# 15 n_estimators = 100, max_depth =  6, max_features = 0.428085, Score = 1320166.87248, CV = 21
# 16 n_estimators = 100, max_depth =  5, max_features = 0.487647, Score = 1332742.91582, CV = 21
# 17 n_estimators = 100, max_depth =  2, max_features = 0.971955, Score = 1329472.45978, CV = 21
# 18 n_estimators = 100, max_depth =  6, max_features = 0.334411, Score = 1305375.61831, CV = 21
# 19 n_estimators = 100, max_depth =  8, max_features = 0.373553, Score = 1347532.76373, CV = 21
# 20 n_estimators = 100, max_depth =  9, max_features = 0.285856, Score = 1334372.96754, CV = 21
# 21 n_estimators = 100, max_depth =  2, max_features = 0.747216, Score = 1320837.68861, CV = 21
# 22 n_estimators = 100, max_depth =  3, max_features = 0.183612, Score = 1309120.01523, CV = 21
# 23 n_estimators = 100, max_depth =  2, max_features = 0.215261, Score = 1338509.28496, CV = 21
# 24 n_estimators = 100, max_depth =  2, max_features = 0.292046, Score = 1326078.90086, CV = 21
# 25 n_estimators = 100, max_depth =  2, max_features = 0.723021, Score = 1319194.17610, CV = 21
# 26 n_estimators = 100, max_depth =  5, max_features = 0.740576, Score = 1358407.49789, CV = 21
# 27 n_estimators = 100, max_depth =  2, max_features = 0.599079, Score = 1318957.99641, CV = 21
# 28 n_estimators = 100, max_depth =  8, max_features = 0.945407, Score = 1379519.60596, CV = 21
# 29 n_estimators = 100, max_depth =  6, max_features = 0.436558, Score = 1320166.87248, CV = 21
# 30 n_estimators = 100, max_depth =  2, max_features = 0.479371, Score = 1319081.04998, CV = 21
# 31 n_estimators = 100, max_depth =  4, max_features = 0.421117, Score = 1319620.77841, CV = 21
# 32 n_estimators = 100, max_depth =  5, max_features = 0.902758, Score = 1340022.53307, CV = 21
# 33 n_estimators = 100, max_depth =  2, max_features = 0.455738, Score = 1319081.04998, CV = 21
# 34 n_estimators = 100, max_depth =  4, max_features = 0.349045, Score = 1310781.17707, CV = 21
# 35 n_estimators = 100, max_depth =  8, max_features = 0.244138, Score = 1313623.53996, CV = 21
# 36 n_estimators = 100, max_depth =  6, max_features = 0.251904, Score = 1303831.68755, CV = 21
# 37 n_estimators = 100, max_depth =  4, max_features = 0.836893, Score = 1333255.24938, CV = 21
# 38 n_estimators = 100, max_depth =  4, max_features = 0.127603, Score = 1312123.41171, CV = 21
# 39 n_estimators = 100, max_depth =  6, max_features = 0.968326, Score = 1375605.42324, CV = 21
# 40 n_estimators = 100, max_depth =  6, max_features = 0.689173, Score = 1349384.40219, CV = 21
# 41 n_estimators = 100, max_depth =  7, max_features = 0.692955, Score = 1363656.63388, CV = 21
# 42 n_estimators = 100, max_depth =  4, max_features = 0.515370, Score = 1323330.44064, CV = 21
# 43 n_estimators = 100, max_depth =  4, max_features = 0.853665, Score = 1333255.24938, CV = 21
# 44 n_estimators = 100, max_depth =  4, max_features = 0.726213, Score = 1327786.43387, CV = 21
# 45 n_estimators = 100, max_depth =  4, max_features = 0.855685, Score = 1333255.24938, CV = 21
# 46 n_estimators = 100, max_depth =  4, max_features = 0.310425, Score = 1310781.17707, CV = 21
# 47 n_estimators = 100, max_depth =  5, max_features = 0.450838, Score = 1327745.10216, CV = 21
# 48 n_estimators = 100, max_depth =  7, max_features = 0.254683, Score = 1294474.45360, CV = 21
# 49 n_estimators = 100, max_depth =  4, max_features = 0.940600, Score = 1347691.84409, CV = 21
# 50 n_estimators = 100, max_depth =  4, max_features = 0.244430, Score = 1311591.78240, CV = 21
# 51 n_estimators = 100, max_depth =  8, max_features = 0.132733, Score = 1277252.89212, CV = 21
# 52 n_estimators = 100, max_depth =  2, max_features = 0.353864, Score = 1326078.90086, CV = 21
# 53 n_estimators = 100, max_depth =  9, max_features = 0.281320, Score = 1334372.96754, CV = 21
# 54 n_estimators = 100, max_depth =  4, max_features = 0.305977, Score = 1310781.17707, CV = 21
# 55 n_estimators = 100, max_depth =  7, max_features = 0.691155, Score = 1363656.63388, CV = 21
# 56 n_estimators = 100, max_depth =  8, max_features = 0.174468, Score = 1277252.89212, CV = 21
# 57 n_estimators = 100, max_depth =  2, max_features = 0.437823, Score = 1318075.43888, CV = 21
# 58 n_estimators = 100, max_depth =  8, max_features = 0.623734, Score = 1362752.22616, CV = 21
# 59 n_estimators = 100, max_depth =  9, max_features = 0.446114, Score = 1385707.47022, CV = 21
# 60 n_estimators = 100, max_depth =  9, max_features = 0.649808, Score = 1384190.29939, CV = 21
# 61 n_estimators = 100, max_depth =  5, max_features = 0.735378, Score = 1358407.49789, CV = 21
# 62 n_estimators = 100, max_depth =  4, max_features = 0.620926, Score = 1320694.19468, CV = 21
# 63 n_estimators = 100, max_depth =  2, max_features = 0.827960, Score = 1325749.36134, CV = 21
# 64 n_estimators = 100, max_depth =  5, max_features = 0.599446, Score = 1331464.71505, CV = 21
# 65 n_estimators = 100, max_depth =  3, max_features = 0.273752, Score = 1303756.58439, CV = 21
# 66 n_estimators = 100, max_depth =  2, max_features = 0.188661, Score = 1338509.28496, CV = 21
# 67 n_estimators = 100, max_depth =  7, max_features = 0.817954, Score = 1383655.99688, CV = 21
# 68 n_estimators = 100, max_depth =  4, max_features = 0.890631, Score = 1333255.24938, CV = 21
# 69 n_estimators = 100, max_depth =  8, max_features = 0.352114, Score = 1329349.45368, CV = 21
# 70 n_estimators = 100, max_depth =  5, max_features = 0.809297, Score = 1358407.49789, CV = 21
# 71 n_estimators = 100, max_depth =  4, max_features = 0.482887, Score = 1323330.44064, CV = 21
# 72 n_estimators = 100, max_depth =  2, max_features = 0.896984, Score = 1325749.36134, CV = 21
# 73 n_estimators = 100, max_depth =  9, max_features = 0.781998, Score = 1376462.49984, CV = 21
# 74 n_estimators = 100, max_depth =  9, max_features = 0.293265, Score = 1334372.96754, CV = 21
# 75 n_estimators = 100, max_depth =  4, max_features = 0.589456, Score = 1320694.19468, CV = 21
# 76 n_estimators = 100, max_depth =  7, max_features = 0.227435, Score = 1294474.45360, CV = 21
# 77 n_estimators = 100, max_depth =  8, max_features = 0.471142, Score = 1343602.91676, CV = 21
# 78 n_estimators = 100, max_depth =  8, max_features = 0.420364, Score = 1347532.76373, CV = 21
# 79 n_estimators = 100, max_depth =  3, max_features = 0.585040, Score = 1322652.27175, CV = 21
# 80 n_estimators = 100, max_depth =  2, max_features = 0.823927, Score = 1325749.36134, CV = 21
# 81 n_estimators = 100, max_depth =  6, max_features = 0.511155, Score = 1340294.81920, CV = 21
# 82 n_estimators = 100, max_depth =  7, max_features = 0.605368, Score = 1362691.25901, CV = 21
# 83 n_estimators = 100, max_depth =  9, max_features = 0.758009, Score = 1376462.49984, CV = 21
# 84 n_estimators = 100, max_depth =  4, max_features = 0.582826, Score = 1320694.19468, CV = 21
# 85 n_estimators = 100, max_depth =  2, max_features = 0.748887, Score = 1320837.68861, CV = 21
# 86 n_estimators = 100, max_depth =  9, max_features = 0.899060, Score = 1394777.24132, CV = 21
# 87 n_estimators = 100, max_depth =  2, max_features = 0.396787, Score = 1318075.43888, CV = 21
# 88 n_estimators = 100, max_depth =  8, max_features = 0.877878, Score = 1390262.06044, CV = 21
# 89 n_estimators = 100, max_depth =  3, max_features = 0.188986, Score = 1309120.01523, CV = 21
# 90 n_estimators = 100, max_depth =  8, max_features = 0.527456, Score = 1343602.91676, CV = 21
# 91 n_estimators = 100, max_depth =  6, max_features = 0.500634, Score = 1340294.81920, CV = 21
# 92 n_estimators = 100, max_depth =  8, max_features = 0.814726, Score = 1372100.68420, CV = 21
# 93 n_estimators = 100, max_depth =  8, max_features = 0.703531, Score = 1370343.59264, CV = 21
# 94 n_estimators = 100, max_depth =  6, max_features = 0.140666, Score = 1299440.95381, CV = 21
# 95 n_estimators = 100, max_depth =  4, max_features = 0.465786, Score = 1323330.44064, CV = 21
# 96 n_estimators = 100, max_depth =  5, max_features = 0.552629, Score = 1331464.71505, CV = 21
# 97 n_estimators = 100, max_depth =  7, max_features = 0.167080, Score = 1300584.03825, CV = 21
# 98 n_estimators = 100, max_depth =  3, max_features = 0.441690, Score = 1307830.91285, CV = 21
# 99 n_estimators = 100, max_depth =  6, max_features = 0.363565, Score = 1305375.61831, CV = 21
#  0 n_estimators = 100, max_depth =  8, max_features = 0.463272, Score = 1380750.55906, CV = 23
#  1 n_estimators = 100, max_depth =  6, max_features = 0.258751, Score = 1336381.87811, CV = 23
#  2 n_estimators = 100, max_depth =  9, max_features = 0.760923, Score = 1407282.79977, CV = 23
#  3 n_estimators = 100, max_depth =  9, max_features = 0.440839, Score = 1391917.61947, CV = 23
#  4 n_estimators = 100, max_depth =  9, max_features = 0.592590, Score = 1402610.87856, CV = 23
#  5 n_estimators = 100, max_depth =  6, max_features = 0.170834, Score = 1336899.75670, CV = 23
#  6 n_estimators = 100, max_depth =  8, max_features = 0.285851, Score = 1364810.40084, CV = 23
#  7 n_estimators = 100, max_depth =  6, max_features = 0.453334, Score = 1366453.35979, CV = 23
#  8 n_estimators = 100, max_depth =  9, max_features = 0.490308, Score = 1380187.38438, CV = 23
#  9 n_estimators = 100, max_depth =  8, max_features = 0.190645, Score = 1353065.21812, CV = 23
# 10 n_estimators = 100, max_depth =  6, max_features = 0.319453, Score = 1359085.37717, CV = 23
# 11 n_estimators = 100, max_depth =  5, max_features = 0.354840, Score = 1346470.54574, CV = 23
# 12 n_estimators = 100, max_depth =  7, max_features = 0.178809, Score = 1328893.65036, CV = 23
# 13 n_estimators = 100, max_depth =  2, max_features = 0.836255, Score = 1371618.97751, CV = 23
# 14 n_estimators = 100, max_depth =  2, max_features = 0.148161, Score = 1434287.58277, CV = 23
# 15 n_estimators = 100, max_depth =  5, max_features = 0.676230, Score = 1393970.50586, CV = 23
# 16 n_estimators = 100, max_depth =  7, max_features = 0.700036, Score = 1406104.67049, CV = 23
# 17 n_estimators = 100, max_depth =  6, max_features = 0.408331, Score = 1366453.35979, CV = 23
# 18 n_estimators = 100, max_depth =  3, max_features = 0.733139, Score = 1358533.96697, CV = 23
# 19 n_estimators = 100, max_depth =  4, max_features = 0.693432, Score = 1357502.03904, CV = 23
# 20 n_estimators = 100, max_depth =  4, max_features = 0.240968, Score = 1344518.16880, CV = 23
# 21 n_estimators = 100, max_depth =  8, max_features = 0.484708, Score = 1380750.55906, CV = 23
# 22 n_estimators = 100, max_depth =  2, max_features = 0.630888, Score = 1360559.03724, CV = 23
# 23 n_estimators = 100, max_depth =  2, max_features = 0.941238, Score = 1377146.08791, CV = 23
# 24 n_estimators = 100, max_depth =  7, max_features = 0.721242, Score = 1406104.67049, CV = 23
# 25 n_estimators = 100, max_depth =  4, max_features = 0.632587, Score = 1370475.10070, CV = 23
# 26 n_estimators = 100, max_depth =  6, max_features = 0.761453, Score = 1401061.71481, CV = 23
# 27 n_estimators = 100, max_depth =  4, max_features = 0.552885, Score = 1370475.10070, CV = 23
# 28 n_estimators = 100, max_depth =  5, max_features = 0.622794, Score = 1392132.12408, CV = 23
# 29 n_estimators = 100, max_depth =  5, max_features = 0.779559, Score = 1388792.06981, CV = 23
# 30 n_estimators = 100, max_depth =  3, max_features = 0.656412, Score = 1350488.91384, CV = 23
# 31 n_estimators = 100, max_depth =  4, max_features = 0.663045, Score = 1357502.03904, CV = 23
# 32 n_estimators = 100, max_depth =  6, max_features = 0.529891, Score = 1380396.87246, CV = 23
# 33 n_estimators = 100, max_depth =  3, max_features = 0.302711, Score = 1345302.23565, CV = 23
# 34 n_estimators = 100, max_depth =  3, max_features = 0.799742, Score = 1358533.96697, CV = 23
# 35 n_estimators = 100, max_depth =  2, max_features = 0.619742, Score = 1360559.03724, CV = 23
# 36 n_estimators = 100, max_depth =  3, max_features = 0.124407, Score = 1389664.70043, CV = 23
# 37 n_estimators = 100, max_depth =  7, max_features = 0.420866, Score = 1354953.40476, CV = 23
# 38 n_estimators = 100, max_depth =  9, max_features = 0.185441, Score = 1364851.84780, CV = 23
# 39 n_estimators = 100, max_depth =  3, max_features = 0.549057, Score = 1354518.62477, CV = 23
# 40 n_estimators = 100, max_depth =  7, max_features = 0.187641, Score = 1331826.82936, CV = 23
# 41 n_estimators = 100, max_depth =  8, max_features = 0.621465, Score = 1401160.35278, CV = 23
# 42 n_estimators = 100, max_depth =  4, max_features = 0.583925, Score = 1370475.10070, CV = 23
# 43 n_estimators = 100, max_depth =  2, max_features = 0.368832, Score = 1352246.25932, CV = 23
# 44 n_estimators = 100, max_depth =  6, max_features = 0.794906, Score = 1401061.71481, CV = 23
# 45 n_estimators = 100, max_depth =  2, max_features = 0.742722, Score = 1363599.87615, CV = 23
# 46 n_estimators = 100, max_depth =  6, max_features = 0.166659, Score = 1336899.75670, CV = 23
# 47 n_estimators = 100, max_depth =  3, max_features = 0.253244, Score = 1348092.67152, CV = 23
# 48 n_estimators = 100, max_depth =  9, max_features = 0.201484, Score = 1364851.84780, CV = 23
# 49 n_estimators = 100, max_depth =  6, max_features = 0.183164, Score = 1336381.87811, CV = 23
# 50 n_estimators = 100, max_depth =  8, max_features = 0.323992, Score = 1364810.40084, CV = 23
# 51 n_estimators = 100, max_depth =  4, max_features = 0.851045, Score = 1365873.15000, CV = 23
# 52 n_estimators = 100, max_depth =  3, max_features = 0.602848, Score = 1354518.62477, CV = 23
# 53 n_estimators = 100, max_depth =  4, max_features = 0.537991, Score = 1353597.38987, CV = 23
# 54 n_estimators = 100, max_depth =  6, max_features = 0.631636, Score = 1401224.22507, CV = 23
# 55 n_estimators = 100, max_depth =  2, max_features = 0.852368, Score = 1371618.97751, CV = 23
# 56 n_estimators = 100, max_depth =  4, max_features = 0.428214, Score = 1340656.65881, CV = 23
# 57 n_estimators = 100, max_depth =  8, max_features = 0.573873, Score = 1401160.35278, CV = 23
# 58 n_estimators = 100, max_depth =  4, max_features = 0.628620, Score = 1370475.10070, CV = 23
# 59 n_estimators = 100, max_depth =  9, max_features = 0.279284, Score = 1360527.59984, CV = 23
# 60 n_estimators = 100, max_depth =  9, max_features = 0.735096, Score = 1407282.79977, CV = 23
# 61 n_estimators = 100, max_depth =  7, max_features = 0.558404, Score = 1389436.51328, CV = 23
# 62 n_estimators = 100, max_depth =  3, max_features = 0.973856, Score = 1375209.30496, CV = 23
# 63 n_estimators = 100, max_depth =  6, max_features = 0.666961, Score = 1395635.47063, CV = 23
# 64 n_estimators = 100, max_depth =  4, max_features = 0.625375, Score = 1370475.10070, CV = 23
# 65 n_estimators = 100, max_depth =  3, max_features = 0.112875, Score = 1389664.70043, CV = 23
# 66 n_estimators = 100, max_depth =  9, max_features = 0.810278, Score = 1407282.79977, CV = 23
# 67 n_estimators = 100, max_depth =  4, max_features = 0.918612, Score = 1369624.58852, CV = 23
# 68 n_estimators = 100, max_depth =  7, max_features = 0.311536, Score = 1355058.48101, CV = 23
# 69 n_estimators = 100, max_depth =  9, max_features = 0.478612, Score = 1380187.38438, CV = 23
# 70 n_estimators = 100, max_depth =  7, max_features = 0.629108, Score = 1389436.51328, CV = 23
# 71 n_estimators = 100, max_depth =  9, max_features = 0.183927, Score = 1364851.84780, CV = 23
# 72 n_estimators = 100, max_depth =  7, max_features = 0.933795, Score = 1434707.51973, CV = 23
# 73 n_estimators = 100, max_depth =  6, max_features = 0.388006, Score = 1366453.35979, CV = 23
# 74 n_estimators = 100, max_depth =  8, max_features = 0.762505, Score = 1412153.63955, CV = 23
# 75 n_estimators = 100, max_depth =  4, max_features = 0.131141, Score = 1345140.07648, CV = 23
# 76 n_estimators = 100, max_depth =  5, max_features = 0.898373, Score = 1382295.73483, CV = 23
# 77 n_estimators = 100, max_depth =  7, max_features = 0.458310, Score = 1372167.44795, CV = 23
# 78 n_estimators = 100, max_depth =  5, max_features = 0.520238, Score = 1371321.46827, CV = 23
# 79 n_estimators = 100, max_depth =  3, max_features = 0.524370, Score = 1346165.04245, CV = 23
# 80 n_estimators = 100, max_depth =  5, max_features = 0.839459, Score = 1382295.73483, CV = 23
# 81 n_estimators = 100, max_depth =  4, max_features = 0.597661, Score = 1370475.10070, CV = 23
# 82 n_estimators = 100, max_depth =  7, max_features = 0.957932, Score = 1434707.51973, CV = 23
# 83 n_estimators = 100, max_depth =  9, max_features = 0.871974, Score = 1426075.59309, CV = 23
# 84 n_estimators = 100, max_depth =  2, max_features = 0.361132, Score = 1359654.75570, CV = 23
# 85 n_estimators = 100, max_depth =  5, max_features = 0.367896, Score = 1344039.23499, CV = 23
# 86 n_estimators = 100, max_depth =  6, max_features = 0.706827, Score = 1395635.47063, CV = 23
# 87 n_estimators = 100, max_depth =  3, max_features = 0.860648, Score = 1362541.19426, CV = 23
# 88 n_estimators = 100, max_depth =  4, max_features = 0.852798, Score = 1365873.15000, CV = 23
# 89 n_estimators = 100, max_depth =  2, max_features = 0.643739, Score = 1354221.98393, CV = 23
# 90 n_estimators = 100, max_depth =  4, max_features = 0.995494, Score = 1369624.58852, CV = 23
# 91 n_estimators = 100, max_depth =  6, max_features = 0.613113, Score = 1401224.22507, CV = 23
# 92 n_estimators = 100, max_depth =  8, max_features = 0.319888, Score = 1364810.40084, CV = 23
# 93 n_estimators = 100, max_depth =  2, max_features = 0.449320, Score = 1352246.25932, CV = 23
# 94 n_estimators = 100, max_depth =  8, max_features = 0.476684, Score = 1380750.55906, CV = 23
# 95 n_estimators = 100, max_depth =  9, max_features = 0.757236, Score = 1407282.79977, CV = 23
# 96 n_estimators = 100, max_depth =  9, max_features = 0.676696, Score = 1398993.17053, CV = 23
# 97 n_estimators = 100, max_depth =  3, max_features = 0.437874, Score = 1349061.15553, CV = 23
# 98 n_estimators = 100, max_depth =  4, max_features = 0.237378, Score = 1344518.16880, CV = 23
# 99 n_estimators = 100, max_depth =  7, max_features = 0.878880, Score = 1403980.03498, CV = 23
#  0 n_estimators = 100, max_depth =  4, max_features = 0.574414, Score = 1283058.03598, CV = 25
#  1 n_estimators = 100, max_depth =  6, max_features = 0.959904, Score = 1344484.33423, CV = 25
#  2 n_estimators = 100, max_depth =  5, max_features = 0.429618, Score = 1302183.05455, CV = 25
#  3 n_estimators = 100, max_depth =  9, max_features = 0.879816, Score = 1357603.39795, CV = 25
#  4 n_estimators = 100, max_depth =  3, max_features = 0.425869, Score = 1280412.89595, CV = 25
#  5 n_estimators = 100, max_depth =  2, max_features = 0.558455, Score = 1280066.46054, CV = 25
#  6 n_estimators = 100, max_depth =  7, max_features = 0.289561, Score = 1308588.75139, CV = 25
#  7 n_estimators = 100, max_depth =  3, max_features = 0.895661, Score = 1288079.83285, CV = 25
#  8 n_estimators = 100, max_depth =  6, max_features = 0.132156, Score = 1276872.75214, CV = 25
#  9 n_estimators = 100, max_depth =  5, max_features = 0.545447, Score = 1291586.17355, CV = 25
# 10 n_estimators = 100, max_depth =  6, max_features = 0.922818, Score = 1344484.33423, CV = 25
# 11 n_estimators = 100, max_depth =  5, max_features = 0.662426, Score = 1302703.05564, CV = 25
# 12 n_estimators = 100, max_depth =  5, max_features = 0.929453, Score = 1311846.88476, CV = 25
# 13 n_estimators = 100, max_depth =  9, max_features = 0.579359, Score = 1334376.09970, CV = 25
# 14 n_estimators = 100, max_depth =  4, max_features = 0.326578, Score = 1269086.80650, CV = 25
# 15 n_estimators = 100, max_depth =  9, max_features = 0.259684, Score = 1299587.41677, CV = 25
# 16 n_estimators = 100, max_depth =  5, max_features = 0.423293, Score = 1302183.05455, CV = 25
# 17 n_estimators = 100, max_depth =  6, max_features = 0.731521, Score = 1330711.11919, CV = 25
# 18 n_estimators = 100, max_depth =  5, max_features = 0.812686, Score = 1321966.45164, CV = 25
# 19 n_estimators = 100, max_depth =  7, max_features = 0.579072, Score = 1318720.95985, CV = 25
# 20 n_estimators = 100, max_depth =  2, max_features = 0.827537, Score = 1289562.10232, CV = 25
# 21 n_estimators = 100, max_depth =  9, max_features = 0.410676, Score = 1311987.28825, CV = 25
# 22 n_estimators = 100, max_depth =  7, max_features = 0.930537, Score = 1359729.04795, CV = 25
# 23 n_estimators = 100, max_depth =  2, max_features = 0.125870, Score = 1368576.18648, CV = 25
# 24 n_estimators = 100, max_depth =  3, max_features = 0.950818, Score = 1298594.05559, CV = 25
# 25 n_estimators = 100, max_depth =  9, max_features = 0.805073, Score = 1330501.49652, CV = 25
# 26 n_estimators = 100, max_depth =  8, max_features = 0.338829, Score = 1302470.68696, CV = 25
# 27 n_estimators = 100, max_depth =  9, max_features = 0.334070, Score = 1290014.60587, CV = 25
# 28 n_estimators = 100, max_depth =  2, max_features = 0.576812, Score = 1280066.46054, CV = 25
# 29 n_estimators = 100, max_depth =  9, max_features = 0.922781, Score = 1365342.90233, CV = 25
# 30 n_estimators = 100, max_depth =  6, max_features = 0.852527, Score = 1322868.27869, CV = 25
# 31 n_estimators = 100, max_depth =  4, max_features = 0.418241, Score = 1278123.26986, CV = 25
# 32 n_estimators = 100, max_depth =  7, max_features = 0.759102, Score = 1340779.24245, CV = 25
# 33 n_estimators = 100, max_depth =  8, max_features = 0.947371, Score = 1364677.32237, CV = 25
# 34 n_estimators = 100, max_depth =  3, max_features = 0.592085, Score = 1272460.54641, CV = 25
# 35 n_estimators = 100, max_depth =  2, max_features = 0.901862, Score = 1289562.10232, CV = 25
# 36 n_estimators = 100, max_depth =  4, max_features = 0.515528, Score = 1285364.99696, CV = 25
# 37 n_estimators = 100, max_depth =  6, max_features = 0.427628, Score = 1283706.66965, CV = 25
# 38 n_estimators = 100, max_depth =  8, max_features = 0.392814, Score = 1325634.35493, CV = 25
# 39 n_estimators = 100, max_depth =  6, max_features = 0.190732, Score = 1279579.32953, CV = 25
# 40 n_estimators = 100, max_depth =  2, max_features = 0.655640, Score = 1281861.23915, CV = 25
# 41 n_estimators = 100, max_depth =  7, max_features = 0.664172, Score = 1332515.84871, CV = 25
# 42 n_estimators = 100, max_depth =  5, max_features = 0.743409, Score = 1321966.45164, CV = 25
# 43 n_estimators = 100, max_depth =  7, max_features = 0.541321, Score = 1316685.32464, CV = 25
# 44 n_estimators = 100, max_depth =  9, max_features = 0.745773, Score = 1330501.49652, CV = 25
# 45 n_estimators = 100, max_depth =  6, max_features = 0.263858, Score = 1279579.32953, CV = 25
# 46 n_estimators = 100, max_depth =  5, max_features = 0.439894, Score = 1302183.05455, CV = 25
# 47 n_estimators = 100, max_depth =  4, max_features = 0.940110, Score = 1319568.23155, CV = 25
# 48 n_estimators = 100, max_depth =  6, max_features = 0.857549, Score = 1322868.27869, CV = 25
# 49 n_estimators = 100, max_depth =  2, max_features = 0.255314, Score = 1309671.22573, CV = 25
# 50 n_estimators = 100, max_depth =  8, max_features = 0.406611, Score = 1325634.35493, CV = 25
# 51 n_estimators = 100, max_depth =  5, max_features = 0.105050, Score = 1280014.83932, CV = 25
# 52 n_estimators = 100, max_depth =  6, max_features = 0.306645, Score = 1287833.46198, CV = 25
# 53 n_estimators = 100, max_depth =  6, max_features = 0.735692, Score = 1330711.11919, CV = 25
# 54 n_estimators = 100, max_depth =  6, max_features = 0.133631, Score = 1276872.75214, CV = 25
# 55 n_estimators = 100, max_depth =  6, max_features = 0.158644, Score = 1276872.75214, CV = 25
# 56 n_estimators = 100, max_depth =  6, max_features = 0.643483, Score = 1331116.95053, CV = 25
# 57 n_estimators = 100, max_depth =  9, max_features = 0.981831, Score = 1365342.90233, CV = 25
# 58 n_estimators = 100, max_depth =  8, max_features = 0.858735, Score = 1347173.60248, CV = 25
# 59 n_estimators = 100, max_depth =  3, max_features = 0.287967, Score = 1279172.96440, CV = 25
# 60 n_estimators = 100, max_depth =  9, max_features = 0.110251, Score = 1266825.83199, CV = 25
# 61 n_estimators = 100, max_depth =  2, max_features = 0.210247, Score = 1309671.22573, CV = 25
# 62 n_estimators = 100, max_depth =  6, max_features = 0.576636, Score = 1309487.72104, CV = 25
# 63 n_estimators = 100, max_depth =  3, max_features = 0.360727, Score = 1279172.96440, CV = 25
# 64 n_estimators = 100, max_depth =  5, max_features = 0.221276, Score = 1274370.84031, CV = 25
# 65 n_estimators = 100, max_depth =  8, max_features = 0.710389, Score = 1340104.77367, CV = 25
# 66 n_estimators = 100, max_depth =  2, max_features = 0.774285, Score = 1284407.63463, CV = 25
# 67 n_estimators = 100, max_depth =  4, max_features = 0.316980, Score = 1269086.80650, CV = 25
# 68 n_estimators = 100, max_depth =  4, max_features = 0.848565, Score = 1305191.02626, CV = 25
# 69 n_estimators = 100, max_depth =  5, max_features = 0.448458, Score = 1302183.05455, CV = 25
# 70 n_estimators = 100, max_depth =  8, max_features = 0.902806, Score = 1347173.60248, CV = 25
# 71 n_estimators = 100, max_depth =  7, max_features = 0.833651, Score = 1355795.55752, CV = 25
# 72 n_estimators = 100, max_depth =  5, max_features = 0.664681, Score = 1302703.05564, CV = 25
# 73 n_estimators = 100, max_depth =  6, max_features = 0.205177, Score = 1279579.32953, CV = 25
# 74 n_estimators = 100, max_depth =  9, max_features = 0.174302, Score = 1266825.83199, CV = 25
# 75 n_estimators = 100, max_depth =  3, max_features = 0.661030, Score = 1279051.04974, CV = 25
# 76 n_estimators = 100, max_depth =  5, max_features = 0.482460, Score = 1291586.17355, CV = 25
# 77 n_estimators = 100, max_depth =  7, max_features = 0.707898, Score = 1332515.84871, CV = 25
# 78 n_estimators = 100, max_depth =  6, max_features = 0.546132, Score = 1309487.72104, CV = 25
# 79 n_estimators = 100, max_depth =  7, max_features = 0.463867, Score = 1316685.32464, CV = 25
# 80 n_estimators = 100, max_depth =  2, max_features = 0.172683, Score = 1368576.18648, CV = 25
# 81 n_estimators = 100, max_depth =  6, max_features = 0.593965, Score = 1309487.72104, CV = 25
# 82 n_estimators = 100, max_depth =  7, max_features = 0.752579, Score = 1340779.24245, CV = 25
# 83 n_estimators = 100, max_depth =  4, max_features = 0.262858, Score = 1275003.42668, CV = 25
# 84 n_estimators = 100, max_depth =  6, max_features = 0.954498, Score = 1344484.33423, CV = 25
# 85 n_estimators = 100, max_depth =  3, max_features = 0.237975, Score = 1279963.70859, CV = 25
# 86 n_estimators = 100, max_depth =  3, max_features = 0.749767, Score = 1281608.64351, CV = 25
# 87 n_estimators = 100, max_depth =  3, max_features = 0.768270, Score = 1281608.64351, CV = 25
# 88 n_estimators = 100, max_depth =  5, max_features = 0.777830, Score = 1321966.45164, CV = 25
# 89 n_estimators = 100, max_depth =  7, max_features = 0.725839, Score = 1332515.84871, CV = 25
# 90 n_estimators = 100, max_depth =  2, max_features = 0.760880, Score = 1284407.63463, CV = 25
# 91 n_estimators = 100, max_depth =  4, max_features = 0.272018, Score = 1275003.42668, CV = 25
# 92 n_estimators = 100, max_depth =  4, max_features = 0.233461, Score = 1275003.42668, CV = 25
# 93 n_estimators = 100, max_depth =  5, max_features = 0.561712, Score = 1290680.23294, CV = 25
# 94 n_estimators = 100, max_depth =  4, max_features = 0.389244, Score = 1278123.26986, CV = 25
# 95 n_estimators = 100, max_depth =  7, max_features = 0.512037, Score = 1316685.32464, CV = 25
# 96 n_estimators = 100, max_depth =  2, max_features = 0.635226, Score = 1280066.46054, CV = 25
# 97 n_estimators = 100, max_depth =  9, max_features = 0.881219, Score = 1357603.39795, CV = 25
# 98 n_estimators = 100, max_depth =  4, max_features = 0.960996, Score = 1319568.23155, CV = 25
# 99 n_estimators = 100, max_depth =  2, max_features = 0.481239, Score = 1293196.38867, CV = 25

# %%
display(cv_cv)
# Out:
# [    epoch         score  n_estimators  max_depth  max_features  cv
#  25     25  1.303383e+06           100          5      0.234854  19,
#      epoch         score  n_estimators  max_depth  max_features  cv
#  56     56  1.277253e+06           100          8      0.174468  21,
#      epoch         score  n_estimators  max_depth  max_features  cv
#  12     12  1.328894e+06           100          7      0.178809  23,
#      epoch         score  n_estimators  max_depth  max_features  cv
#  60     60  1.266826e+06           100          9      0.110251  25]

# %%
# 가장 정확도가 높은 하이퍼패러미터를 저장
best_hyperparameters = finer_hyperparameters_list.iloc[0]

best_max_depth = best_hyperparameters["max_depth"]
best_max_features = best_hyperparameters["max_features"]

print(f"max_depth(best) = {best_max_depth}, max_features(best) = {best_max_features:.6f}")

# %%
from sklearn.ensemble import RandomForestRegressor

best_n_estimators = 3000
model = RandomForestRegressor(n_estimators=best_n_estimators,
                              max_depth=best_max_depth,
                              max_features=best_max_features,
                              random_state=37,
                              n_jobs=-1)
model

# %%
model.fit(X_train, Y_train)
prediction = model.predict(X_test)

# %% [markdown]
# ## 저장

# %%
save_file(prediction, 1)
# Out:
# done

# %%
a = 0
for i in range(len(prediction)) :
    if prediction[i] <= 0 :
        prediction[i] = 0
        a += 1

print(a)
#prediction = prediction.astype(int)
prediction
# Out:
# 17
# array([1.20770080e+06, 6.90031595e+05, 2.35273996e+06, 1.79146903e+06,
#        1.28393481e+06, 0.00000000e+00, 4.58973311e+04, 6.74994360e+04,
#        5.73651464e+04, 2.50705505e+05, 3.03949274e+05, 1.24414571e+06,
#        1.25255403e+06, 2.62124358e+05, 1.87210924e+06, 2.78142813e+06,
#        4.45740346e+04, 1.62199791e+06, 6.69302082e+05, 1.18944660e+06,
#        2.81445627e+05, 9.67216873e+04, 0.00000000e+00, 3.41069776e+05,
#        2.70813153e+04, 3.35247077e+06, 3.36520745e+04, 2.12681201e+06,
#        0.00000000e+00, 0.00000000e+00, 1.58380461e+06, 2.81941696e+05,
#        3.26562263e+05, 4.43743548e+05, 9.46483610e+04, 4.99330861e+04,
#        6.94357627e+04, 1.09966984e+05, 2.88522741e+04, 1.78010104e+04,
#        2.56992278e+05, 3.06542471e+05, 1.21835015e+06, 5.37247536e+05,
#        1.30546487e+06, 1.98985767e+06, 3.08039794e+05, 0.00000000e+00,
#        1.01210104e+06, 7.80163312e+04, 5.76994293e+04, 6.73670523e+05,
#        8.22218028e+04, 1.04375578e+06, 1.03554238e+06, 2.81674877e+04,
#        2.23132136e+04, 1.89835178e+06, 1.46056331e+06, 2.25219395e+06,
#        1.61502500e+06, 1.38009750e+06, 2.30654480e+05, 2.80414970e+05,
#        0.00000000e+00, 5.20945260e+04, 1.88346209e+06, 5.14741780e+05,
#        3.85326069e+05, 0.00000000e+00, 1.65775160e+06, 1.66631202e+06,
#        1.09410710e+05, 2.01698463e+06, 3.06363622e+05, 1.38590757e+04,
#        7.18358006e+05, 1.89925243e+05, 8.22420672e+04, 4.30805296e+04,
#        0.00000000e+00, 2.34714109e+06, 0.00000000e+00, 2.09615393e+06,
#        7.20863198e+04, 2.51010385e+06, 1.40848699e+05, 4.87631054e+04,
#        2.32593472e+04, 9.42631779e+05, 1.56229938e+04, 6.17191398e+04,
#        7.34784803e+05, 1.58490711e+06, 7.31397695e+05, 7.89400165e+04,
